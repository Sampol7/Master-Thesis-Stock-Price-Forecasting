# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_squared_error as mse

# %%
import pandas as pd

csv_file_path = 'close.csv'

df = pd.read_csv(csv_file_path, header=None)

close = df[0].tolist()
logclose = np.log(close).tolist()
logclose_series = pd.Series(logclose)
logreturns = np.array(logclose_series.diff().dropna()).tolist()

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, axes = plt.subplots(2, 1,figsize=(6, 6)) 

lags=np.ceil(np.log(len(logreturns)))

plot_acf(logreturns, ax=axes[0], lags=lags)  
axes[0].set_title('')
axes[0].set_xlabel('Lags', fontsize=20)
axes[0].set_ylabel('ACF', fontsize=20)
axes[0].tick_params(axis='both', which='major', labelsize=16) 

plot_pacf(logreturns, ax=axes[1], lags=lags, method='ywm') 
axes[1].set_title('')
axes[1].set_xlabel('Lags', fontsize=20)
axes[1].set_ylabel('PACF', fontsize=20)
axes[1].tick_params(axis='both', which='major', labelsize=16) 

fig.suptitle('Correlation in Training Log Returns', fontsize=24)


plt.tight_layout()
plt.show()

# %%
from math import floor

size = len(logclose)-100
close_train, close_test = close[0:size], close[size:len(close)]
logclose_train, logclose_test = logclose[0:size], logclose[size:len(logclose)]

series = logclose
train = logclose_train
test = logclose_test

plt.plot(series , color = 'r')
plt.show()

# %%
predicted_list, error_list = [], []
training_data = train

# %%
import pandas as pd

csv_file_path = 'forecasted_logclose_ARIMA_t_GARCH_t.csv'

df = pd.read_csv(csv_file_path, header=None)

predicted_list = df[0].tolist()

print(predicted_list)
# Out:
# [3.3425, 3.3362, 3.3245, 3.331, 3.3391, 3.3475, 3.3474, 3.3822, 3.3893, 3.3924, 3.3997, 3.4261, 3.4453, 3.4369, 3.441, 3.4603, 3.4867, 3.4968, 3.4867, 3.4899, 3.5012, 3.4913, 3.6438, 3.5962, 3.567, 3.5668, 3.5738, 3.5888, 3.5962, 3.5894, 3.5932, 3.5926, 3.5967, 3.5713, 3.5826, 3.6041, 3.5909, 3.5947, 3.5926, 3.5919, 3.5597, 3.5488, 3.5568, 3.5552, 3.5506, 3.5519, 3.5457, 3.5649, 3.5676, 3.5857, 3.5867, 3.6039, 3.6201, 3.6376, 3.6408, 3.6224, 3.6164, 3.6385, 3.6305, 3.6337, 3.5923, 3.5946, 3.5881, 3.5715, 3.5868, 3.5614, 3.5206, 3.4914, 3.4895, 3.4678, 3.4976, 3.5125, 3.5201, 3.5483, 3.5484, 3.5695, 3.5811, 3.5454, 3.5513, 3.5634, 3.5583, 3.5745, 3.572, 3.5732, 3.5499, 3.5692, 3.5884, 3.5671, 3.566, 3.5396, 3.5229, 3.5326, 3.5118, 3.509, 3.5007, 3.507, 3.5196, 3.5389, 3.5421, 3.5507]

# %%
for t in range(len(test)):
    predicted_value = predicted_list[t]
    obs = test[t]
    error_list.append(obs - predicted_value)
    training_data.append(obs)
    print('predicted=%f, expected=%f error=%f' % (predicted_value, obs,abs(predicted_value-obs)))
# Out:
# predicted=3.342500, expected=3.335414 error=0.007086
# predicted=3.336200, expected=3.323236 error=0.012964
# predicted=3.324500, expected=3.330059 error=0.005559
# predicted=3.331000, expected=3.338613 error=0.007613
# predicted=3.339100, expected=3.347093 error=0.007993
# predicted=3.347500, expected=3.346741 error=0.000759
# predicted=3.347400, expected=3.382354 error=0.034954
# predicted=3.382200, expected=3.389462 error=0.007262
# predicted=3.389300, expected=3.391820 error=0.002520
# predicted=3.392400, expected=3.399195 error=0.006795
# predicted=3.399700, expected=3.426215 error=0.026515
# predicted=3.426100, expected=3.445533 error=0.019433
# predicted=3.445300, expected=3.436243 error=0.009057
# predicted=3.436900, expected=3.440098 error=0.003198
# predicted=3.441000, expected=3.460095 error=0.019095
# predicted=3.460300, expected=3.487069 error=0.026769
# predicted=3.486700, expected=3.496811 error=0.010111
# predicted=3.496800, expected=3.485845 error=0.010955
# predicted=3.486700, expected=3.488903 error=0.002203
# predicted=3.489900, expected=3.500741 error=0.010841
# predicted=3.501200, expected=3.490429 error=0.010771
# predicted=3.491300, expected=3.647015 error=0.155715
# predicted=3.643800, expected=3.597312 error=0.046488
# predicted=3.596200, expected=3.564449 error=0.031751
# predicted=3.567000, expected=3.565298 error=0.001702
# predicted=3.566800, expected=3.573188 error=0.006388
# predicted=3.573800, expected=3.588506 error=0.014706
# predicted=3.588800, expected=3.595941 error=0.007141
# predicted=3.596200, expected=3.588506 error=0.007694
# predicted=3.589400, expected=3.592369 error=0.002969
# predicted=3.593200, expected=3.591818 error=0.001382
# predicted=3.592600, expected=3.595941 error=0.003341
# predicted=3.596700, expected=3.569814 error=0.026886
# predicted=3.571300, expected=3.581573 error=0.010273
# predicted=3.582600, expected=3.604138 error=0.021538
# predicted=3.604100, expected=3.590163 error=0.013937
# predicted=3.590900, expected=3.593744 error=0.002844
# predicted=3.594700, expected=3.591818 error=0.002882
# predicted=3.592600, expected=3.590991 error=0.001609
# predicted=3.591900, expected=3.557916 error=0.033984
# predicted=3.559700, expected=3.547028 error=0.012672
# predicted=3.548800, expected=3.555919 error=0.007119
# predicted=3.556800, expected=3.554491 error=0.002309
# predicted=3.555200, expected=3.549617 error=0.005583
# predicted=3.550600, expected=3.551053 error=0.000453
# predicted=3.551900, expected=3.544720 error=0.007180
# predicted=3.545700, expected=3.564449 error=0.018749
# predicted=3.564900, expected=3.567277 error=0.002377
# predicted=3.567600, expected=3.585461 error=0.017861
# predicted=3.585700, expected=3.586293 error=0.000593
# predicted=3.586700, expected=3.603594 error=0.016894
# predicted=3.603900, expected=3.620065 error=0.016165
# predicted=3.620100, expected=3.637586 error=0.017486
# predicted=3.637600, expected=3.640477 error=0.002877
# predicted=3.640800, expected=3.621136 error=0.019664
# predicted=3.622400, expected=3.614964 error=0.007436
# predicted=3.616400, expected=3.638112 error=0.021712
# predicted=3.638500, expected=3.629925 error=0.008575
# predicted=3.630500, expected=3.632838 error=0.002338
# predicted=3.633700, expected=3.590439 error=0.043261
# predicted=3.592300, expected=3.592919 error=0.000619
# predicted=3.594600, expected=3.587124 error=0.007476
# predicted=3.588100, expected=3.570096 error=0.018004
# predicted=3.571500, expected=3.586016 error=0.014516
# predicted=3.586800, expected=3.560193 error=0.026607
# predicted=3.561400, expected=3.518091 error=0.043309
# predicted=3.520600, expected=3.488903 error=0.031697
# predicted=3.491400, expected=3.487987 error=0.003413
# predicted=3.489500, expected=3.466361 error=0.023139
# predicted=3.467800, expected=3.497113 error=0.029313
# predicted=3.497600, expected=3.512739 error=0.015139
# predicted=3.512500, expected=3.519869 error=0.007369
# predicted=3.520100, expected=3.548467 error=0.028367
# predicted=3.548300, expected=3.548180 error=0.000120
# predicted=3.548400, expected=3.569251 error=0.020851
# predicted=3.569500, expected=3.581016 error=0.011516
# predicted=3.581100, expected=3.543854 error=0.037246
# predicted=3.545400, expected=3.549905 error=0.004505
# predicted=3.551300, expected=3.563033 error=0.011733
# predicted=3.563400, expected=3.557631 error=0.005769
# predicted=3.558300, expected=3.574030 error=0.015730
# predicted=3.574500, expected=3.571503 error=0.002997
# predicted=3.572000, expected=3.572346 error=0.000346
# predicted=3.573200, expected=3.548467 error=0.024733
# predicted=3.549900, expected=3.568405 error=0.018505
# predicted=3.569200, expected=3.588506 error=0.019306
# predicted=3.588400, expected=3.566147 error=0.022253
# predicted=3.567100, expected=3.564732 error=0.002368
# predicted=3.566000, expected=3.538057 error=0.027943
# predicted=3.539600, expected=3.521052 error=0.018548
# predicted=3.522900, expected=3.531641 error=0.008741
# predicted=3.532600, expected=3.510650 error=0.021950
# predicted=3.511800, expected=3.507657 error=0.004143
# predicted=3.509000, expected=3.499533 error=0.009467
# predicted=3.500700, expected=3.506158 error=0.005458
# predicted=3.507000, expected=3.519277 error=0.012277
# predicted=3.519600, expected=3.538928 error=0.019328
# predicted=3.538900, expected=3.541829 error=0.002929
# predicted=3.542100, expected=3.550192 error=0.008092
# predicted=3.550700, expected=3.548467 error=0.002233

# %%
error = mse(test, predicted_list)
print('Test MSE: %.3f' % error)
# Out:
# Test MSE: 0.001

# %%
import pandas as pd

csv_file_path = 'rawResiduals_ARIMA_t_GARCH_t.csv'

df = pd.read_csv(csv_file_path, header=None)

training_error = np.array(df[0].tolist())

print(training_error)
# Out:
# [-0.0015702  -0.01431    -0.010919   ...  0.00063469 -0.005104
#   0.0086868 ]

# %%
plt.plot(test)
plt.plot(predicted_list, color='red')
plt.show()

error = mse(test,predicted_list)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000529

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error as mse

# %%
import numpy as np
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.svm import SVR
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
import hyperopt
import warnings

training_error = np.array(training_error).reshape(-1,1)

space = {
    "window_size": hp.choice("window_size", range(2,20)),
    "kernel": hp.choice("kernel", ["linear", "poly", "rbf"]),
    "C": hp.loguniform("C", np.log(0.001), np.log(100)),
    "epsilon": hp.loguniform("epsilon", np.log(0.00001), np.log(1)),
    "gamma": hp.choice("gamma", ["scale", "auto"]),
    "degree": hp.quniform("degree", 2, 4, 1),  
    "coef0": hp.uniform("coef0", -5, 5)      
}

def objective(params):
    window_size = params["window_size"]
    kernel = params["kernel"]
    C = params["C"]
    epsilon = params["epsilon"]

    scaler = StandardScaler()

    training_error_scaled = scaler.fit_transform(training_error)
    train_X, train_Y = [], []
    for i in range(len(training_error_scaled) - window_size):
        train_X.append(training_error_scaled[i:i+window_size])
        train_Y.append(training_error_scaled[i+window_size])
    new_train_X = np.array([x.reshape(-1) for x in train_X])
    new_train_Y = np.array(train_Y).ravel()

    svr_params = {"C": C, "epsilon": epsilon}
    
    if kernel == "poly":
        svr_params["gamma"] = params["gamma"]
        svr_params["degree"] = int(params["degree"]) 
        svr_params["coef0"] = (params["coef0"])    
    elif kernel == "rbf":
        svr_params["gamma"] = params["gamma"]

    model = SVR(kernel=kernel, **svr_params)

    tscv = TimeSeriesSplit(n_splits=2)
    score = np.mean(cross_val_score(model, new_train_X, new_train_Y, cv=tscv, scoring='neg_mean_squared_error', n_jobs=-1))
    
    return {"loss": -score, "status": STATUS_OK}

trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials,
            rstate=np.random.default_rng(42))

best_loss = trials.best_trial['result']['loss']
best_score = best_loss

print("\n------------------------")
print("BEST OVERALL RESULTS:")
print("------------------------")
print("Best parameters (raw indices and values):")
print(best)
print(f"Best score: {best_score:.4f}")
# Out:
# 100%|██████████| 100/100 [12:19<00:00,  7.39s/trial, best loss: 0.7807837138842728]
#
# ------------------------
# BEST OVERALL RESULTS:
# ------------------------
# Best parameters (raw indices and values):
# {'C': 0.005322369228736632, 'coef0': 1.603325906590108, 'degree': 2.0, 'epsilon': 0.022978105168615273, 'gamma': 0, 'kernel': 2, 'window_size': 7}
# Best score: 0.7808

# %%
from sklearn.preprocessing import RobustScaler, RobustScaler
from sklearn.svm import SVR
import numpy as np

window_sizes = range(2,20)
kernels_list = ["linear", "poly", "rbf"]
gamma_list = ["scale", "auto"]

window_size = window_sizes[best["window_size"]]
best_kernel = kernels_list[best["kernel"]]
best_gamma = gamma_list[best["gamma"]]
best_C = best["C"]
best_epsilon = best["epsilon"]
best_degree = int(best["degree"]) if best_kernel == "poly" else None
best_coef0 = (best["coef0"]) if best_kernel == "poly" else None

scaler = StandardScaler()

training_error_scaled = scaler.fit_transform(training_error)
train_X, train_Y = [], []
for i in range(0, len(training_error_scaled) - window_size):
    train_X.append(training_error_scaled[i:i+window_size])
    train_Y.append(training_error_scaled[i+window_size])

new_train_X = np.array([x.reshape(-1) for x in train_X])
new_train_Y = np.array(train_Y).ravel()

svr_params = {"C": best_C, "epsilon": best_epsilon}
if best_kernel == "poly":
    svr_params["gamma"] = best_gamma
    svr_params["degree"] = best_degree
    svr_params["coef0"] = best_coef0
elif best_kernel == "rbf":
    svr_params["gamma"] = best_gamma

model = SVR(kernel=best_kernel, **svr_params)

model.fit(new_train_X, new_train_Y)
# Out:
# SVR(C=0.005322369228736632, epsilon=0.022978105168615273)

# %%
print(window_size)
print(best_kernel)
print(best_gamma)
print(best_C)
print(best_epsilon)
print(best_degree)
print(best_coef0)
# Out:
# 9
# rbf
# scale
# 0.005322369228736632
# 0.022978105168615273
# None
# None

# %%
predictions = model.predict(new_train_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))

error = mse(training_error[window_size:],predictions_rescaled)
print('Train MSE: %.6f' % error)

Y = pd.DataFrame(training_error[window_size:])
pred = pd.DataFrame(predictions_rescaled)
plt.plot(Y, label='Real Residuals')
plt.plot(pred , color = 'r', label='Residual Predictions')
plt.xlabel('Time', fontsize=16)  
plt.ylabel('Value', fontsize=16) 
plt.ylim([-0.18,0.18]) 
plt.title('ML Predictions On ARIMA-t Residuals', fontsize=24)
legend = plt.legend(loc='best', fontsize=14, frameon=True)
legend.get_frame().set_facecolor('white')  
legend.get_frame().set_edgecolor('black')  
plt.text(10, -0.15, f'MSE: {error:.6f}', fontsize=14, color='k',
         bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()
# Out:
# Train MSE: 0.000564

# %%
rawResiduals_ARIMA_t_GARCH_t_SVR = Y - pred
plt.plot(rawResiduals_ARIMA_t_GARCH_t_SVR)
plt.show()

rawResiduals_ARIMA_t_GARCH_t_SVR.to_csv('rawResiduals_ARIMA_t_GARCH_t_SVR_BO-TPE_standardscaler.csv', index=False)

# %%
test_extended = training_error.tolist()[-1*window_size:] + error_list
test_data = []
for i in test_extended:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
        
test_data = np.array(test_data).reshape(-1,1)
test_scaled = scaler.transform(test_data)

test_X,test_Y = [],[]
for i in range(0 , len(test_scaled) - window_size):
    test_X.append(test_scaled[i:i+window_size])
    test_Y.append(test_scaled[i+window_size])

new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)

predictions = model.predict(new_test_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))


Y = pd.DataFrame(error_list)
pred = pd.DataFrame(predictions_rescaled)

plt.plot(predictions_rescaled , color = 'r')
plt.show()
error = mse(error_list,predictions_rescaled)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000530

# %%
error = mse(error_list,predictions_rescaled)
print('Test MSE: %.6f' % error)

plt.plot(Y, label='Forecasting Error ARIMA-t')
plt.plot(pred , color = 'r', label='Residual Forecasts')
plt.xlabel('Time', fontsize=20)  
plt.ylabel('Value', fontsize=20) 
plt.ylim([-0.18,0.18])  
legend = plt.legend(loc='best', fontsize=14, frameon=True)
legend.get_frame().set_facecolor('white') 
legend.get_frame().set_edgecolor('black') 
plt.title('ML Forecasts On ARIMA-t Forecasting Errors', fontsize=24)
plt.text(50, 0.13, f'MSE: {error:.6f}', fontsize=14, color='k',
         bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()
# Out:
# Test MSE: 0.000530

# %%
predicted_array = np.array(predicted_list)
final_pred = predicted_array+predictions_rescaled.flatten()
hybrid_error = mse(np.array(test), final_pred)
print('Hybrid Test MSE: %.6f' % hybrid_error)

plt.plot(pd.DataFrame(test), label="Real Log Close")
plt.plot(pd.DataFrame(final_pred), color='r', label="Hybrid Forecasts")
plt.xlabel('Time', fontsize=20)  
plt.ylabel('Value', fontsize=20)  
legend = plt.legend(loc='best', fontsize=14, frameon=True)
legend.get_frame().set_facecolor('white') 
legend.get_frame().set_edgecolor('black') 
plt.title('Hybrid Forecasts On Test Data', fontsize=24)
plt.text(60, 3.3, f'MSE: {error:.6f}', fontsize=14, color='k',
         bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()
# Out:
# Hybrid Test MSE: 0.000530

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on logclose: ")
print(compute_error_metrics(test, final_pred))
print(compute_directional_metrics(test, final_pred))
# Out:
# Errors on logclose:
# {'NMSE': 0.09360673209674567, 'MAE': 0.01461388664947091, 'RMSE': 0.023021529965107965, 'MSE': 0.0005299908419343638, 'MAPE': 0.41215241579520384, 'TheilsU': 0.9956632848930952}
# {'DA': 0.5555555555555556, 'DS': 0.48484848484848486, 'CU': 0.543859649122807, 'CD': 0.40476190476190477}

# %%
close_pred = np.exp(final_pred)
Y = pd.DataFrame(close_test)
pred = pd.DataFrame(close_pred)
plt.plot(Y, label="Actual Close")
plt.plot(pred , color = 'r', label="Hybrid Forecast Close")
plt.legend()
plt.show()

error = mse(close_test,close_pred)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.652518

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on close: ")
print(compute_error_metrics(close_test, close_pred))
print(compute_directional_metrics(close_test, close_pred))
# Out:
# Errors on close:
# {'NMSE': 0.10649140373967939, 'MAE': 0.505259129450983, 'RMSE': 0.8077856380074724, 'MSE': 0.6525176369711393, 'MAPE': 1.4525126951843559, 'TheilsU': 0.9956652182093857}
# {'DA': 0.5555555555555556, 'DS': 0.48484848484848486, 'CU': 0.543859649122807, 'CD': 0.40476190476190477}

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from trading_strategies import trading_strategy1

trading_strategy1(close_test, close_pred)
# Out:
# Stock: 28.09 Action: Buy Portfolio: 28090.0 Stocks: 1000 Balance_init: 0 total($) 28090.0
# Stock: 27.75 Action: Bought--Holding Portfolio: 27750.0 Stocks: 1000 Balance_init: 0 total($) 27750.0
# Stock: 27.94 Action: Bought--Holding Portfolio: 27940.0 Stocks: 1000 Balance_init: 0 total($) 27940.0
# Stock: 28.18 Action: Bought--Holding Portfolio: 28180.0 Stocks: 1000 Balance_init: 0 total($) 28180.0
# Stock: 28.42 Action: Bought--Holding Portfolio: 28420.0 Stocks: 1000 Balance_init: 0 total($) 28420.0
# Stock: 28.41 Action: Bought--Holding Portfolio: 28410.0 Stocks: 1000 Balance_init: 0 total($) 28410.0
# Stock: 29.44 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29440.0
# Stock: 29.65 Action: Buy Portfolio: 29412.8 Stocks: 992 Balance_init: 27 total($) 29439.8
# Stock: 29.72 Action: Bought--Holding Portfolio: 29482.24 Stocks: 992 Balance_init: 27 total($) 29509.24
# Stock: 29.94 Action: Bought--Holding Portfolio: 29700.48 Stocks: 992 Balance_init: 27 total($) 29727.48
# Stock: 30.76 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30540.92
# Stock: 31.36 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30540.92
# Stock: 31.07 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30540.92
# Stock: 31.19 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30540.92
# Stock: 31.82 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30540.92
# Stock: 32.69 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30540.92
# Stock: 33.01 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30540.92
# Stock: 32.65 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30540.92
# Stock: 32.75 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30540.92
# Stock: 33.14 Action: Buy Portfolio: 30521.94 Stocks: 921 Balance_init: 18 total($) 30539.94
# Stock: 32.8 Action: Bought--Holding Portfolio: 30208.8 Stocks: 921 Balance_init: 18 total($) 30226.8
# Stock: 38.36 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 35347.56
# Stock: 36.5 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 35347.56
# Stock: 35.32 Action: Buy Portfolio: 35320.0 Stocks: 1000 Balance_init: 27 total($) 35347.0
# Stock: 35.35 Action: Bought--Holding Portfolio: 35350.0 Stocks: 1000 Balance_init: 27 total($) 35377.0
# Stock: 35.63 Action: Bought--Holding Portfolio: 35630.0 Stocks: 1000 Balance_init: 27 total($) 35657.0
# Stock: 36.18 Action: Bought--Holding Portfolio: 36180.0 Stocks: 1000 Balance_init: 27 total($) 36207.0
# Stock: 36.45 Action: Bought--Holding Portfolio: 36450.0 Stocks: 1000 Balance_init: 27 total($) 36477.0
# Stock: 36.18 Action: Bought--Holding Portfolio: 36180.0 Stocks: 1000 Balance_init: 27 total($) 36207.0
# Stock: 36.32 Action: Bought--Holding Portfolio: 36320.0 Stocks: 1000 Balance_init: 27 total($) 36347.0
# Stock: 36.3 Action: Bought--Holding Portfolio: 36300.0 Stocks: 1000 Balance_init: 27 total($) 36327.0
# Stock: 36.45 Action: Bought--Holding Portfolio: 36450.0 Stocks: 1000 Balance_init: 27 total($) 36477.0
# Stock: 35.51 Action: Bought--Holding Portfolio: 35510.0 Stocks: 1000 Balance_init: 27 total($) 35537.0
# Stock: 35.93 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 35957.0
# Stock: 36.75 Action: Buy Portfolio: 35941.5 Stocks: 978 Balance_init: 15 total($) 35956.5
# Stock: 36.24 Action: Bought--Holding Portfolio: 35442.72 Stocks: 978 Balance_init: 15 total($) 35457.72
# Stock: 36.37 Action: Bought--Holding Portfolio: 35569.86 Stocks: 978 Balance_init: 15 total($) 35584.86
# Stock: 36.3 Action: Bought--Holding Portfolio: 35501.4 Stocks: 978 Balance_init: 15 total($) 35516.4
# Stock: 36.27 Action: Bought--Holding Portfolio: 35472.06 Stocks: 978 Balance_init: 15 total($) 35487.06
# Stock: 35.09 Action: Bought--Holding Portfolio: 34318.02 Stocks: 978 Balance_init: 15 total($) 34333.02
# Stock: 34.71 Action: Bought--Holding Portfolio: 33946.38 Stocks: 978 Balance_init: 15 total($) 33961.38
# Stock: 35.02 Action: Bought--Holding Portfolio: 34249.56 Stocks: 978 Balance_init: 15 total($) 34264.56
# Stock: 34.97 Action: Bought--Holding Portfolio: 34200.66 Stocks: 978 Balance_init: 15 total($) 34215.66
# Stock: 34.8 Action: Bought--Holding Portfolio: 34034.4 Stocks: 978 Balance_init: 15 total($) 34049.4
# Stock: 34.85 Action: Bought--Holding Portfolio: 34083.3 Stocks: 978 Balance_init: 15 total($) 34098.3
# Stock: 34.63 Action: Bought--Holding Portfolio: 33868.14 Stocks: 978 Balance_init: 15 total($) 33883.14
# Stock: 35.32 Action: Bought--Holding Portfolio: 34542.96 Stocks: 978 Balance_init: 15 total($) 34557.96
# Stock: 35.42 Action: Bought--Holding Portfolio: 34640.76 Stocks: 978 Balance_init: 15 total($) 34655.76
# Stock: 36.07 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 35291.46
# Stock: 36.1 Action: Buy Portfolio: 35269.7 Stocks: 977 Balance_init: 21 total($) 35290.7
# Stock: 36.73 Action: Bought--Holding Portfolio: 35885.21 Stocks: 977 Balance_init: 21 total($) 35906.21
# Stock: 37.34 Action: Bought--Holding Portfolio: 36481.18 Stocks: 977 Balance_init: 21 total($) 36502.18
# Stock: 38.0 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 37147.0
# Stock: 38.11 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 37147.0
# Stock: 37.38 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 37147.0
# Stock: 37.15 Action: Buy Portfolio: 37112.85 Stocks: 999 Balance_init: 34 total($) 37146.85
# Stock: 38.02 Action: Bought--Holding Portfolio: 37981.98 Stocks: 999 Balance_init: 34 total($) 38015.98
# Stock: 37.71 Action: Bought--Holding Portfolio: 37672.29 Stocks: 999 Balance_init: 34 total($) 37706.29
# Stock: 37.82 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 37816.18
# Stock: 36.25 Action: Buy Portfolio: 37808.75 Stocks: 1043 Balance_init: 7 total($) 37815.75
# Stock: 36.34 Action: Bought--Holding Portfolio: 37902.62 Stocks: 1043 Balance_init: 7 total($) 37909.62
# Stock: 36.13 Action: Bought--Holding Portfolio: 37683.59 Stocks: 1043 Balance_init: 7 total($) 37690.59
# Stock: 35.52 Action: Bought--Holding Portfolio: 37047.36 Stocks: 1043 Balance_init: 7 total($) 37054.36
# Stock: 36.09 Action: Bought--Holding Portfolio: 37641.87 Stocks: 1043 Balance_init: 7 total($) 37648.87
# Stock: 35.17 Action: Bought--Holding Portfolio: 36682.31 Stocks: 1043 Balance_init: 7 total($) 36689.31
# Stock: 33.72 Action: Bought--Holding Portfolio: 35169.96 Stocks: 1043 Balance_init: 7 total($) 35176.96
# Stock: 32.75 Action: Bought--Holding Portfolio: 34158.25 Stocks: 1043 Balance_init: 7 total($) 34165.25
# Stock: 32.72 Action: Bought--Holding Portfolio: 34126.96 Stocks: 1043 Balance_init: 7 total($) 34133.96
# Stock: 32.02 Action: Bought--Holding Portfolio: 33396.86 Stocks: 1043 Balance_init: 7 total($) 33403.86
# Stock: 33.02 Action: Bought--Holding Portfolio: 34439.86 Stocks: 1043 Balance_init: 7 total($) 34446.86
# Stock: 33.54 Action: Bought--Holding Portfolio: 34982.22 Stocks: 1043 Balance_init: 7 total($) 34989.22
# Stock: 33.78 Action: Bought--Holding Portfolio: 35232.54 Stocks: 1043 Balance_init: 7 total($) 35239.54
# Stock: 34.76 Action: Bought--Holding Portfolio: 36254.68 Stocks: 1043 Balance_init: 7 total($) 36261.68
# Stock: 34.75 Action: Bought--Holding Portfolio: 36244.25 Stocks: 1043 Balance_init: 7 total($) 36251.25
# Stock: 35.49 Action: Bought--Holding Portfolio: 37016.07 Stocks: 1043 Balance_init: 7 total($) 37023.07
# Stock: 35.91 Action: Bought--Holding Portfolio: 37454.13 Stocks: 1043 Balance_init: 7 total($) 37461.13
# Stock: 34.6 Action: Bought--Holding Portfolio: 36087.8 Stocks: 1043 Balance_init: 7 total($) 36094.8
# Stock: 34.81 Action: Bought--Holding Portfolio: 36306.83 Stocks: 1043 Balance_init: 7 total($) 36313.83
# Stock: 35.27 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 36793.61
# Stock: 35.08 Action: Buy Portfolio: 36763.84 Stocks: 1048 Balance_init: 29 total($) 36792.84
# Stock: 35.66 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 37400.68
# Stock: 35.57 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 37400.68
# Stock: 35.6 Action: Buy Portfolio: 37380.0 Stocks: 1050 Balance_init: 20 total($) 37400.0
# Stock: 34.76 Action: Bought--Holding Portfolio: 36498.0 Stocks: 1050 Balance_init: 20 total($) 36518.0
# Stock: 35.46 Action: Bought--Holding Portfolio: 37233.0 Stocks: 1050 Balance_init: 20 total($) 37253.0
# Stock: 36.18 Action: Bought--Holding Portfolio: 37989.0 Stocks: 1050 Balance_init: 20 total($) 38009.0
# Stock: 35.38 Action: Bought--Holding Portfolio: 37149.0 Stocks: 1050 Balance_init: 20 total($) 37169.0
# Stock: 35.33 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 37116.5
# Stock: 34.4 Action: Buy Portfolio: 37083.2 Stocks: 1078 Balance_init: 33 total($) 37116.2
# Stock: 33.82 Action: Bought--Holding Portfolio: 36457.96 Stocks: 1078 Balance_init: 33 total($) 36490.96
# Stock: 34.18 Action: Bought--Holding Portfolio: 36846.04 Stocks: 1078 Balance_init: 33 total($) 36879.04
# Stock: 33.47 Action: Bought--Holding Portfolio: 36080.66 Stocks: 1078 Balance_init: 33 total($) 36113.66
# Stock: 33.37 Action: Bought--Holding Portfolio: 35972.86 Stocks: 1078 Balance_init: 33 total($) 36005.86
# Stock: 33.1 Action: Bought--Holding Portfolio: 35681.8 Stocks: 1078 Balance_init: 33 total($) 35714.8
# Stock: 33.32 Action: Bought--Holding Portfolio: 35918.96 Stocks: 1078 Balance_init: 33 total($) 35951.96
# Stock: 33.76 Action: Bought--Holding Portfolio: 36393.28 Stocks: 1078 Balance_init: 33 total($) 36426.28
# Stock: 34.43 Action: Bought--Holding Portfolio: 37115.54 Stocks: 1078 Balance_init: 33 total($) 37148.54
# Stock: 34.53 Action: Bought--Holding Portfolio: 37223.34 Stocks: 1078 Balance_init: 33 total($) 37256.34
# Stock: 34.82 Action: Bought--Holding Portfolio: 37535.96 Stocks: 1078 Balance_init: 33 total($) 37568.96
# Final value of stock:
# 34.76
# Final value of portfolio:
# 37569.0

# %% [markdown]
# From here on all figures that were originally in MATLAB are generated for poster presentation

# %%
plt.plot(close)
plt.xlabel('Time', fontsize=20)  
plt.ylabel('Value', fontsize=20)  
plt.title('Close', fontsize=24)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()

# %%
plt.plot(logclose)
plt.xlabel('Time', fontsize=20)  
plt.ylabel('Value', fontsize=20)  
plt.title('Log Close', fontsize=24)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()

# %%
plt.plot(logreturns)
plt.xlabel('Time', fontsize=20)  
plt.ylabel('Value', fontsize=20)  
plt.title('Log Returns', fontsize=24)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, axes = plt.subplots(2, 1,figsize=(6, 6)) 

lags=np.ceil(np.log(len(logreturns)))

plot_acf(logreturns, ax=axes[0], lags=lags)  
axes[0].set_title('')
axes[0].set_xlabel('Lags', fontsize=20)
axes[0].set_ylabel('ACF', fontsize=20)
axes[0].tick_params(axis='both', which='major', labelsize=16) 
axes[0].grid(True)

plot_pacf(logreturns, ax=axes[1], lags=lags, method='ywm') 
axes[1].set_title('')
axes[1].set_xlabel('Lags', fontsize=20)
axes[1].set_ylabel('PACF', fontsize=20)
axes[1].tick_params(axis='both', which='major', labelsize=16) 
axes[1].grid(True)

fig.suptitle('Correlation in Training Log Returns', fontsize=24)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, axes = plt.subplots(2, 1,figsize=(6, 6)) 

lags=np.ceil(np.log(len(training_error)))

plot_acf(training_error, ax=axes[0], lags=lags)  
axes[0].set_title('')
axes[0].set_xlabel('Lags', fontsize=20)
axes[0].set_ylabel('ACF', fontsize=20)
axes[0].tick_params(axis='both', which='major', labelsize=16) 
axes[0].grid(True)

plot_pacf(training_error, ax=axes[1], lags=lags, method='ywm') 
axes[1].set_title('')
axes[1].set_xlabel('Lags', fontsize=20)
axes[1].set_ylabel('PACF', fontsize=20)
axes[1].tick_params(axis='both', which='major', labelsize=16) 
axes[1].grid(True)

fig.suptitle('Correlation in Residuals of ARIMA-t', fontsize=24)


plt.tight_layout()
plt.show()

# %%
import pandas as pd

csv_file_path = 'stanResiduals_ARIMA_t.csv'

df = pd.read_csv(csv_file_path, header=None)

stan = np.array(df[0].tolist())

import pandas as pd
import matplotlib.pyplot as plt

stan_series = pd.Series(stan)  


window_size = 100
moving_variance = stan_series.rolling(window=window_size, min_periods=1).var()

plt.figure()
plt.plot(moving_variance)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Variance', fontsize=20)
plt.ylim([-0.1,2.2])
plt.title('Moving Variance in Residuals of ARIMA-t', fontsize=24)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()

# %%
import pandas as pd

csv_file_path = 'stanResiduals_ARIMA_t_GARCH_t.csv'

df = pd.read_csv(csv_file_path, header=None)

stan = np.array(df[0].tolist())


import pandas as pd
import matplotlib.pyplot as plt

stan_series = pd.Series(stan)  


window_size = 100
moving_variance = stan_series.rolling(window=window_size, min_periods=1).var()

plt.figure()
plt.plot(moving_variance)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Variance', fontsize=20)
plt.ylim([-0.1,2.2])
plt.title('Moving Variance Residuals ARIMA_t-GARCH_t', fontsize=24)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()

# %%
import pandas as pd

csv_file_path = 'train_logclose.csv'

df = pd.read_csv(csv_file_path, header=None)

train_logclose = df[0].tolist()


plt.plot(train_logclose)
plt.xlabel('Time', fontsize=20)  
plt.ylabel('Value', fontsize=20)  
plt.title('Log Close Training Data', fontsize=24)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()

# %%
import pandas as pd

csv_file_path = 'rawResiduals_ARIMA_t.csv'

df = pd.read_csv(csv_file_path, header=None)

training_error = np.array(df[0].tolist())


import numpy as np
import matplotlib.pyplot as plt

train_logclose_pred = train_logclose - training_error

mse = np.mean((train_logclose - train_logclose_pred) ** 2)

plt.figure()
plt.plot(train_logclose, label='Real Log Close') 
plt.plot(train_logclose_pred, 'r', label='Log Close Predictions')  
plt.title('ARIMA-t Predictions On Training Data', fontsize=24)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Value', fontsize=20)
legend = plt.legend(loc='best', fontsize=14)
legend.get_frame().set_facecolor('white')
legend.get_frame().set_edgecolor('black')
plt.text(400, 2.65, f'MSE: {mse:.6f}', fontsize=14, color='k',
         bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()

# %%
import pandas as pd

csv_file_path = 'forecasted_logclose_ARIMA_t.csv'

df = pd.read_csv(csv_file_path, header=None)

predicted_list = np.array(df[0].tolist())


import numpy as np
import matplotlib.pyplot as plt


mse = np.mean((logclose_test - predicted_list) ** 2)

plt.figure()
plt.plot(logclose_test, label='Real Log Close') 
plt.plot(predicted_list, 'r', label='Log Close Forecasts')  
plt.title('ARIMA-t Forecasts on Test Data', fontsize=24)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Value', fontsize=20)
legend = plt.legend(loc='best', fontsize=14)
legend.get_frame().set_facecolor('white')
legend.get_frame().set_edgecolor('black')
plt.text(0, 3.07, f'MSE: {mse:.6f}', fontsize=14, color='k',
         bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()
