# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_squared_error as mse

# %%
import pandas as pd

csv_file_path = 'close.csv'

df = pd.read_csv(csv_file_path, header=None)

close = df[0].tolist()
logclose = np.log(close).tolist()


plt.plot(close , color = 'r')
plt.show()

# %%
from math import floor

size = len(close) - 100
close_train, close_test = close[0:size], close[size:len(close)]
logclose_train, logclose_test = logclose[0:size], logclose[size:len(logclose)]

logreturns = np.diff(logclose).tolist()
logreturns_train, logreturns_test = logreturns[0:size-1], logreturns[size-1:len(logreturns)]

series = logreturns
train = logreturns_train
test = logreturns_test

plt.plot(series , color = 'r')
plt.show()

train = np.array(train).reshape(-1,1)

# %%
import numpy as np
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.svm import SVR
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
import hyperopt
import warnings


space = {
    "window_size": hp.choice("window_size", range(2,20)),
    "kernel": hp.choice("kernel", ["linear", "poly", "rbf"]),
    "C": hp.loguniform("C", np.log(0.001), np.log(100)),
    "epsilon": hp.loguniform("epsilon", np.log(0.00001), np.log(1)),
    "gamma": hp.choice("gamma", ["scale", "auto"]),
    "degree": hp.quniform("degree", 2, 4, 1),  
    "coef0": hp.uniform("coef0", -5, 5)      
}

def objective(params):
    window_size = params["window_size"]
    kernel = params["kernel"]
    C = params["C"]
    epsilon = params["epsilon"]

    scaler = StandardScaler()

    train_scaled = scaler.fit_transform(train)
    train_X, train_Y = [], []
    for i in range(len(train_scaled) - window_size):
        train_X.append(train_scaled[i:i+window_size])
        train_Y.append(train_scaled[i+window_size])
    new_train_X = np.array([x.reshape(-1) for x in train_X])
    new_train_Y = np.array(train_Y).ravel()

    svr_params = {"C": C, "epsilon": epsilon}
    
    if kernel == "poly":
        svr_params["gamma"] = params["gamma"]
        svr_params["degree"] = int(params["degree"]) 
        svr_params["coef0"] = (params["coef0"])   
    elif kernel == "rbf":
        svr_params["gamma"] = params["gamma"]

    model = SVR(kernel=kernel, **svr_params)

    tscv = TimeSeriesSplit(n_splits=2)
    score = np.mean(cross_val_score(model, new_train_X, new_train_Y, cv=tscv, scoring='neg_mean_squared_error', n_jobs=-1))
    
    return {"loss": -score, "status": STATUS_OK}

trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials,
            rstate=np.random.default_rng(42))

best_loss = trials.best_trial['result']['loss']
best_score = best_loss

print("\n------------------------")
print("BEST OVERALL RESULTS:")
print("------------------------")
print("Best parameters (raw indices and values):")
print(best)
print(f"Best score: {best_score:.4f}")
# Out:
# 100%|██████████| 100/100 [06:40<00:00,  4.00s/trial, best loss: 0.7798208726069027]
#
# ------------------------
# BEST OVERALL RESULTS:
# ------------------------
# Best parameters (raw indices and values):
# {'C': 0.0077044043263305665, 'coef0': -3.968086864195068, 'degree': 3.0, 'epsilon': 0.01085881101494941, 'gamma': 0, 'kernel': 2, 'window_size': 7}
# Best score: 0.7798

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.svm import SVR
import numpy as np

window_sizes = range(2,20)
kernels_list = ["linear", "poly", "rbf"]
gamma_list = ["scale", "auto"]

window_size = window_sizes[best["window_size"]]
best_kernel = kernels_list[best["kernel"]]
best_gamma = gamma_list[best["gamma"]]
best_C = best["C"]
best_epsilon = best["epsilon"]
best_degree = int(best["degree"]) if best_kernel == "poly" else None
best_coef0 = (best["coef0"]) if best_kernel == "poly" else None

scaler = StandardScaler()

train_scaled = scaler.fit_transform(train)
train_X, train_Y = [], []
for i in range(0, len(train_scaled) - window_size):
    train_X.append(train_scaled[i:i+window_size])
    train_Y.append(train_scaled[i+window_size])

new_train_X = np.array([x.reshape(-1) for x in train_X])
new_train_Y = np.array(train_Y).ravel()

svr_params = {"C": best_C, "epsilon": best_epsilon}
if best_kernel == "poly":
    svr_params["gamma"] = best_gamma
    svr_params["degree"] = best_degree
    svr_params["coef0"] = best_coef0
elif best_kernel == "rbf":
    svr_params["gamma"] = best_gamma

model = SVR(kernel=best_kernel, **svr_params)

model.fit(new_train_X, new_train_Y)
# Out:
# SVR(C=0.0077044043263305665, epsilon=0.01085881101494941)

# %%
print(window_size)
print(best_kernel)
print(best_gamma)
print(best_C)
print(best_epsilon)
print(best_degree)
print(best_coef0)
# Out:
# 9
# rbf
# scale
# 0.0077044043263305665
# 0.01085881101494941
# None
# None

# %%
predictions = model.predict(new_train_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))
Y = pd.DataFrame(train[window_size:])
pred = pd.DataFrame(predictions_rescaled)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()
error = mse(train[window_size:],predictions_rescaled)
print('Train MSE: %.6f' % error)
# Out:
# Train MSE: 0.000564

# %%
rawResiduals_SVR = Y - pred
plt.plot(rawResiduals_SVR)
plt.show()

rawResiduals_SVR.to_csv('rawResiduals_SVR_BO-TPE_standardscaler.csv', index=False)

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox

lags=np.ceil(np.log(len(rawResiduals_SVR)))

plt.figure(figsize=(10, 5))
plot_acf(rawResiduals_SVR, lags=lags, alpha=0.05)
plt.title('Autocorrelation Function (ACF)')
plt.show()

plt.figure(figsize=(10, 5))
plot_pacf(rawResiduals_SVR, lags=lags, alpha=0.05, method='ywm')
plt.title('Partial Autocorrelation Function (PACF)')
plt.show()

lbq_test = acorr_ljungbox(rawResiduals_SVR, lags=lags, return_df=True)
print(lbq_test)
# Out:
#      lb_stat  lb_pvalue
# 1   6.154398   0.013109
# 2   7.791384   0.020329
# 3   7.793903   0.050469
# 4   8.966120   0.061952
# 5  11.711659   0.038960
# 6  14.821682   0.021690
# 7  16.445997   0.021340
# 8  28.809387   0.000342
# 9  28.969300   0.000656

# %%
test_extended = train.tolist()[-1*window_size:] + test
test_data = []
for i in test_extended:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
test_data = np.array(test_data).reshape(-1,1)
test_scaled = scaler.transform(test_data)
test_X,test_Y = [],[]
for i in range(0 , len(test_scaled) - window_size):
    test_X.append(test_scaled[i:i+window_size])
    test_Y.append(test_scaled[i+window_size])
new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)
predictions = model.predict(new_test_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))
predictions_rescaled = predictions_rescaled.flatten().tolist()

Y = pd.DataFrame(test)
pred = pd.DataFrame(predictions_rescaled)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()
error = mse(test,predictions_rescaled)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000534

# %%
predicted_log_prices = np.zeros(len(logclose_test)) 
predicted_log_prices[0] = logclose_train[-1] + predictions_rescaled[0]

for t in range(1, len(logclose_test)):
    predicted_log_prices[t] = logclose_test[t-1] + predictions_rescaled[t] 


Y = pd.DataFrame(logclose_test)
pred = pd.DataFrame(predicted_log_prices)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()

error = mse(logclose_test,predicted_log_prices)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000534

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on logclose: ")
print(compute_error_metrics(logclose_test, predicted_log_prices))
print(compute_directional_metrics(logclose_test, predicted_log_prices))
# Out:
# Errors on logclose:
# {'NMSE': 0.09430626475172219, 'MAE': 0.014637103403499947, 'RMSE': 0.023107390972254362, 'MSE': 0.0005339515175446225, 'MAPE': 0.41277673438095536, 'TheilsU': 0.9991117051513515}
# {'DS': 0.494949494949495, 'CU': 0.5614035087719298, 'CD': 0.40476190476190477}

# %%
predicted_prices = np.exp(predicted_log_prices)
Y = pd.DataFrame(close_test)
pred = pd.DataFrame(predicted_prices)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()

error = mse(close_test,predicted_prices)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.658334

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on close: ")
print(compute_error_metrics(close_test, predicted_prices))
print(compute_directional_metrics(close_test, predicted_prices))
# Out:
# Errors on close:
# {'NMSE': 0.10744063186067097, 'MAE': 0.5062692930135487, 'RMSE': 0.8113778140029383, 'MSE': 0.6583339570561867, 'MAPE': 1.455027499100738, 'TheilsU': 0.9990445818441682}
# {'DS': 0.494949494949495, 'CU': 0.5614035087719298, 'CD': 0.40476190476190477}

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from trading_strategies import trading_strategy1

trading_strategy1(close_test, predicted_prices)
# Out:
# Stock: 28.09 Action: Buy Portfolio: 28090.0 Stocks: 1000 Balance_init: 0 total($) 28090.0
# Stock: 27.75 Action: Bought--Holding Portfolio: 27750.0 Stocks: 1000 Balance_init: 0 total($) 27750.0
# Stock: 27.94 Action: Bought--Holding Portfolio: 27940.0 Stocks: 1000 Balance_init: 0 total($) 27940.0
# Stock: 28.18 Action: Bought--Holding Portfolio: 28180.0 Stocks: 1000 Balance_init: 0 total($) 28180.0
# Stock: 28.42 Action: Bought--Holding Portfolio: 28420.0 Stocks: 1000 Balance_init: 0 total($) 28420.0
# Stock: 28.41 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28410.0
# Stock: 29.44 Action: Buy Portfolio: 28409.6 Stocks: 965 Balance_init: 0 total($) 28409.6
# Stock: 29.65 Action: Bought--Holding Portfolio: 28612.25 Stocks: 965 Balance_init: 0 total($) 28612.25
# Stock: 29.72 Action: Bought--Holding Portfolio: 28679.8 Stocks: 965 Balance_init: 0 total($) 28679.8
# Stock: 29.94 Action: Bought--Holding Portfolio: 28892.1 Stocks: 965 Balance_init: 0 total($) 28892.1
# Stock: 30.76 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29683.4
# Stock: 31.36 Action: Buy Portfolio: 29666.56 Stocks: 946 Balance_init: 16 total($) 29682.56
# Stock: 31.07 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29408.22
# Stock: 31.19 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29408.22
# Stock: 31.82 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29408.22
# Stock: 32.69 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29408.22
# Stock: 33.01 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29408.22
# Stock: 32.65 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29408.22
# Stock: 32.75 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29408.22
# Stock: 33.14 Action: Buy Portfolio: 29395.18 Stocks: 887 Balance_init: 13 total($) 29408.18
# Stock: 32.8 Action: Bought--Holding Portfolio: 29093.6 Stocks: 887 Balance_init: 13 total($) 29106.6
# Stock: 38.36 Action: Bought--Holding Portfolio: 34025.32 Stocks: 887 Balance_init: 13 total($) 34038.32
# Stock: 36.5 Action: Bought--Holding Portfolio: 32375.5 Stocks: 887 Balance_init: 13 total($) 32388.5
# Stock: 35.32 Action: Bought--Holding Portfolio: 31328.84 Stocks: 887 Balance_init: 13 total($) 31341.84
# Stock: 35.35 Action: Bought--Holding Portfolio: 31355.45 Stocks: 887 Balance_init: 13 total($) 31368.45
# Stock: 35.63 Action: Bought--Holding Portfolio: 31603.81 Stocks: 887 Balance_init: 13 total($) 31616.81
# Stock: 36.18 Action: Bought--Holding Portfolio: 32091.66 Stocks: 887 Balance_init: 13 total($) 32104.66
# Stock: 36.45 Action: Bought--Holding Portfolio: 32331.15 Stocks: 887 Balance_init: 13 total($) 32344.15
# Stock: 36.18 Action: Bought--Holding Portfolio: 32091.66 Stocks: 887 Balance_init: 13 total($) 32104.66
# Stock: 36.32 Action: Bought--Holding Portfolio: 32215.84 Stocks: 887 Balance_init: 13 total($) 32228.84
# Stock: 36.3 Action: Bought--Holding Portfolio: 32198.1 Stocks: 887 Balance_init: 13 total($) 32211.1
# Stock: 36.45 Action: Bought--Holding Portfolio: 32331.15 Stocks: 887 Balance_init: 13 total($) 32344.15
# Stock: 35.51 Action: Bought--Holding Portfolio: 31497.37 Stocks: 887 Balance_init: 13 total($) 31510.37
# Stock: 35.93 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31882.91
# Stock: 36.75 Action: Buy Portfolio: 31862.25 Stocks: 867 Balance_init: 20 total($) 31882.25
# Stock: 36.24 Action: Bought--Holding Portfolio: 31420.08 Stocks: 867 Balance_init: 20 total($) 31440.08
# Stock: 36.37 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31552.79
# Stock: 36.3 Action: Buy Portfolio: 31544.7 Stocks: 869 Balance_init: 8 total($) 31552.7
# Stock: 36.27 Action: Bought--Holding Portfolio: 31518.63 Stocks: 869 Balance_init: 8 total($) 31526.63
# Stock: 35.09 Action: Bought--Holding Portfolio: 30493.21 Stocks: 869 Balance_init: 8 total($) 30501.21
# Stock: 34.71 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30170.99
# Stock: 35.02 Action: Buy Portfolio: 30152.22 Stocks: 861 Balance_init: 18 total($) 30170.22
# Stock: 34.97 Action: Bought--Holding Portfolio: 30109.17 Stocks: 861 Balance_init: 18 total($) 30127.17
# Stock: 34.8 Action: Bought--Holding Portfolio: 29962.8 Stocks: 861 Balance_init: 18 total($) 29980.8
# Stock: 34.85 Action: Bought--Holding Portfolio: 30005.85 Stocks: 861 Balance_init: 18 total($) 30023.85
# Stock: 34.63 Action: Bought--Holding Portfolio: 29816.43 Stocks: 861 Balance_init: 18 total($) 29834.43
# Stock: 35.32 Action: Bought--Holding Portfolio: 30410.52 Stocks: 861 Balance_init: 18 total($) 30428.52
# Stock: 35.42 Action: Bought--Holding Portfolio: 30496.62 Stocks: 861 Balance_init: 18 total($) 30514.62
# Stock: 36.07 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31074.27
# Stock: 36.1 Action: Buy Portfolio: 31046.0 Stocks: 860 Balance_init: 28 total($) 31074.0
# Stock: 36.73 Action: Bought--Holding Portfolio: 31587.8 Stocks: 860 Balance_init: 28 total($) 31615.8
# Stock: 37.34 Action: Bought--Holding Portfolio: 32112.4 Stocks: 860 Balance_init: 28 total($) 32140.4
# Stock: 38.0 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32708.0
# Stock: 38.11 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32708.0
# Stock: 37.38 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32708.0
# Stock: 37.15 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32708.0
# Stock: 38.02 Action: Buy Portfolio: 32697.2 Stocks: 860 Balance_init: 10 total($) 32707.2
# Stock: 37.71 Action: Bought--Holding Portfolio: 32430.6 Stocks: 860 Balance_init: 10 total($) 32440.6
# Stock: 37.82 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32535.2
# Stock: 36.25 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32535.2
# Stock: 36.34 Action: Buy Portfolio: 32524.3 Stocks: 895 Balance_init: 10 total($) 32534.3
# Stock: 36.13 Action: Bought--Holding Portfolio: 32336.35 Stocks: 895 Balance_init: 10 total($) 32346.35
# Stock: 35.52 Action: Bought--Holding Portfolio: 31790.4 Stocks: 895 Balance_init: 10 total($) 31800.4
# Stock: 36.09 Action: Bought--Holding Portfolio: 32300.55 Stocks: 895 Balance_init: 10 total($) 32310.55
# Stock: 35.17 Action: Bought--Holding Portfolio: 31477.15 Stocks: 895 Balance_init: 10 total($) 31487.15
# Stock: 33.72 Action: Bought--Holding Portfolio: 30179.4 Stocks: 895 Balance_init: 10 total($) 30189.4
# Stock: 32.75 Action: Bought--Holding Portfolio: 29311.25 Stocks: 895 Balance_init: 10 total($) 29321.25
# Stock: 32.72 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29294.4
# Stock: 32.02 Action: Buy Portfolio: 29266.28 Stocks: 914 Balance_init: 28 total($) 29294.28
# Stock: 33.02 Action: Bought--Holding Portfolio: 30180.28 Stocks: 914 Balance_init: 28 total($) 30208.28
# Stock: 33.54 Action: Bought--Holding Portfolio: 30655.56 Stocks: 914 Balance_init: 28 total($) 30683.56
# Stock: 33.78 Action: Bought--Holding Portfolio: 30874.92 Stocks: 914 Balance_init: 28 total($) 30902.92
# Stock: 34.76 Action: Bought--Holding Portfolio: 31770.64 Stocks: 914 Balance_init: 28 total($) 31798.64
# Stock: 34.75 Action: Bought--Holding Portfolio: 31761.5 Stocks: 914 Balance_init: 28 total($) 31789.5
# Stock: 35.49 Action: Bought--Holding Portfolio: 32437.86 Stocks: 914 Balance_init: 28 total($) 32465.86
# Stock: 35.91 Action: Bought--Holding Portfolio: 32821.74 Stocks: 914 Balance_init: 28 total($) 32849.74
# Stock: 34.6 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31652.4
# Stock: 34.81 Action: Buy Portfolio: 31642.29 Stocks: 909 Balance_init: 10 total($) 31652.29
# Stock: 35.27 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32070.43
# Stock: 35.08 Action: Buy Portfolio: 32063.12 Stocks: 914 Balance_init: 7 total($) 32070.12
# Stock: 35.66 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32600.24
# Stock: 35.57 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32600.24
# Stock: 35.6 Action: Buy Portfolio: 32574.0 Stocks: 915 Balance_init: 26 total($) 32600.0
# Stock: 34.76 Action: Bought--Holding Portfolio: 31805.4 Stocks: 915 Balance_init: 26 total($) 31831.4
# Stock: 35.46 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32471.9
# Stock: 36.18 Action: Buy Portfolio: 32453.46 Stocks: 897 Balance_init: 18 total($) 32471.46
# Stock: 35.38 Action: Bought--Holding Portfolio: 31735.86 Stocks: 897 Balance_init: 18 total($) 31753.86
# Stock: 35.33 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31709.01
# Stock: 34.4 Action: Buy Portfolio: 31682.4 Stocks: 921 Balance_init: 26 total($) 31708.4
# Stock: 33.82 Action: Bought--Holding Portfolio: 31148.22 Stocks: 921 Balance_init: 26 total($) 31174.22
# Stock: 34.18 Action: Bought--Holding Portfolio: 31479.78 Stocks: 921 Balance_init: 26 total($) 31505.78
# Stock: 33.47 Action: Bought--Holding Portfolio: 30825.87 Stocks: 921 Balance_init: 26 total($) 30851.87
# Stock: 33.37 Action: Bought--Holding Portfolio: 30733.77 Stocks: 921 Balance_init: 26 total($) 30759.77
# Stock: 33.1 Action: Bought--Holding Portfolio: 30485.1 Stocks: 921 Balance_init: 26 total($) 30511.1
# Stock: 33.32 Action: Bought--Holding Portfolio: 30687.72 Stocks: 921 Balance_init: 26 total($) 30713.72
# Stock: 33.76 Action: Bought--Holding Portfolio: 31092.96 Stocks: 921 Balance_init: 26 total($) 31118.96
# Stock: 34.43 Action: Bought--Holding Portfolio: 31710.03 Stocks: 921 Balance_init: 26 total($) 31736.03
# Stock: 34.53 Action: Bought--Holding Portfolio: 31802.13 Stocks: 921 Balance_init: 26 total($) 31828.13
# Stock: 34.82 Action: Bought--Holding Portfolio: 32069.22 Stocks: 921 Balance_init: 26 total($) 32095.22
# Final value of stock:
# 34.76
# Final value of portfolio:
# 32095.0
