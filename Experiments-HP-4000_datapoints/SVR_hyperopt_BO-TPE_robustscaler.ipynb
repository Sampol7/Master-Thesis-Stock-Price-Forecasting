# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_squared_error as mse

# %%
import pandas as pd

csv_file_path = 'close.csv'

df = pd.read_csv(csv_file_path, header=None)

close = df[0].tolist()
logclose = np.log(close).tolist()


plt.plot(close , color = 'r')
plt.show()

# %%
from math import floor

size = len(close) - 100
close_train, close_test = close[0:size], close[size:len(close)]
logclose_train, logclose_test = logclose[0:size], logclose[size:len(logclose)]

logreturns = np.diff(logclose).tolist()
logreturns_train, logreturns_test = logreturns[0:size-1], logreturns[size-1:len(logreturns)]

series = logreturns
train = logreturns_train
test = logreturns_test

plt.plot(series , color = 'r')
plt.show()

train = np.array(train).reshape(-1,1)

# %%
import numpy as np
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.svm import SVR
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
import hyperopt
import warnings


space = {
    "window_size": hp.choice("window_size", range(2,20)),
    "kernel": hp.choice("kernel", ["linear", "poly", "rbf"]),
    "C": hp.loguniform("C", np.log(0.001), np.log(100)),
    "epsilon": hp.loguniform("epsilon", np.log(0.00001), np.log(1)),
    "gamma": hp.choice("gamma", ["scale", "auto"]),
    "degree": hp.quniform("degree", 2, 4, 1),  
    "coef0": hp.uniform("coef0", -5, 5)      
}

def objective(params):
    window_size = params["window_size"]
    kernel = params["kernel"]
    C = params["C"]
    epsilon = params["epsilon"]

    scaler = RobustScaler()

    train_scaled = scaler.fit_transform(train)
    train_X, train_Y = [], []
    for i in range(len(train_scaled) - window_size):
        train_X.append(train_scaled[i:i+window_size])
        train_Y.append(train_scaled[i+window_size])
    new_train_X = np.array([x.reshape(-1) for x in train_X])
    new_train_Y = np.array(train_Y).ravel()

    svr_params = {"C": C, "epsilon": epsilon}
    
    if kernel == "poly":
        svr_params["gamma"] = params["gamma"]
        svr_params["degree"] = int(params["degree"]) 
        svr_params["coef0"] = (params["coef0"])     
    elif kernel == "rbf":
        svr_params["gamma"] = params["gamma"]

    model = SVR(kernel=kernel, **svr_params)

    tscv = TimeSeriesSplit(n_splits=2)
    score = np.mean(cross_val_score(model, new_train_X, new_train_Y, cv=tscv, scoring='neg_mean_squared_error', n_jobs=-1))
    
    return {"loss": -score, "status": STATUS_OK}

trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials,
            rstate=np.random.default_rng(42))

best_loss = trials.best_trial['result']['loss']
best_score = best_loss

print("\n------------------------")
print("BEST OVERALL RESULTS:")
print("------------------------")
print("Best parameters (raw indices and values):")
print(best)
print(f"Best score: {best_score:.4f}")
# Out:
# 100%|██████████| 100/100 [03:53<00:00,  2.34s/trial, best loss: 1.1412469840473323]
#
# ------------------------
# BEST OVERALL RESULTS:
# ------------------------
# Best parameters (raw indices and values):
# {'C': 8.442894410883781, 'coef0': 3.7553038477828626, 'degree': 4.0, 'epsilon': 0.8713878505194068, 'gamma': 1, 'kernel': 0, 'window_size': 1}
# Best score: 1.1412

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.svm import SVR
import numpy as np

window_sizes = range(2,20)
kernels_list = ["linear", "poly", "rbf"]
gamma_list = ["scale", "auto"]

window_size = window_sizes[best["window_size"]]
best_kernel = kernels_list[best["kernel"]]
best_gamma = gamma_list[best["gamma"]]
best_C = best["C"]
best_epsilon = best["epsilon"]
best_degree = int(best["degree"]) if best_kernel == "poly" else None
best_coef0 = (best["coef0"]) if best_kernel == "poly" else None

scaler = RobustScaler()

train_scaled = scaler.fit_transform(train)
train_X, train_Y = [], []
for i in range(0, len(train_scaled) - window_size):
    train_X.append(train_scaled[i:i+window_size])
    train_Y.append(train_scaled[i+window_size])

new_train_X = np.array([x.reshape(-1) for x in train_X])
new_train_Y = np.array(train_Y).ravel()

svr_params = {"C": best_C, "epsilon": best_epsilon}
if best_kernel == "poly":
    svr_params["gamma"] = best_gamma
    svr_params["degree"] = best_degree
    svr_params["coef0"] = best_coef0
elif best_kernel == "rbf":
    svr_params["gamma"] = best_gamma

model = SVR(kernel=best_kernel, **svr_params)

model.fit(new_train_X, new_train_Y)
# Out:
# SVR(C=8.442894410883781, epsilon=0.8713878505194068, kernel='linear')

# %%
print(window_size)
print(best_kernel)
print(best_gamma)
print(best_C)
print(best_epsilon)
print(best_degree)
print(best_coef0)
# Out:
# 3
# linear
# auto
# 8.442894410883781
# 0.8713878505194068
# None
# None

# %%
predictions = model.predict(new_train_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))
Y = pd.DataFrame(train[window_size:])
pred = pd.DataFrame(predictions_rescaled)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()
error = mse(train[window_size:],predictions_rescaled)
print('Train MSE: %.6f' % error)
# Out:
# Train MSE: 0.000475

# %%
rawResiduals_SVR = Y - pred
plt.plot(rawResiduals_SVR)
plt.show()

rawResiduals_SVR.to_csv('rawResiduals_SVR_BO-TPE_robustscaler.csv', index=False)

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox

lags=np.ceil(np.log(len(rawResiduals_SVR)))

plt.figure(figsize=(10, 5))
plot_acf(rawResiduals_SVR, lags=lags, alpha=0.05)
plt.title('Autocorrelation Function (ACF)')
plt.show()

plt.figure(figsize=(10, 5))
plot_pacf(rawResiduals_SVR, lags=lags, alpha=0.05, method='ywm')
plt.title('Partial Autocorrelation Function (PACF)')
plt.show()

lbq_test = acorr_ljungbox(rawResiduals_SVR, lags=lags, return_df=True)
print(lbq_test)
# Out:
#      lb_stat  lb_pvalue
# 1   0.652650   0.419167
# 2   1.128688   0.568733
# 3   4.977976   0.173417
# 4   5.854653   0.210269
# 5  11.202755   0.047505
# 6  16.129928   0.013073
# 7  19.606342   0.006486
# 8  35.119082   0.000025
# 9  35.913934   0.000041

# %%
test_extended = train.tolist()[-1*window_size:] + test
test_data = []
for i in test_extended:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
test_data = np.array(test_data).reshape(-1,1)
test_scaled = scaler.transform(test_data)
test_X,test_Y = [],[]
for i in range(0 , len(test_scaled) - window_size):
    test_X.append(test_scaled[i:i+window_size])
    test_Y.append(test_scaled[i+window_size])
new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)
predictions = model.predict(new_test_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))
predictions_rescaled = predictions_rescaled.flatten().tolist()

Y = pd.DataFrame(test)
pred = pd.DataFrame(predictions_rescaled)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()
error = mse(test,predictions_rescaled)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000531

# %%
predicted_log_prices = np.zeros(len(logclose_test)) 
predicted_log_prices[0] = logclose_train[-1] + predictions_rescaled[0]

for t in range(1, len(logclose_test)):
    predicted_log_prices[t] = logclose_test[t-1] + predictions_rescaled[t] 


Y = pd.DataFrame(logclose_test)
pred = pd.DataFrame(predicted_log_prices)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()

error = mse(logclose_test,predicted_log_prices)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000531

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on logclose: ")
print(compute_error_metrics(logclose_test, predicted_log_prices))
print(compute_directional_metrics(logclose_test, predicted_log_prices))
# Out:
# Errors on logclose:
# {'NMSE': 0.093866935844774, 'MAE': 0.014658498356108019, 'RMSE': 0.02305350486232455, 'MSE': 0.0005314640864372217, 'MAPE': 0.41342354218364225, 'TheilsU': 0.9970973794977788}
# {'DA': 0.47474747474747475, 'DS': 0.5454545454545454, 'CU': 0.6140350877192983, 'CD': 0.4523809523809524}

# %%
predicted_prices = np.exp(predicted_log_prices)
Y = pd.DataFrame(close_test)
pred = pd.DataFrame(predicted_prices)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()

error = mse(close_test,predicted_prices)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.654153

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on close: ")
print(compute_error_metrics(close_test, predicted_prices))
print(compute_directional_metrics(close_test, predicted_prices))
# Out:
# Errors on close:
# {'NMSE': 0.10675831545071009, 'MAE': 0.5067767526508574, 'RMSE': 0.8087973277204412, 'MSE': 0.6541531173277267, 'MAPE': 1.4570688906639488, 'TheilsU': 0.9969031681956855}
# {'DA': 0.47474747474747475, 'DS': 0.5454545454545454, 'CU': 0.6140350877192983, 'CD': 0.4523809523809524}

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from trading_strategies import trading_strategy1

trading_strategy1(close_test, predicted_prices)
# Out:
# Stock: 28.09 Action: Buy Portfolio: 28090.0 Stocks: 1000 Balance_init: 0 total($) 28090.0
# Stock: 27.75 Action: Bought--Holding Portfolio: 27750.0 Stocks: 1000 Balance_init: 0 total($) 27750.0
# Stock: 27.94 Action: Bought--Holding Portfolio: 27940.0 Stocks: 1000 Balance_init: 0 total($) 27940.0
# Stock: 28.18 Action: Bought--Holding Portfolio: 28180.0 Stocks: 1000 Balance_init: 0 total($) 28180.0
# Stock: 28.42 Action: Bought--Holding Portfolio: 28420.0 Stocks: 1000 Balance_init: 0 total($) 28420.0
# Stock: 28.41 Action: Bought--Holding Portfolio: 28410.0 Stocks: 1000 Balance_init: 0 total($) 28410.0
# Stock: 29.44 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29440.0
# Stock: 29.65 Action: Buy Portfolio: 29412.8 Stocks: 992 Balance_init: 27 total($) 29439.8
# Stock: 29.72 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29509.24
# Stock: 29.94 Action: Buy Portfolio: 29490.9 Stocks: 985 Balance_init: 18 total($) 29508.9
# Stock: 30.76 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30316.6
# Stock: 31.36 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30316.6
# Stock: 31.07 Action: Buy Portfolio: 30293.25 Stocks: 975 Balance_init: 23 total($) 30316.25
# Stock: 31.19 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30433.25
# Stock: 31.82 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30433.25
# Stock: 32.69 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30433.25
# Stock: 33.01 Action: Buy Portfolio: 30402.21 Stocks: 921 Balance_init: 31 total($) 30433.21
# Stock: 32.65 Action: Bought--Holding Portfolio: 30070.65 Stocks: 921 Balance_init: 31 total($) 30101.65
# Stock: 32.75 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30193.75
# Stock: 33.14 Action: Buy Portfolio: 30190.54 Stocks: 911 Balance_init: 3 total($) 30193.54
# Stock: 32.8 Action: Bought--Holding Portfolio: 29880.8 Stocks: 911 Balance_init: 3 total($) 29883.8
# Stock: 38.36 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34948.96
# Stock: 36.5 Action: Buy Portfolio: 34930.5 Stocks: 957 Balance_init: 18 total($) 34948.5
# Stock: 35.32 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33819.24
# Stock: 35.35 Action: Buy Portfolio: 33794.6 Stocks: 956 Balance_init: 24 total($) 33818.6
# Stock: 35.63 Action: Bought--Holding Portfolio: 34062.28 Stocks: 956 Balance_init: 24 total($) 34086.28
# Stock: 36.18 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34612.08
# Stock: 36.45 Action: Buy Portfolio: 34591.05 Stocks: 949 Balance_init: 21 total($) 34612.05
# Stock: 36.18 Action: Bought--Holding Portfolio: 34334.82 Stocks: 949 Balance_init: 21 total($) 34355.82
# Stock: 36.32 Action: Bought--Holding Portfolio: 34467.68 Stocks: 949 Balance_init: 21 total($) 34488.68
# Stock: 36.3 Action: Bought--Holding Portfolio: 34448.7 Stocks: 949 Balance_init: 21 total($) 34469.7
# Stock: 36.45 Action: Bought--Holding Portfolio: 34591.05 Stocks: 949 Balance_init: 21 total($) 34612.05
# Stock: 35.51 Action: Bought--Holding Portfolio: 33698.99 Stocks: 949 Balance_init: 21 total($) 33719.99
# Stock: 35.93 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34118.57
# Stock: 36.75 Action: Buy Portfolio: 34104.0 Stocks: 928 Balance_init: 14 total($) 34118.0
# Stock: 36.24 Action: Bought--Holding Portfolio: 33630.72 Stocks: 928 Balance_init: 14 total($) 33644.72
# Stock: 36.37 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33765.36
# Stock: 36.3 Action: Buy Portfolio: 33759.0 Stocks: 930 Balance_init: 6 total($) 33765.0
# Stock: 36.27 Action: Bought--Holding Portfolio: 33731.1 Stocks: 930 Balance_init: 6 total($) 33737.1
# Stock: 35.09 Action: Bought--Holding Portfolio: 32633.7 Stocks: 930 Balance_init: 6 total($) 32639.7
# Stock: 34.71 Action: Bought--Holding Portfolio: 32280.3 Stocks: 930 Balance_init: 6 total($) 32286.3
# Stock: 35.02 Action: Bought--Holding Portfolio: 32568.6 Stocks: 930 Balance_init: 6 total($) 32574.6
# Stock: 34.97 Action: Bought--Holding Portfolio: 32522.1 Stocks: 930 Balance_init: 6 total($) 32528.1
# Stock: 34.8 Action: Bought--Holding Portfolio: 32364.0 Stocks: 930 Balance_init: 6 total($) 32370.0
# Stock: 34.85 Action: Bought--Holding Portfolio: 32410.5 Stocks: 930 Balance_init: 6 total($) 32416.5
# Stock: 34.63 Action: Bought--Holding Portfolio: 32205.9 Stocks: 930 Balance_init: 6 total($) 32211.9
# Stock: 35.32 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32853.6
# Stock: 35.42 Action: Buy Portfolio: 32834.34 Stocks: 927 Balance_init: 19 total($) 32853.34
# Stock: 36.07 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33455.89
# Stock: 36.1 Action: Buy Portfolio: 33428.6 Stocks: 926 Balance_init: 27 total($) 33455.6
# Stock: 36.73 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34038.98
# Stock: 37.34 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34038.98
# Stock: 38.0 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34038.98
# Stock: 38.11 Action: Buy Portfolio: 34032.23 Stocks: 893 Balance_init: 6 total($) 34038.23
# Stock: 37.38 Action: Bought--Holding Portfolio: 33380.34 Stocks: 893 Balance_init: 6 total($) 33386.34
# Stock: 37.15 Action: Bought--Holding Portfolio: 33174.95 Stocks: 893 Balance_init: 6 total($) 33180.95
# Stock: 38.02 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33957.86
# Stock: 37.71 Action: Buy Portfolio: 33939.0 Stocks: 900 Balance_init: 18 total($) 33957.0
# Stock: 37.82 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34056.0
# Stock: 36.25 Action: Buy Portfolio: 34038.75 Stocks: 939 Balance_init: 17 total($) 34055.75
# Stock: 36.34 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34140.26
# Stock: 36.13 Action: Buy Portfolio: 34106.72 Stocks: 944 Balance_init: 33 total($) 34139.72
# Stock: 35.52 Action: Bought--Holding Portfolio: 33530.88 Stocks: 944 Balance_init: 33 total($) 33563.88
# Stock: 36.09 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34101.96
# Stock: 35.17 Action: Buy Portfolio: 34079.73 Stocks: 969 Balance_init: 22 total($) 34101.73
# Stock: 33.72 Action: Bought--Holding Portfolio: 32674.68 Stocks: 969 Balance_init: 22 total($) 32696.68
# Stock: 32.75 Action: Bought--Holding Portfolio: 31734.75 Stocks: 969 Balance_init: 22 total($) 31756.75
# Stock: 32.72 Action: Bought--Holding Portfolio: 31705.68 Stocks: 969 Balance_init: 22 total($) 31727.68
# Stock: 32.02 Action: Bought--Holding Portfolio: 31027.38 Stocks: 969 Balance_init: 22 total($) 31049.38
# Stock: 33.02 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32018.38
# Stock: 33.54 Action: Buy Portfolio: 31997.16 Stocks: 954 Balance_init: 21 total($) 32018.16
# Stock: 33.78 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32247.12
# Stock: 34.76 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32247.12
# Stock: 34.75 Action: Buy Portfolio: 32213.25 Stocks: 927 Balance_init: 33 total($) 32246.25
# Stock: 35.49 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32932.23
# Stock: 35.91 Action: Buy Portfolio: 32929.47 Stocks: 917 Balance_init: 2 total($) 32931.47
# Stock: 34.6 Action: Bought--Holding Portfolio: 31728.2 Stocks: 917 Balance_init: 2 total($) 31730.2
# Stock: 34.81 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31922.77
# Stock: 35.27 Action: Buy Portfolio: 31919.35 Stocks: 905 Balance_init: 3 total($) 31922.35
# Stock: 35.08 Action: Bought--Holding Portfolio: 31747.4 Stocks: 905 Balance_init: 3 total($) 31750.4
# Stock: 35.66 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32275.3
# Stock: 35.57 Action: Buy Portfolio: 32261.99 Stocks: 907 Balance_init: 13 total($) 32274.99
# Stock: 35.6 Action: Bought--Holding Portfolio: 32289.2 Stocks: 907 Balance_init: 13 total($) 32302.2
# Stock: 34.76 Action: Bought--Holding Portfolio: 31527.32 Stocks: 907 Balance_init: 13 total($) 31540.32
# Stock: 35.46 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32175.22
# Stock: 36.18 Action: Buy Portfolio: 32164.02 Stocks: 889 Balance_init: 11 total($) 32175.02
# Stock: 35.38 Action: Bought--Holding Portfolio: 31452.82 Stocks: 889 Balance_init: 11 total($) 31463.82
# Stock: 35.33 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31419.37
# Stock: 34.4 Action: Buy Portfolio: 31407.2 Stocks: 913 Balance_init: 12 total($) 31419.2
# Stock: 33.82 Action: Bought--Holding Portfolio: 30877.66 Stocks: 913 Balance_init: 12 total($) 30889.66
# Stock: 34.18 Action: Bought--Holding Portfolio: 31206.34 Stocks: 913 Balance_init: 12 total($) 31218.34
# Stock: 33.47 Action: Bought--Holding Portfolio: 30558.11 Stocks: 913 Balance_init: 12 total($) 30570.11
# Stock: 33.37 Action: Bought--Holding Portfolio: 30466.81 Stocks: 913 Balance_init: 12 total($) 30478.81
# Stock: 33.1 Action: Bought--Holding Portfolio: 30220.3 Stocks: 913 Balance_init: 12 total($) 30232.3
# Stock: 33.32 Action: Bought--Holding Portfolio: 30421.16 Stocks: 913 Balance_init: 12 total($) 30433.16
# Stock: 33.76 Action: Bought--Holding Portfolio: 30822.88 Stocks: 913 Balance_init: 12 total($) 30834.88
# Stock: 34.43 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31446.59
# Stock: 34.53 Action: Buy Portfolio: 31422.3 Stocks: 910 Balance_init: 24 total($) 31446.3
# Stock: 34.82 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31710.2
# Final value of stock:
# 34760.0
# Final value of portfolio:
# 31710.0
# TS=
# 0.9122554660529344
