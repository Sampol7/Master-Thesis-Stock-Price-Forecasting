# %%
import os
import random
import numpy as np
import pandas as pd
import tensorflow as tf


random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.graphics.api import qqplot
from sklearn.metrics import mean_squared_error as mse
from tensorflow.keras.optimizers import SGD

# %matplotlib inline

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from sklearn import preprocessing
from tensorflow.keras.layers import LSTM

# %%
import pandas as pd

csv_file_path = 'close.csv'

df = pd.read_csv(csv_file_path, header=None)

close = df[0].tolist()
logclose = np.log(close).tolist()


plt.plot(close , color = 'r')
plt.show()

# %%
from math import floor

size = len(close)-100
close_train, close_test = close[0:size], close[size:len(close)]
logclose_train, logclose_test = logclose[0:size], logclose[size:len(logclose)]

logreturns = np.diff(logclose).tolist()
logreturns_train, logreturns_test = logreturns[0:size-1], logreturns[size-1:len(logreturns)]

series = logreturns
train = logreturns_train
test = logreturns_test

plt.plot(series , color = 'r')
plt.show()

train = np.array(train).reshape(-1,1)

# %%
import numpy as np
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.preprocessing import StandardScaler, RobustScaler
from scikeras.wrappers import KerasRegressor
from tensorflow.keras.callbacks import EarlyStopping
import warnings

warnings.filterwarnings("ignore")

def make_model(num_layers, neurons, activation, initializer, optimizer, dropout_rate, window_size):
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Dense, Dropout
    model = Sequential()
    model.add(Dense(neurons[0], input_dim=window_size, kernel_initializer=initializer, activation=activation))
    model.add(Dropout(dropout_rate))
    for i in range(1, num_layers):
        model.add(Dense(neurons[i], kernel_initializer=initializer, activation=activation))
        model.add(Dropout(dropout_rate))
    model.add(Dense(1, activation='linear'))
    model.compile(loss='mean_squared_error', optimizer=optimizer)
    return model

space = {
    "window_size": hp.choice("window_size", list(range(2, 20))), 
    "num_layers_choice": hp.choice("num_layers_choice", [
         { 
             "num_layers": 1,
             "neurons": hp.quniform("neurons_1", 2, 299, 1)
         }
    ]),
    "activation": hp.choice("activation", ["sigmoid", "tanh", "relu", "elu"]),
    "initializer": hp.choice("initializer", ["uniform", "glorot_uniform", "he_uniform"]),
    "optimizer": hp.choice("optimizer", ["adam", "sgd", "rmsprop"]),
    "dropout_rate": hp.uniform("dropout_rate", 0.0, 0.5),
    "batch_size": hp.quniform("batch_size", 8, 128, 1)
}
    
    
def objective(params):
    
    window_size = params["window_size"]

    scaler = RobustScaler()
    train_scaled = scaler.fit_transform(train)

    arch = params["num_layers_choice"]
    if arch["num_layers"] == 1:
        num_layers = 1
        neurons = [int(arch["neurons"])]
    if arch["num_layers"] == 2:
        num_layers = 2
        neurons = [int(arch["neurons1"]), int(arch["neurons2"])]
    if arch["num_layers"] == 3:
        num_layers = 3
        neurons = [int(arch["neurons1"]), int(arch["neurons2"]), int(arch["neurons3"])]
    
    
    activation = params["activation"]
    initializer = params["initializer"]
    optimizer_param = params["optimizer"]
    dropout_rate = params["dropout_rate"]
    batch_size = int(params["batch_size"])
    
    train_X, train_Y = [], []
    for i in range(len(train_scaled) - window_size):
        train_X.append(train_scaled[i:i+window_size])
        train_Y.append(train_scaled[i+window_size])
    new_train_X = np.array([x.reshape(-1) for x in train_X])
    new_train_Y = np.array(train_Y).ravel()
    
    callbacks = [EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)]
    epochs = 2000
    validation_split = 0.10
    
    modelKeras = KerasRegressor(
        model=make_model,
        window_size=window_size,
        model__num_layers=num_layers,
        model__neurons=neurons,
        model__activation=activation,
        model__initializer=initializer,
        model__optimizer=optimizer_param,
        model__dropout_rate=dropout_rate,
        batch_size=batch_size,
        epochs=epochs,
        validation_split=validation_split,
        callbacks=callbacks,
        shuffle=False,  
        random_state=42,    
        verbose=0
    )
    
    tscv = TimeSeriesSplit(n_splits=2)
    score = np.mean(cross_val_score(modelKeras, new_train_X, new_train_Y, cv=tscv, scoring='neg_mean_squared_error', n_jobs=-1))

    print(f"Params: {params}, Score: {score:.4f}")

    return {"loss": -score, "status": STATUS_OK}


trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials,
            rstate=np.random.default_rng(42))

best_loss = trials.best_trial['result']['loss']
best_score = best_loss

print("\n------------------------")
print("BEST OVERALL RESULTS:")
print("------------------------")
print("Raw best parameters (indices/values):")
print(best)
print(f"Best score: {best_score:.4f}")
# Out:
# Params: {'activation': 'elu', 'batch_size': 100.0, 'dropout_rate': 0.32587119987444696, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 186.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1432
# Params: {'activation': 'elu', 'batch_size': 76.0, 'dropout_rate': 0.029968094540700263, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 183.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 17}, Score: -1.2385
# Params: {'activation': 'relu', 'batch_size': 77.0, 'dropout_rate': 0.07858985028094856, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 24.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 4}, Score: -1.1458
# Params: {'activation': 'relu', 'batch_size': 17.0, 'dropout_rate': 0.35223000813752336, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 65.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 13}, Score: -1.1688
# Params: {'activation': 'tanh', 'batch_size': 49.0, 'dropout_rate': 0.17305929881725102, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 31.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 7}, Score: -1.1533
# Params: {'activation': 'tanh', 'batch_size': 117.0, 'dropout_rate': 0.36157396222211435, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 50.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 15}, Score: -1.1440
# Params: {'activation': 'sigmoid', 'batch_size': 69.0, 'dropout_rate': 0.434677958142653, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 298.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 15}, Score: -1.1527
# Params: {'activation': 'relu', 'batch_size': 25.0, 'dropout_rate': 0.16848986962255413, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 249.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 10}, Score: -1.1502
# Params: {'activation': 'sigmoid', 'batch_size': 127.0, 'dropout_rate': 0.28673048470873264, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 231.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1420
# Params: {'activation': 'tanh', 'batch_size': 86.0, 'dropout_rate': 0.35206702845306526, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 145.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 18}, Score: -1.2055
# Params: {'activation': 'tanh', 'batch_size': 122.0, 'dropout_rate': 0.4773902233445454, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 14.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 3}, Score: -1.1582
# Params: {'activation': 'sigmoid', 'batch_size': 39.0, 'dropout_rate': 0.15390229944946937, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 183.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 18}, Score: -1.1644
# Params: {'activation': 'relu', 'batch_size': 105.0, 'dropout_rate': 0.10843483792853714, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 219.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 8}, Score: -1.1441
# Params: {'activation': 'sigmoid', 'batch_size': 99.0, 'dropout_rate': 0.4410499053490562, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 141.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 14}, Score: -1.1474
# Params: {'activation': 'sigmoid', 'batch_size': 21.0, 'dropout_rate': 0.4869739733232261, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 271.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 11}, Score: -1.1466
# Params: {'activation': 'sigmoid', 'batch_size': 111.0, 'dropout_rate': 0.16743004719404048, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 295.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 5}, Score: -1.1878
# Params: {'activation': 'elu', 'batch_size': 45.0, 'dropout_rate': 0.2258128479235475, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 244.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 14}, Score: -1.1583
# Params: {'activation': 'tanh', 'batch_size': 26.0, 'dropout_rate': 0.4882626520810925, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 33.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 12}, Score: -1.1596
# Params: {'activation': 'sigmoid', 'batch_size': 50.0, 'dropout_rate': 0.2085813440926868, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 254.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 19}, Score: -1.1588
# Params: {'activation': 'elu', 'batch_size': 39.0, 'dropout_rate': 0.1149178980045017, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 214.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 5}, Score: -1.3396
# Params: {'activation': 'elu', 'batch_size': 127.0, 'dropout_rate': 0.27225254183888425, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 106.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1426
# Params: {'activation': 'elu', 'batch_size': 127.0, 'dropout_rate': 0.2846627250440074, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 93.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1426
# Params: {'activation': 'elu', 'batch_size': 128.0, 'dropout_rate': 0.2643739138340197, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 110.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1445
# Params: {'activation': 'elu', 'batch_size': 91.0, 'dropout_rate': 0.30224433435898346, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 107.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 6}, Score: -1.1529
# Params: {'activation': 'sigmoid', 'batch_size': 118.0, 'dropout_rate': 0.4018137281040942, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 80.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1422
# Params: {'activation': 'sigmoid', 'batch_size': 114.0, 'dropout_rate': 0.40418611340986443, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 69.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 9}, Score: -1.1461
# Params: {'activation': 'sigmoid', 'batch_size': 94.0, 'dropout_rate': 0.3967982129419533, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 162.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 16}, Score: -1.1550
# Params: {'activation': 'sigmoid', 'batch_size': 106.0, 'dropout_rate': 0.3903843045093334, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 215.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1449
# Params: {'activation': 'sigmoid', 'batch_size': 117.0, 'dropout_rate': 0.3145384778726582, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 125.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1416
# Params: {'activation': 'sigmoid', 'batch_size': 62.0, 'dropout_rate': 0.3270182057395526, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 156.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 17}, Score: -1.1544
# Params: {'activation': 'sigmoid', 'batch_size': 84.0, 'dropout_rate': 0.22985541426015033, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 130.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 12}, Score: -1.1531
# Params: {'activation': 'sigmoid', 'batch_size': 104.0, 'dropout_rate': 0.3129348686993436, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 196.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 4}, Score: -1.1436
# Params: {'activation': 'relu', 'batch_size': 77.0, 'dropout_rate': 0.023423900137783227, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 171.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 13}, Score: -1.2019
# Params: {'activation': 'sigmoid', 'batch_size': 58.0, 'dropout_rate': 0.2077298926601922, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 128.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 7}, Score: -1.1504
# Params: {'activation': 'relu', 'batch_size': 123.0, 'dropout_rate': 0.24490348397394546, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 277.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 11}, Score: -1.3282
# Params: {'activation': 'sigmoid', 'batch_size': 8.0, 'dropout_rate': 0.06461637987980473, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 195.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 8}, Score: -1.1539
# Params: {'activation': 'tanh', 'batch_size': 109.0, 'dropout_rate': 0.3497442765663858, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 223.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 10}, Score: -1.1512
# Params: {'activation': 'sigmoid', 'batch_size': 71.0, 'dropout_rate': 0.4433473822030126, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 53.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 3}, Score: -1.1459
# Params: {'activation': 'relu', 'batch_size': 80.0, 'dropout_rate': 0.1372171373794241, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 170.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 9}, Score: -1.1468
# Params: {'activation': 'tanh', 'batch_size': 97.0, 'dropout_rate': 0.19294795819780522, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 238.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 19}, Score: -1.1952
# Params: {'activation': 'sigmoid', 'batch_size': 89.0, 'dropout_rate': 0.32925974107702877, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 283.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 15}, Score: -1.1752
# Params: {'activation': 'sigmoid', 'batch_size': 120.0, 'dropout_rate': 0.36541802128358214, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 128.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 6}, Score: -1.1509
# Params: {'activation': 'relu', 'batch_size': 114.0, 'dropout_rate': 0.29738171204550523, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 202.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 16}, Score: -1.2009
# Params: {'activation': 'tanh', 'batch_size': 101.0, 'dropout_rate': 0.46096491849729027, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 259.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1448
# Params: {'activation': 'sigmoid', 'batch_size': 123.0, 'dropout_rate': 0.06564335244254069, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 179.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 18}, Score: -1.1513
# Params: {'activation': 'sigmoid', 'batch_size': 64.0, 'dropout_rate': 0.2433413883853499, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 229.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 13}, Score: -1.1508
# Params: {'activation': 'relu', 'batch_size': 110.0, 'dropout_rate': 0.3793011560938413, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 8.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 4}, Score: -1.1496
# Params: {'activation': 'tanh', 'batch_size': 72.0, 'dropout_rate': 0.0004005310929280359, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 141.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 7}, Score: -1.2131
# Params: {'activation': 'sigmoid', 'batch_size': 33.0, 'dropout_rate': 0.4234070272913811, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 39.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 17}, Score: -1.1491
# Params: {'activation': 'sigmoid', 'batch_size': 10.0, 'dropout_rate': 0.1877099702389486, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 262.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 2}, Score: -1.1728
# Params: {'activation': 'elu', 'batch_size': 83.0, 'dropout_rate': 0.3434402697704405, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 96.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 10}, Score: -1.1502
# Params: {'activation': 'sigmoid', 'batch_size': 55.0, 'dropout_rate': 0.2667917820155447, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 296.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 14}, Score: -1.1794
# Params: {'activation': 'tanh', 'batch_size': 116.0, 'dropout_rate': 0.14302293712953626, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 203.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 5}, Score: -1.1582
# Params: {'activation': 'elu', 'batch_size': 128.0, 'dropout_rate': 0.11692634426126003, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 115.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 3}, Score: -1.1436
# Params: {'activation': 'sigmoid', 'batch_size': 96.0, 'dropout_rate': 0.28209332057119674, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 80.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1434
# Params: {'activation': 'relu', 'batch_size': 102.0, 'dropout_rate': 0.371345891323382, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 149.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 8}, Score: -1.1640
# Params: {'activation': 'sigmoid', 'batch_size': 88.0, 'dropout_rate': 0.4668665566265222, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 233.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 15}, Score: -1.1502
# Params: {'activation': 'elu', 'batch_size': 92.0, 'dropout_rate': 0.09197721822346602, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 21.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 11}, Score: -1.1612
# Params: {'activation': 'sigmoid', 'batch_size': 125.0, 'dropout_rate': 0.4226182733313707, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 63.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 12}, Score: -1.1458
# Params: {'activation': 'tanh', 'batch_size': 15.0, 'dropout_rate': 0.3106669159122875, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 245.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 2}, Score: -1.1425
# Params: {'activation': 'sigmoid', 'batch_size': 108.0, 'dropout_rate': 0.2281525662605635, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 190.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 18}, Score: -1.1550
# Params: {'activation': 'sigmoid', 'batch_size': 47.0, 'dropout_rate': 0.4996287657156995, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 159.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 19}, Score: -1.1584
# Params: {'activation': 'elu', 'batch_size': 113.0, 'dropout_rate': 0.25926468458688046, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 122.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 16}, Score: -1.2032
# Params: {'activation': 'relu', 'batch_size': 118.0, 'dropout_rate': 0.17307606712435672, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 287.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 6}, Score: -1.1529
# Params: {'activation': 'sigmoid', 'batch_size': 67.0, 'dropout_rate': 0.3275164578120384, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 99.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 9}, Score: -1.1436
# Params: {'activation': 'sigmoid', 'batch_size': 120.0, 'dropout_rate': 0.38731703292874065, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 71.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1445
# Params: {'activation': 'sigmoid', 'batch_size': 106.0, 'dropout_rate': 0.4170407229578187, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 80.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1441
# Params: {'activation': 'sigmoid', 'batch_size': 98.0, 'dropout_rate': 0.2893746086241145, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 46.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1429
# Params: {'activation': 'sigmoid', 'batch_size': 128.0, 'dropout_rate': 0.3414095486415016, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 137.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1420
# Params: {'activation': 'sigmoid', 'batch_size': 126.0, 'dropout_rate': 0.35128620526395915, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 177.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1431
# Params: {'activation': 'sigmoid', 'batch_size': 122.0, 'dropout_rate': 0.2069188097106431, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 137.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 14}, Score: -1.1618
# Params: {'activation': 'sigmoid', 'batch_size': 112.0, 'dropout_rate': 0.3362217432746535, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 116.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 5}, Score: -1.1471
# Params: {'activation': 'sigmoid', 'batch_size': 104.0, 'dropout_rate': 0.3142441907382976, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 152.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 4}, Score: -1.1451
# Params: {'activation': 'sigmoid', 'batch_size': 117.0, 'dropout_rate': 0.27670567922788214, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 89.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 17}, Score: -1.1507
# Params: {'activation': 'sigmoid', 'batch_size': 94.0, 'dropout_rate': 0.2415411785787454, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 166.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 13}, Score: -1.1544
# Params: {'activation': 'tanh', 'batch_size': 79.0, 'dropout_rate': 0.44378382130646965, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 184.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 7}, Score: -1.1531
# Params: {'activation': 'relu', 'batch_size': 128.0, 'dropout_rate': 0.25832147716287107, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 206.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1437
# Params: {'activation': 'sigmoid', 'batch_size': 74.0, 'dropout_rate': 0.298480838080785, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 134.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 10}, Score: -1.1683
# Params: {'activation': 'elu', 'batch_size': 123.0, 'dropout_rate': 0.2150871043616437, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 103.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 8}, Score: -1.1454
# Params: {'activation': 'sigmoid', 'batch_size': 108.0, 'dropout_rate': 0.3598024902471108, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 211.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 3}, Score: -1.1439
# Params: {'activation': 'sigmoid', 'batch_size': 101.0, 'dropout_rate': 0.3102750005495543, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 90.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 12}, Score: -1.1478
# Params: {'activation': 'tanh', 'batch_size': 39.0, 'dropout_rate': 0.4058619681468873, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 144.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 11}, Score: -1.1641
# Params: {'activation': 'sigmoid', 'batch_size': 115.0, 'dropout_rate': 0.31953331434479, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 59.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1558
# Params: {'activation': 'relu', 'batch_size': 121.0, 'dropout_rate': 0.37275606275592177, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 123.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 9}, Score: -1.1667
# Params: {'activation': 'elu', 'batch_size': 111.0, 'dropout_rate': 0.1892601225185434, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 191.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 15}, Score: -1.1535
# Params: {'activation': 'sigmoid', 'batch_size': 84.0, 'dropout_rate': 0.45293868946591465, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 220.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 18}, Score: -1.1531
# Params: {'activation': 'sigmoid', 'batch_size': 54.0, 'dropout_rate': 0.3409057245279797, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 270.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 19}, Score: -1.1670
# Params: {'activation': 'sigmoid', 'batch_size': 125.0, 'dropout_rate': 0.2898589002559769, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 113.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 6}, Score: -1.1494
# Params: {'activation': 'tanh', 'batch_size': 89.0, 'dropout_rate': 0.3863795450166159, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 154.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1451
# Params: {'activation': 'relu', 'batch_size': 119.0, 'dropout_rate': 0.4793576066535742, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 172.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 16}, Score: -1.1520
# Params: {'activation': 'sigmoid', 'batch_size': 104.0, 'dropout_rate': 0.1631908165929642, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 164.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 17}, Score: -1.1580
# Params: {'activation': 'elu', 'batch_size': 22.0, 'dropout_rate': 0.2388993507230815, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 226.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 13}, Score: -1.1565
# Params: {'activation': 'sigmoid', 'batch_size': 99.0, 'dropout_rate': 0.35931053740179486, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 135.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 14}, Score: -1.1465
# Params: {'activation': 'sigmoid', 'batch_size': 95.0, 'dropout_rate': 0.4129173657327462, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 73.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1453
# Params: {'activation': 'tanh', 'batch_size': 43.0, 'dropout_rate': 0.27130276940129944, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 238.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 5}, Score: -1.1509
# Params: {'activation': 'sigmoid', 'batch_size': 32.0, 'dropout_rate': 0.25299963123974456, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 178.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 4}, Score: -1.1502
# Params: {'activation': 'relu', 'batch_size': 115.0, 'dropout_rate': 0.21692522906942918, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 28.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 7}, Score: -1.1651
# Params: {'activation': 'sigmoid', 'batch_size': 62.0, 'dropout_rate': 0.1272257538334987, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 120.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 10}, Score: -1.1493
# Params: {'activation': 'elu', 'batch_size': 125.0, 'dropout_rate': 0.17984982600617772, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 149.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1419
# Params: {'activation': 'elu', 'batch_size': 87.0, 'dropout_rate': 0.03976986945109559, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 149.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 3}, Score: -1.1638
# 100%|██████████| 100/100 [03:16<00:00,  1.96s/trial, best loss: 1.141591254391635]
#
# ------------------------
# BEST OVERALL RESULTS:
# ------------------------
# Raw best parameters (indices/values):
# {'activation': 0, 'batch_size': 117.0, 'dropout_rate': 0.3145384778726582, 'initializer': 1, 'neurons_1': 125.0, 'num_layers_choice': 0, 'optimizer': 2, 'window_size': 0}
# Best score: 1.1416

# %%
window_size_values = []
neuron_values = []
losses = []

for trial in trials.trials:
    losses.append(trial['result']['loss'])
    
plt.figure(figsize=(8, 6))
plt.plot(losses, marker='o', linestyle='-', color='b')
plt.xlabel('Sample Index')
plt.ylabel('Loss')
plt.ylim([0.75, 1.85])
plt.grid(True)
plt.text(0.1, 0.95, f'Mean Loss: {np.mean(losses):.4f}', transform=plt.gca().transAxes, fontsize=10, bbox=dict(facecolor='white', alpha=0.5))
plt.text(0.1, 0.89, f'Minimal Loss: {np.min(losses):.4f}', transform=plt.gca().transAxes, fontsize=10, bbox=dict(facecolor='white', alpha=0.5))
close_to_min = int(np.sum(np.abs(losses - np.min(losses)) <= 0.1))
plt.text(0.1, 0.83, f'Close to Minimum: {close_to_min}', transform=plt.gca().transAxes, fontsize=10, bbox=dict(facecolor='white', alpha=0.5))
plt.show()
    
    
print('Mean loss across all trails:')
print(np.mean(losses))
# Out:
# Mean loss across all trails:
# 1.1596776113570164

# %%
window_sizes = list(range(2, 20))
activations_list = ["sigmoid", "tanh", "relu", "elu"]
initializers_list = ["uniform", "glorot_uniform", "he_uniform"]
optimizers_list = ["adam", "sgd", "rmsprop"]

best_window_size = window_sizes[ best["window_size"] ]
best_activation = activations_list[ best["activation"] ]
best_initializer = initializers_list[ best["initializer"] ]
best_optimizer = optimizers_list[ best["optimizer"] ]
best_dropout_rate = best["dropout_rate"]
best_batch_size = int(best["batch_size"])

if best["num_layers_choice"] == 0:
    best_num_layers = 1
    best_neurons = [int(best["neurons_1"])]
if best["num_layers_choice"] == 1:
    best_num_layers = 2
    best_neurons = [int(best["neurons_2_1"]), int(best["neurons_2_2"])]
if best["num_layers_choice"] == 2:
    best_num_layers = 3
    best_neurons = [int(best["neurons_3_1"]), int(best["neurons_3_2"]), int(best["neurons_3_3"])]


scaler = RobustScaler()
train_scaled = scaler.fit_transform(train)

train_X, train_Y = [], []
for i in range(0, len(train_scaled) - best_window_size):
    train_X.append(train_scaled[i:i+best_window_size])
    train_Y.append(train_scaled[i+best_window_size])
new_train_X = np.array([x.reshape(-1) for x in train_X])
new_train_Y = np.array(train_Y).ravel()


final_model = make_model(
    num_layers=best_num_layers,
    neurons=best_neurons,
    activation=best_activation,
    initializer=best_initializer,
    optimizer=best_optimizer,
    dropout_rate=best_dropout_rate,
    window_size=best_window_size
)

fit = final_model.fit(new_train_X, new_train_Y,
                batch_size=best_batch_size,
                epochs=2000,
                validation_split=0.10,
                callbacks=[EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)],
                shuffle=False,  
                verbose=1)
# Out:
# Epoch 1/2000
# 30/30 [==============================] - 1s 9ms/step - loss: 1.5161 - val_loss: 0.7178
# Epoch 2/2000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.5157 - val_loss: 0.7199
# Epoch 3/2000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.4698 - val_loss: 0.7253
# Epoch 4/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4683 - val_loss: 0.7182
# Epoch 5/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4393 - val_loss: 0.7184
# Epoch 6/2000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.4285 - val_loss: 0.7222
# Epoch 7/2000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.3791 - val_loss: 0.7218
# Epoch 8/2000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.3986 - val_loss: 0.7228
# Epoch 9/2000
# 30/30 [==============================] - 0s 7ms/step - loss: 1.3614 - val_loss: 0.7203
# Epoch 10/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3755 - val_loss: 0.7201
# Epoch 11/2000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3656 - val_loss: 0.7207

# %%
print(best_window_size)
print(best_activation)
print(best_initializer)
print(best_optimizer)
print(best_dropout_rate)
print(best_batch_size) 
print(best_neurons)
# Out:
# 2
# sigmoid
# glorot_uniform
# rmsprop
# 0.3145384778726582
# 117
# [125]

# %%
window_size = best_window_size
model = final_model

# %%
predictions = model.predict(new_train_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))
Y = pd.DataFrame(train[window_size:])
pred = pd.DataFrame(predictions_rescaled)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()
error = mse(train[window_size:],predictions_rescaled)
print('Train MSE: %.6f' % error)
# Out:
# 122/122 [==============================] - 0s 574us/step
# Train MSE: 0.000476

# %%
rawResiduals_FNN = Y - pred
plt.plot(rawResiduals_FNN)
plt.show()

rawResiduals_FNN.to_csv('rawResiduals_FNN_BO-TPE_robustscaler.csv', index=False)

# %%
test_extended = train.tolist()[-1*window_size:] + test
test_data = []
for i in test_extended:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
test_data = np.array(test_data).reshape(-1,1)
test_scaled = scaler.transform(test_data)
test_X,test_Y = [],[]
for i in range(0 , len(test_scaled) - window_size):
    test_X.append(test_scaled[i:i+window_size])
    test_Y.append(test_scaled[i+window_size])
new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)


predictions = model.predict(new_test_X)
predictions_rescaled=scaler.inverse_transform(predictions)
predictions_rescaled = predictions_rescaled.flatten().tolist()

Y = pd.DataFrame(test)
pred = pd.DataFrame(predictions_rescaled)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()
error = mse(test,predictions_rescaled)
print('Test MSE: %.6f' % error)
# Out:
# 4/4 [==============================] - 0s 4ms/step
# Test MSE: 0.000536

# %%
predicted_log_prices = np.zeros(len(logclose_test)) 
predicted_log_prices[0] = logclose_train[-1] + predictions_rescaled[0]

for t in range(1, len(logclose_test)):
    predicted_log_prices[t] = logclose_test[t-1] + predictions_rescaled[t] 


Y = pd.DataFrame(logclose_test)
pred = pd.DataFrame(predicted_log_prices)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()

error = mse(logclose_test,predicted_log_prices)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000536

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on logclose: ")
print(compute_error_metrics(logclose_test, predicted_log_prices))
print(compute_directional_metrics(logclose_test, predicted_log_prices))
# Out:
# Errors on logclose:
# {'NMSE': 0.09464478544125862, 'MAE': 0.014755975164478335, 'RMSE': 0.023148826834337156, 'MSE': 0.000535868183806128, 'MAPE': 0.4161641623922688, 'TheilsU': 1.0017112682244762}
# {'DS': 0.5050505050505051, 'CU': 0.5789473684210527, 'CD': 0.40476190476190477}

# %%
predicted_prices = np.exp(predicted_log_prices)
Y = pd.DataFrame(close_test)
pred = pd.DataFrame(predicted_prices)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()

error = mse(close_test,predicted_prices)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.658426

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on close: ")
print(compute_error_metrics(close_test, predicted_prices))
print(compute_directional_metrics(close_test, predicted_prices))
# Out:
# Errors on close:
# {'NMSE': 0.10745566096480638, 'MAE': 0.5096566775761139, 'RMSE': 0.8114345609479053, 'MSE': 0.6584260467007199, 'MAPE': 1.4651240363014348, 'TheilsU': 1.0013785483537883}
# {'DS': 0.5050505050505051, 'CU': 0.5789473684210527, 'CD': 0.40476190476190477}

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from trading_strategies import trading_strategy1

trading_strategy1(close_test, predicted_prices)
# Out:
# Stock: 28.09 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 27.75 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 27.94 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 28.18 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 28.42 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 28.41 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 29.44 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 29.65 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 29.72 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 29.94 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 30.76 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 31.36 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 31.07 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 31.19 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 31.82 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 32.69 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 33.01 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 32.65 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 32.75 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 33.14 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 32.8 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 38.36 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28090.0
# Stock: 36.5 Action: Buy Portfolio: 28068.5 Stocks: 769 Balance_init: 21 total($) 28089.5
# Stock: 35.32 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27182.08
# Stock: 35.35 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27182.08
# Stock: 35.63 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27182.08
# Stock: 36.18 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27182.08
# Stock: 36.45 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27182.08
# Stock: 36.18 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27182.08
# Stock: 36.32 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27182.08
# Stock: 36.3 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27182.08
# Stock: 36.45 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27182.08
# Stock: 35.51 Action: Buy Portfolio: 27165.15 Stocks: 765 Balance_init: 16 total($) 27181.15
# Stock: 35.93 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27502.45
# Stock: 36.75 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27502.45
# Stock: 36.24 Action: Buy Portfolio: 27469.92 Stocks: 758 Balance_init: 32 total($) 27501.92
# Stock: 36.37 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27600.46
# Stock: 36.3 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27600.46
# Stock: 36.27 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27600.46
# Stock: 35.09 Action: Buy Portfolio: 27580.74 Stocks: 786 Balance_init: 19 total($) 27599.74
# Stock: 34.71 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 35.02 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 34.97 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 34.8 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 34.85 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 34.63 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 35.32 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 35.42 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 36.07 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 36.1 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 36.73 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 37.34 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 38.0 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 38.11 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 37.38 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 37.15 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 38.02 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 37.71 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 37.82 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27301.06
# Stock: 36.25 Action: Buy Portfolio: 27296.25 Stocks: 753 Balance_init: 4 total($) 27300.25
# Stock: 36.34 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27368.02
# Stock: 36.13 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27368.02
# Stock: 35.52 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27368.02
# Stock: 36.09 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27368.02
# Stock: 35.17 Action: Buy Portfolio: 27362.26 Stocks: 778 Balance_init: 5 total($) 27367.26
# Stock: 33.72 Action: Bought--Holding Portfolio: 26234.16 Stocks: 778 Balance_init: 5 total($) 26239.16
# Stock: 32.75 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 25484.5
# Stock: 32.72 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 25484.5
# Stock: 32.02 Action: Buy Portfolio: 25455.9 Stocks: 795 Balance_init: 28 total($) 25483.9
# Stock: 33.02 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26278.9
# Stock: 33.54 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26278.9
# Stock: 33.78 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26278.9
# Stock: 34.76 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26278.9
# Stock: 34.75 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26278.9
# Stock: 35.49 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26278.9
# Stock: 35.91 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26278.9
# Stock: 34.6 Action: Buy Portfolio: 26261.4 Stocks: 759 Balance_init: 17 total($) 26278.4
# Stock: 34.81 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26437.79
# Stock: 35.27 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26437.79
# Stock: 35.08 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26437.79
# Stock: 35.66 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26437.79
# Stock: 35.57 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26437.79
# Stock: 35.6 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26437.79
# Stock: 34.76 Action: Buy Portfolio: 26417.6 Stocks: 760 Balance_init: 20 total($) 26437.6
# Stock: 35.46 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26969.6
# Stock: 36.18 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26969.6
# Stock: 35.38 Action: Buy Portfolio: 26959.56 Stocks: 762 Balance_init: 10 total($) 26969.56
# Stock: 35.33 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26931.46
# Stock: 34.4 Action: Buy Portfolio: 26900.8 Stocks: 782 Balance_init: 30 total($) 26930.8
# Stock: 33.82 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26477.24
# Stock: 34.18 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26477.24
# Stock: 33.47 Action: Buy Portfolio: 26474.77 Stocks: 791 Balance_init: 2 total($) 26476.77
# Stock: 33.37 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26397.67
# Stock: 33.1 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26397.67
# Stock: 33.32 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26397.67
# Stock: 33.76 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26397.67
# Stock: 34.43 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26397.67
# Stock: 34.53 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26397.67
# Stock: 34.82 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26397.67
# Final value of stock:
# 34.76
# Final value of portfolio:
# 26398.0
