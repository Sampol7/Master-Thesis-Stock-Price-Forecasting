# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_squared_error as mse

# %%
import pandas as pd

csv_file_path = 'close.csv'

df = pd.read_csv(csv_file_path, header=None)

close = df[0].tolist()
logclose = np.log(close).tolist()


plt.plot(close , color = 'r')
plt.show()

# %%
from math import floor

size = len(close) - 100
close_train, close_test = close[0:size], close[size:len(close)]
logclose_train, logclose_test = logclose[0:size], logclose[size:len(logclose)]

logreturns = np.diff(logclose).tolist()
logreturns_train, logreturns_test = logreturns[0:size-1], logreturns[size-1:len(logreturns)]

series = logreturns
train = logreturns_train
test = logreturns_test

plt.plot(series , color = 'r')
plt.show()

train = np.array(train).reshape(-1,1)

# %%
import numpy as np
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.svm import SVR
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
import hyperopt
import warnings


space = {
    "window_size": hp.choice("window_size", range(2,20)),
    "kernel": hp.choice("kernel", ["linear", "poly", "rbf"]),
    "C": hp.loguniform("C", np.log(0.001), np.log(100)),
    "epsilon": hp.loguniform("epsilon", np.log(0.00001), np.log(1)),
    "gamma": hp.choice("gamma", ["scale", "auto"]),
    "degree": hp.quniform("degree", 2, 4, 1),  
    "coef0": hp.uniform("coef0", -5, 5)      
}

def objective(params):
    window_size = params["window_size"]
    kernel = params["kernel"]
    C = params["C"]
    epsilon = params["epsilon"]

    scaler = StandardScaler()

    train_scaled = scaler.fit_transform(train)
    train_X, train_Y = [], []
    for i in range(len(train_scaled) - window_size):
        train_X.append(train_scaled[i:i+window_size])
        train_Y.append(train_scaled[i+window_size])
    new_train_X = np.array([x.reshape(-1) for x in train_X])
    new_train_Y = np.array(train_Y).ravel()

    svr_params = {"C": C, "epsilon": epsilon}
    
    if kernel == "poly":
        svr_params["gamma"] = params["gamma"]
        svr_params["degree"] = int(params["degree"]) 
        svr_params["coef0"] = (params["coef0"])   
    elif kernel == "rbf":
        svr_params["gamma"] = params["gamma"]

    model = SVR(kernel=kernel, **svr_params)

    tscv = TimeSeriesSplit(n_splits=2)
    score = np.mean(cross_val_score(model, new_train_X, new_train_Y, cv=tscv, scoring='neg_mean_squared_error', n_jobs=-1))
    
    return {"loss": -score, "status": STATUS_OK}

trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials,
            rstate=np.random.default_rng(42))

best_loss = trials.best_trial['result']['loss']
best_score = best_loss

print("\n------------------------")
print("BEST OVERALL RESULTS:")
print("------------------------")
print("Best parameters (raw indices and values):")
print(best)
print(f"Best score: {best_score:.4f}")
# Out:
#   0%|          | 0/100 [00:00<?, ?trial/s, best loss=?]
# 100%|██████████| 100/100 [01:44<00:00,  1.05s/trial, best loss: 0.9316728821868538]
#
# ------------------------
# BEST OVERALL RESULTS:
# ------------------------
# Best parameters (raw indices and values):
# {'C': 0.010733063648202482, 'coef0': 2.5848083849347487, 'degree': 3.0, 'epsilon': 6.11070198193271e-05, 'gamma': 0, 'kernel': 2, 'window_size': 3}
# Best score: 0.9317

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.svm import SVR
import numpy as np

window_sizes = range(2,20)
kernels_list = ["linear", "poly", "rbf"]
gamma_list = ["scale", "auto"]

window_size = window_sizes[best["window_size"]]
best_kernel = kernels_list[best["kernel"]]
best_gamma = gamma_list[best["gamma"]]
best_C = best["C"]
best_epsilon = best["epsilon"]
best_degree = int(best["degree"]) if best_kernel == "poly" else None
best_coef0 = (best["coef0"]) if best_kernel == "poly" else None

scaler = StandardScaler()

train_scaled = scaler.fit_transform(train)
train_X, train_Y = [], []
for i in range(0, len(train_scaled) - window_size):
    train_X.append(train_scaled[i:i+window_size])
    train_Y.append(train_scaled[i+window_size])

new_train_X = np.array([x.reshape(-1) for x in train_X])
new_train_Y = np.array(train_Y).ravel()

svr_params = {"C": best_C, "epsilon": best_epsilon}
if best_kernel == "poly":
    svr_params["gamma"] = best_gamma
    svr_params["degree"] = best_degree
    svr_params["coef0"] = best_coef0
elif best_kernel == "rbf":
    svr_params["gamma"] = best_gamma

model = SVR(kernel=best_kernel, **svr_params)

model.fit(new_train_X, new_train_Y)
# Out:
# SVR(C=0.010733063648202482, epsilon=6.11070198193271e-05)

# %%
print(window_size)
print(best_kernel)
print(best_gamma)
print(best_C)
print(best_epsilon)
print(best_degree)
print(best_coef0)
# Out:
# 5
# rbf
# scale
# 0.010733063648202482
# 6.11070198193271e-05
# None
# None

# %%
predictions = model.predict(new_train_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))
Y = pd.DataFrame(train[window_size:])
pred = pd.DataFrame(predictions_rescaled)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()
error = mse(train[window_size:],predictions_rescaled)
print('Train MSE: %.6f' % error)
# Out:
# Train MSE: 0.000473

# %%
rawResiduals_SVR = Y - pred
plt.plot(rawResiduals_SVR)
plt.show()

rawResiduals_SVR.to_csv('rawResiduals_SVR_BO-TPE_standardscaler.csv', index=False)

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox

lags=np.ceil(np.log(len(rawResiduals_SVR)))

plt.figure(figsize=(10, 5))
plot_acf(rawResiduals_SVR, lags=lags, alpha=0.05)
plt.title('Autocorrelation Function (ACF)')
plt.show()

plt.figure(figsize=(10, 5))
plot_pacf(rawResiduals_SVR, lags=lags, alpha=0.05, method='ywm')
plt.title('Partial Autocorrelation Function (PACF)')
plt.show()

lbq_test = acorr_ljungbox(rawResiduals_SVR, lags=lags, return_df=True)
print(lbq_test)
# Out:
#      lb_stat  lb_pvalue
# 1   5.199505   0.022593
# 2   8.129227   0.017170
# 3   8.772466   0.032474
# 4   9.595275   0.047826
# 5  12.786160   0.025467
# 6  18.599008   0.004897
# 7  22.769083   0.001870
# 8  39.765982   0.000004
# 9  41.347638   0.000004

# %%
test_extended = train.tolist()[-1*window_size:] + test
test_data = []
for i in test_extended:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
test_data = np.array(test_data).reshape(-1,1)
test_scaled = scaler.transform(test_data)
test_X,test_Y = [],[]
for i in range(0 , len(test_scaled) - window_size):
    test_X.append(test_scaled[i:i+window_size])
    test_Y.append(test_scaled[i+window_size])
new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)
predictions = model.predict(new_test_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))
predictions_rescaled = predictions_rescaled.flatten().tolist()

Y = pd.DataFrame(test)
pred = pd.DataFrame(predictions_rescaled)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()
error = mse(test,predictions_rescaled)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000530

# %%
predicted_log_prices = np.zeros(len(logclose_test)) 
predicted_log_prices[0] = logclose_train[-1] + predictions_rescaled[0]

for t in range(1, len(logclose_test)):
    predicted_log_prices[t] = logclose_test[t-1] + predictions_rescaled[t] 


Y = pd.DataFrame(logclose_test)
pred = pd.DataFrame(predicted_log_prices)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()

error = mse(logclose_test,predicted_log_prices)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000530

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on logclose: ")
print(compute_error_metrics(logclose_test, predicted_log_prices))
print(compute_directional_metrics(logclose_test, predicted_log_prices))
# Out:
# Errors on logclose:
# {'NMSE': 0.09366914759957068, 'MAE': 0.014524739783153526, 'RMSE': 0.023029203883909263, 'MSE': 0.0005303442315266615, 'MAPE': 0.4095624133018365, 'TheilsU': 0.9953958832188132}
# {'DA': 0.5454545454545454, 'DS': 0.5151515151515151, 'CU': 0.5789473684210527, 'CD': 0.42857142857142855}

# %%
predicted_prices = np.exp(predicted_log_prices)
Y = pd.DataFrame(close_test)
pred = pd.DataFrame(predicted_prices)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()

error = mse(close_test,predicted_prices)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.654998

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on close: ")
print(compute_error_metrics(close_test, predicted_prices))
print(compute_directional_metrics(close_test, predicted_prices))
# Out:
# Errors on close:
# {'NMSE': 0.1068962777642196, 'MAE': 0.5026812845028044, 'RMSE': 0.8093197578647411, 'MSE': 0.6549984704702431, 'MAPE': 1.444183101930225, 'TheilsU': 0.9956423387753884}
# {'DA': 0.5454545454545454, 'DS': 0.5151515151515151, 'CU': 0.5789473684210527, 'CD': 0.42857142857142855}

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from trading_strategies import trading_strategy1

trading_strategy1(close_test, predicted_prices)
# Out:
# Stock: 28.09 Action: Buy Portfolio: 28090.0 Stocks: 1000 Balance_init: 0 total($) 28090.0
# Stock: 27.75 Action: Bought--Holding Portfolio: 27750.0 Stocks: 1000 Balance_init: 0 total($) 27750.0
# Stock: 27.94 Action: Bought--Holding Portfolio: 27940.0 Stocks: 1000 Balance_init: 0 total($) 27940.0
# Stock: 28.18 Action: Bought--Holding Portfolio: 28180.0 Stocks: 1000 Balance_init: 0 total($) 28180.0
# Stock: 28.42 Action: Bought--Holding Portfolio: 28420.0 Stocks: 1000 Balance_init: 0 total($) 28420.0
# Stock: 28.41 Action: Bought--Holding Portfolio: 28410.0 Stocks: 1000 Balance_init: 0 total($) 28410.0
# Stock: 29.44 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29440.0
# Stock: 29.65 Action: Buy Portfolio: 29412.8 Stocks: 992 Balance_init: 27 total($) 29439.8
# Stock: 29.72 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29509.24
# Stock: 29.94 Action: Buy Portfolio: 29490.9 Stocks: 985 Balance_init: 18 total($) 29508.9
# Stock: 30.76 Action: Bought--Holding Portfolio: 30298.6 Stocks: 985 Balance_init: 18 total($) 30316.6
# Stock: 31.36 Action: Bought--Holding Portfolio: 30889.6 Stocks: 985 Balance_init: 18 total($) 30907.6
# Stock: 31.07 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30621.95
# Stock: 31.19 Action: Buy Portfolio: 30597.39 Stocks: 981 Balance_init: 24 total($) 30621.39
# Stock: 31.82 Action: Bought--Holding Portfolio: 31215.42 Stocks: 981 Balance_init: 24 total($) 31239.42
# Stock: 32.69 Action: Bought--Holding Portfolio: 32068.89 Stocks: 981 Balance_init: 24 total($) 32092.89
# Stock: 33.01 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32406.81
# Stock: 32.65 Action: Buy Portfolio: 32388.8 Stocks: 992 Balance_init: 18 total($) 32406.8
# Stock: 32.75 Action: Bought--Holding Portfolio: 32488.0 Stocks: 992 Balance_init: 18 total($) 32506.0
# Stock: 33.14 Action: Bought--Holding Portfolio: 32874.88 Stocks: 992 Balance_init: 18 total($) 32892.88
# Stock: 32.8 Action: Bought--Holding Portfolio: 32537.6 Stocks: 992 Balance_init: 18 total($) 32555.6
# Stock: 38.36 Action: Bought--Holding Portfolio: 38053.12 Stocks: 992 Balance_init: 18 total($) 38071.12
# Stock: 36.5 Action: Bought--Holding Portfolio: 36208.0 Stocks: 992 Balance_init: 18 total($) 36226.0
# Stock: 35.32 Action: Bought--Holding Portfolio: 35037.44 Stocks: 992 Balance_init: 18 total($) 35055.44
# Stock: 35.35 Action: Bought--Holding Portfolio: 35067.2 Stocks: 992 Balance_init: 18 total($) 35085.2
# Stock: 35.63 Action: Bought--Holding Portfolio: 35344.96 Stocks: 992 Balance_init: 18 total($) 35362.96
# Stock: 36.18 Action: Bought--Holding Portfolio: 35890.56 Stocks: 992 Balance_init: 18 total($) 35908.56
# Stock: 36.45 Action: Bought--Holding Portfolio: 36158.4 Stocks: 992 Balance_init: 18 total($) 36176.4
# Stock: 36.18 Action: Bought--Holding Portfolio: 35890.56 Stocks: 992 Balance_init: 18 total($) 35908.56
# Stock: 36.32 Action: Bought--Holding Portfolio: 36029.44 Stocks: 992 Balance_init: 18 total($) 36047.44
# Stock: 36.3 Action: Bought--Holding Portfolio: 36009.6 Stocks: 992 Balance_init: 18 total($) 36027.6
# Stock: 36.45 Action: Bought--Holding Portfolio: 36158.4 Stocks: 992 Balance_init: 18 total($) 36176.4
# Stock: 35.51 Action: Bought--Holding Portfolio: 35225.92 Stocks: 992 Balance_init: 18 total($) 35243.92
# Stock: 35.93 Action: Bought--Holding Portfolio: 35642.56 Stocks: 992 Balance_init: 18 total($) 35660.56
# Stock: 36.75 Action: Bought--Holding Portfolio: 36456.0 Stocks: 992 Balance_init: 18 total($) 36474.0
# Stock: 36.24 Action: Bought--Holding Portfolio: 35950.08 Stocks: 992 Balance_init: 18 total($) 35968.08
# Stock: 36.37 Action: Bought--Holding Portfolio: 36079.04 Stocks: 992 Balance_init: 18 total($) 36097.04
# Stock: 36.3 Action: Bought--Holding Portfolio: 36009.6 Stocks: 992 Balance_init: 18 total($) 36027.6
# Stock: 36.27 Action: Bought--Holding Portfolio: 35979.84 Stocks: 992 Balance_init: 18 total($) 35997.84
# Stock: 35.09 Action: Bought--Holding Portfolio: 34809.28 Stocks: 992 Balance_init: 18 total($) 34827.28
# Stock: 34.71 Action: Bought--Holding Portfolio: 34432.32 Stocks: 992 Balance_init: 18 total($) 34450.32
# Stock: 35.02 Action: Bought--Holding Portfolio: 34739.84 Stocks: 992 Balance_init: 18 total($) 34757.84
# Stock: 34.97 Action: Bought--Holding Portfolio: 34690.24 Stocks: 992 Balance_init: 18 total($) 34708.24
# Stock: 34.8 Action: Bought--Holding Portfolio: 34521.6 Stocks: 992 Balance_init: 18 total($) 34539.6
# Stock: 34.85 Action: Bought--Holding Portfolio: 34571.2 Stocks: 992 Balance_init: 18 total($) 34589.2
# Stock: 34.63 Action: Bought--Holding Portfolio: 34352.96 Stocks: 992 Balance_init: 18 total($) 34370.96
# Stock: 35.32 Action: Bought--Holding Portfolio: 35037.44 Stocks: 992 Balance_init: 18 total($) 35055.44
# Stock: 35.42 Action: Bought--Holding Portfolio: 35136.64 Stocks: 992 Balance_init: 18 total($) 35154.64
# Stock: 36.07 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 35799.44
# Stock: 36.1 Action: Buy Portfolio: 35775.1 Stocks: 991 Balance_init: 24 total($) 35799.1
# Stock: 36.73 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 36423.43
# Stock: 37.34 Action: Buy Portfolio: 36406.5 Stocks: 975 Balance_init: 16 total($) 36422.5
# Stock: 38.0 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 37066.0
# Stock: 38.11 Action: Buy Portfolio: 37042.92 Stocks: 972 Balance_init: 23 total($) 37065.92
# Stock: 37.38 Action: Bought--Holding Portfolio: 36333.36 Stocks: 972 Balance_init: 23 total($) 36356.36
# Stock: 37.15 Action: Bought--Holding Portfolio: 36109.8 Stocks: 972 Balance_init: 23 total($) 36132.8
# Stock: 38.02 Action: Bought--Holding Portfolio: 36955.44 Stocks: 972 Balance_init: 23 total($) 36978.44
# Stock: 37.71 Action: Bought--Holding Portfolio: 36654.12 Stocks: 972 Balance_init: 23 total($) 36677.12
# Stock: 37.82 Action: Bought--Holding Portfolio: 36761.04 Stocks: 972 Balance_init: 23 total($) 36784.04
# Stock: 36.25 Action: Bought--Holding Portfolio: 35235.0 Stocks: 972 Balance_init: 23 total($) 35258.0
# Stock: 36.34 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 35345.48
# Stock: 36.13 Action: Buy Portfolio: 35335.14 Stocks: 978 Balance_init: 10 total($) 35345.14
# Stock: 35.52 Action: Bought--Holding Portfolio: 34738.56 Stocks: 978 Balance_init: 10 total($) 34748.56
# Stock: 36.09 Action: Bought--Holding Portfolio: 35296.02 Stocks: 978 Balance_init: 10 total($) 35306.02
# Stock: 35.17 Action: Bought--Holding Portfolio: 34396.26 Stocks: 978 Balance_init: 10 total($) 34406.26
# Stock: 33.72 Action: Bought--Holding Portfolio: 32978.16 Stocks: 978 Balance_init: 10 total($) 32988.16
# Stock: 32.75 Action: Bought--Holding Portfolio: 32029.5 Stocks: 978 Balance_init: 10 total($) 32039.5
# Stock: 32.72 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32010.16
# Stock: 32.02 Action: Buy Portfolio: 31987.98 Stocks: 999 Balance_init: 22 total($) 32009.98
# Stock: 33.02 Action: Bought--Holding Portfolio: 32986.98 Stocks: 999 Balance_init: 22 total($) 33008.98
# Stock: 33.54 Action: Bought--Holding Portfolio: 33506.46 Stocks: 999 Balance_init: 22 total($) 33528.46
# Stock: 33.78 Action: Bought--Holding Portfolio: 33746.22 Stocks: 999 Balance_init: 22 total($) 33768.22
# Stock: 34.76 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34747.24
# Stock: 34.75 Action: Buy Portfolio: 34715.25 Stocks: 999 Balance_init: 31 total($) 34746.25
# Stock: 35.49 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 35485.51
# Stock: 35.91 Action: Buy Portfolio: 35479.08 Stocks: 988 Balance_init: 6 total($) 35485.08
# Stock: 34.6 Action: Bought--Holding Portfolio: 34184.8 Stocks: 988 Balance_init: 6 total($) 34190.8
# Stock: 34.81 Action: Bought--Holding Portfolio: 34392.28 Stocks: 988 Balance_init: 6 total($) 34398.28
# Stock: 35.27 Action: Bought--Holding Portfolio: 34846.76 Stocks: 988 Balance_init: 6 total($) 34852.76
# Stock: 35.08 Action: Bought--Holding Portfolio: 34659.04 Stocks: 988 Balance_init: 6 total($) 34665.04
# Stock: 35.66 Action: Bought--Holding Portfolio: 35232.08 Stocks: 988 Balance_init: 6 total($) 35238.08
# Stock: 35.57 Action: Bought--Holding Portfolio: 35143.16 Stocks: 988 Balance_init: 6 total($) 35149.16
# Stock: 35.6 Action: Bought--Holding Portfolio: 35172.8 Stocks: 988 Balance_init: 6 total($) 35178.8
# Stock: 34.76 Action: Bought--Holding Portfolio: 34342.88 Stocks: 988 Balance_init: 6 total($) 34348.88
# Stock: 35.46 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 35040.48
# Stock: 36.18 Action: Buy Portfolio: 35022.24 Stocks: 968 Balance_init: 18 total($) 35040.24
# Stock: 35.38 Action: Bought--Holding Portfolio: 34247.84 Stocks: 968 Balance_init: 18 total($) 34265.84
# Stock: 35.33 Action: Bought--Holding Portfolio: 34199.44 Stocks: 968 Balance_init: 18 total($) 34217.44
# Stock: 34.4 Action: Bought--Holding Portfolio: 33299.2 Stocks: 968 Balance_init: 18 total($) 33317.2
# Stock: 33.82 Action: Bought--Holding Portfolio: 32737.76 Stocks: 968 Balance_init: 18 total($) 32755.76
# Stock: 34.18 Action: Bought--Holding Portfolio: 33086.24 Stocks: 968 Balance_init: 18 total($) 33104.24
# Stock: 33.47 Action: Bought--Holding Portfolio: 32398.96 Stocks: 968 Balance_init: 18 total($) 32416.96
# Stock: 33.37 Action: Bought--Holding Portfolio: 32302.16 Stocks: 968 Balance_init: 18 total($) 32320.16
# Stock: 33.1 Action: Bought--Holding Portfolio: 32040.8 Stocks: 968 Balance_init: 18 total($) 32058.8
# Stock: 33.32 Action: Bought--Holding Portfolio: 32253.76 Stocks: 968 Balance_init: 18 total($) 32271.76
# Stock: 33.76 Action: Bought--Holding Portfolio: 32679.68 Stocks: 968 Balance_init: 18 total($) 32697.68
# Stock: 34.43 Action: Bought--Holding Portfolio: 33328.24 Stocks: 968 Balance_init: 18 total($) 33346.24
# Stock: 34.53 Action: Bought--Holding Portfolio: 33425.04 Stocks: 968 Balance_init: 18 total($) 33443.04
# Stock: 34.82 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33723.76
# Final value of stock:
# 34760.0
# Final value of portfolio:
# 33724.0
# TS=
# 0.9701956271576525
