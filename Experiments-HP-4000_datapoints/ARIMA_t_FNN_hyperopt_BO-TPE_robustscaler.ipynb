# %%
import os
import random
import numpy as np
import pandas as pd
import tensorflow as tf


random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_squared_error as mse

# %%
import pandas as pd

csv_file_path = 'close.csv'

df = pd.read_csv(csv_file_path, header=None)

close = df[0].tolist()
logclose = np.log(close).tolist()

# %%
from math import floor

size = len(logclose)-100
close_train, close_test = close[0:size], close[size:len(close)]
logclose_train, logclose_test = logclose[0:size], logclose[size:len(logclose)]

series = logclose
train = logclose_train
test = logclose_test

plt.plot(series , color = 'r')
plt.show()

# %%
predicted_list, error_list = [], []
training_data = train

# %%
import pandas as pd

csv_file_path = 'forecasted_logclose_ARIMA_t.csv'

df = pd.read_csv(csv_file_path, header=None)

predicted_list = df[0].tolist()

print(predicted_list)
# Out:
# [3.3423, 3.3367, 3.3241, 3.3306, 3.3393, 3.3477, 3.3477, 3.3819, 3.391, 3.392, 3.4002, 3.426, 3.4465, 3.4372, 3.4407, 3.4605, 3.4874, 3.4977, 3.4869, 3.4894, 3.5014, 3.4916, 3.6427, 3.6035, 3.5622, 3.5684, 3.572, 3.5903, 3.5958, 3.5903, 3.5923, 3.5933, 3.5961, 3.5719, 3.581, 3.6052, 3.5912, 3.5943, 3.5929, 3.5916, 3.5599, 3.5473, 3.5568, 3.5552, 3.5506, 3.5517, 3.5459, 3.5644, 3.5686, 3.5853, 3.5878, 3.6033, 3.6212, 3.6376, 3.6418, 3.6222, 3.6158, 3.6382, 3.6315, 3.6329, 3.5931, 3.5923, 3.5892, 3.5705, 3.5867, 3.5619, 3.5195, 3.4901, 3.4885, 3.4681, 3.4963, 3.5143, 3.5199, 3.549, 3.5492, 3.5692, 3.5821, 3.5456, 3.5498, 3.5641, 3.5584, 3.5744, 3.5727, 3.5728, 3.5503, 3.5678, 3.5897, 3.5673, 3.5653, 3.5399, 3.5216, 3.5323, 3.5122, 3.508, 3.5009, 3.5063, 3.5202, 3.539, 3.543, 3.5504]

# %%
for t in range(len(test)):
    predicted_value = predicted_list[t]
    obs = test[t]
    error_list.append(obs - predicted_value)
    training_data.append(obs)
    print('predicted=%f, expected=%f error=%f' % (predicted_value, obs,abs(predicted_value-obs)))
# Out:
# predicted=3.342300, expected=3.335414 error=0.006886
# predicted=3.336700, expected=3.323236 error=0.013464
# predicted=3.324100, expected=3.330059 error=0.005959
# predicted=3.330600, expected=3.338613 error=0.008013
# predicted=3.339300, expected=3.347093 error=0.007793
# predicted=3.347700, expected=3.346741 error=0.000959
# predicted=3.347700, expected=3.382354 error=0.034654
# predicted=3.381900, expected=3.389462 error=0.007562
# predicted=3.391000, expected=3.391820 error=0.000820
# predicted=3.392000, expected=3.399195 error=0.007195
# predicted=3.400200, expected=3.426215 error=0.026015
# predicted=3.426000, expected=3.445533 error=0.019533
# predicted=3.446500, expected=3.436243 error=0.010257
# predicted=3.437200, expected=3.440098 error=0.002898
# predicted=3.440700, expected=3.460095 error=0.019395
# predicted=3.460500, expected=3.487069 error=0.026569
# predicted=3.487400, expected=3.496811 error=0.009411
# predicted=3.497700, expected=3.485845 error=0.011855
# predicted=3.486900, expected=3.488903 error=0.002003
# predicted=3.489400, expected=3.500741 error=0.011341
# predicted=3.501400, expected=3.490429 error=0.010971
# predicted=3.491600, expected=3.647015 error=0.155415
# predicted=3.642700, expected=3.597312 error=0.045388
# predicted=3.603500, expected=3.564449 error=0.039051
# predicted=3.562200, expected=3.565298 error=0.003098
# predicted=3.568400, expected=3.573188 error=0.004788
# predicted=3.572000, expected=3.588506 error=0.016506
# predicted=3.590300, expected=3.595941 error=0.005641
# predicted=3.595800, expected=3.588506 error=0.007294
# predicted=3.590300, expected=3.592369 error=0.002069
# predicted=3.592300, expected=3.591818 error=0.000482
# predicted=3.593300, expected=3.595941 error=0.002641
# predicted=3.596100, expected=3.569814 error=0.026286
# predicted=3.571900, expected=3.581573 error=0.009673
# predicted=3.581000, expected=3.604138 error=0.023138
# predicted=3.605200, expected=3.590163 error=0.015037
# predicted=3.591200, expected=3.593744 error=0.002544
# predicted=3.594300, expected=3.591818 error=0.002482
# predicted=3.592900, expected=3.590991 error=0.001909
# predicted=3.591600, expected=3.557916 error=0.033684
# predicted=3.559900, expected=3.547028 error=0.012872
# predicted=3.547300, expected=3.555919 error=0.008619
# predicted=3.556800, expected=3.554491 error=0.002309
# predicted=3.555200, expected=3.549617 error=0.005583
# predicted=3.550600, expected=3.551053 error=0.000453
# predicted=3.551700, expected=3.544720 error=0.006980
# predicted=3.545900, expected=3.564449 error=0.018549
# predicted=3.564400, expected=3.567277 error=0.002877
# predicted=3.568600, expected=3.585461 error=0.016861
# predicted=3.585300, expected=3.586293 error=0.000993
# predicted=3.587800, expected=3.603594 error=0.015794
# predicted=3.603300, expected=3.620065 error=0.016765
# predicted=3.621200, expected=3.637586 error=0.016386
# predicted=3.637600, expected=3.640477 error=0.002877
# predicted=3.641800, expected=3.621136 error=0.020664
# predicted=3.622200, expected=3.614964 error=0.007236
# predicted=3.615800, expected=3.638112 error=0.022312
# predicted=3.638200, expected=3.629925 error=0.008275
# predicted=3.631500, expected=3.632838 error=0.001338
# predicted=3.632900, expected=3.590439 error=0.042461
# predicted=3.593100, expected=3.592919 error=0.000181
# predicted=3.592300, expected=3.587124 error=0.005176
# predicted=3.589200, expected=3.570096 error=0.019104
# predicted=3.570500, expected=3.586016 error=0.015516
# predicted=3.586700, expected=3.560193 error=0.026507
# predicted=3.561900, expected=3.518091 error=0.043809
# predicted=3.519500, expected=3.488903 error=0.030597
# predicted=3.490100, expected=3.487987 error=0.002113
# predicted=3.488500, expected=3.466361 error=0.022139
# predicted=3.468100, expected=3.497113 error=0.029013
# predicted=3.496300, expected=3.512739 error=0.016439
# predicted=3.514300, expected=3.519869 error=0.005569
# predicted=3.519900, expected=3.548467 error=0.028567
# predicted=3.549000, expected=3.548180 error=0.000820
# predicted=3.549200, expected=3.569251 error=0.020051
# predicted=3.569200, expected=3.581016 error=0.011816
# predicted=3.582100, expected=3.543854 error=0.038246
# predicted=3.545600, expected=3.549905 error=0.004305
# predicted=3.549800, expected=3.563033 error=0.013233
# predicted=3.564100, expected=3.557631 error=0.006469
# predicted=3.558400, expected=3.574030 error=0.015630
# predicted=3.574400, expected=3.571503 error=0.002897
# predicted=3.572700, expected=3.572346 error=0.000354
# predicted=3.572800, expected=3.548467 error=0.024333
# predicted=3.550300, expected=3.568405 error=0.018105
# predicted=3.567800, expected=3.588506 error=0.020706
# predicted=3.589700, expected=3.566147 error=0.023553
# predicted=3.567300, expected=3.564732 error=0.002568
# predicted=3.565300, expected=3.538057 error=0.027243
# predicted=3.539900, expected=3.521052 error=0.018848
# predicted=3.521600, expected=3.531641 error=0.010041
# predicted=3.532300, expected=3.510650 error=0.021650
# predicted=3.512200, expected=3.507657 error=0.004543
# predicted=3.508000, expected=3.499533 error=0.008467
# predicted=3.500900, expected=3.506158 error=0.005258
# predicted=3.506300, expected=3.519277 error=0.012977
# predicted=3.520200, expected=3.538928 error=0.018728
# predicted=3.539000, expected=3.541829 error=0.002829
# predicted=3.543000, expected=3.550192 error=0.007192
# predicted=3.550400, expected=3.548467 error=0.001933

# %%
error = mse(test, predicted_list)
print('Test MSE: %.3f' % error)
# Out:
# Test MSE: 0.001

# %%
import pandas as pd

csv_file_path = 'rawResiduals_ARIMA_t.csv'

df = pd.read_csv(csv_file_path, header=None)

training_error = np.array(df[0].tolist())

print(training_error)
# Out:
# [-0.021932    0.038129    0.034581   ...  0.00047675 -0.0055517
#   0.0087502 ]

# %%
plt.plot(test)
plt.plot(predicted_list, color='red')
plt.show()

error = mse(test,predicted_list)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000533

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error as mse


training_error = np.array(training_error).reshape(-1,1)

# %%
import numpy as np
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.preprocessing import StandardScaler, RobustScaler
from scikeras.wrappers import KerasRegressor
from tensorflow.keras.callbacks import EarlyStopping
import warnings

warnings.filterwarnings("ignore")

def make_model(num_layers, neurons, activation, initializer, optimizer, dropout_rate, window_size):
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Dense, Dropout
    model = Sequential()
    model.add(Dense(neurons[0], input_dim=window_size, kernel_initializer=initializer, activation=activation))
    model.add(Dropout(dropout_rate))
    for i in range(1, num_layers):
        model.add(Dense(neurons[i], kernel_initializer=initializer, activation=activation))
        model.add(Dropout(dropout_rate))
    model.add(Dense(1, activation='linear'))
    model.compile(loss='mean_squared_error', optimizer=optimizer)
    return model

space = {
    "window_size": hp.choice("window_size", list(range(2, 20))), 
    "num_layers_choice": hp.choice("num_layers_choice", [
         { 
             "num_layers": 1,
             "neurons": hp.quniform("neurons_1", 2, 299, 1)
         }
    ]),
    "activation": hp.choice("activation", ["sigmoid", "tanh", "relu", "elu"]),
    "initializer": hp.choice("initializer", ["uniform", "glorot_uniform", "he_uniform"]),
    "optimizer": hp.choice("optimizer", ["adam", "sgd", "rmsprop"]),
    "dropout_rate": hp.uniform("dropout_rate", 0.0, 0.5),
    "batch_size": hp.quniform("batch_size", 8, 128, 1)
}


def objective(params):
        
    window_size = params["window_size"]

    scaler = RobustScaler()
    training_error_scaled = scaler.fit_transform(training_error)

    arch = params["num_layers_choice"]
    if arch["num_layers"] == 1:
        num_layers = 1
        neurons = [int(arch["neurons"])]
    if arch["num_layers"] == 2:
        num_layers = 2
        neurons = [int(arch["neurons1"]), int(arch["neurons2"])]
    if arch["num_layers"] == 3:
        num_layers = 3
        neurons = [int(arch["neurons1"]), int(arch["neurons2"]), int(arch["neurons3"])]
    
    
    activation = params["activation"]
    initializer = params["initializer"]
    optimizer_param = params["optimizer"]
    dropout_rate = params["dropout_rate"]
    batch_size = int(params["batch_size"])
    
    train_X, train_Y = [], []
    for i in range(len(training_error_scaled) - window_size):
        train_X.append(training_error_scaled[i:i+window_size])
        train_Y.append(training_error_scaled[i+window_size])
    new_train_X = np.array([x.reshape(-1) for x in train_X])
    new_train_Y = np.array(train_Y).ravel()
    
    callbacks = [EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)]
    epochs = 2000
    validation_split = 0.10
    
    modelKeras = KerasRegressor(
        model=make_model,
        window_size=window_size,
        model__num_layers=num_layers,
        model__neurons=neurons,
        model__activation=activation,
        model__initializer=initializer,
        model__optimizer=optimizer_param,
        model__dropout_rate=dropout_rate,
        batch_size=batch_size,
        epochs=epochs,
        validation_split=validation_split,
        callbacks=callbacks,
        shuffle=False,
        random_state=42,    
        verbose=0
    )
    
    tscv = TimeSeriesSplit(n_splits=2)
    score = np.mean(cross_val_score(modelKeras, new_train_X, new_train_Y, cv=tscv, scoring='neg_mean_squared_error', n_jobs=-1))

    
    print(f"Params: {params}, Score: {score:.4f}")

    return {"loss": -score, "status": STATUS_OK}


trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials,
            rstate=np.random.default_rng(42))

best_loss = trials.best_trial['result']['loss']
best_score = best_loss

print("\n------------------------")
print("BEST OVERALL RESULTS:")
print("------------------------")
print("Raw best parameters (indices/values):")
print(best)
print(f"Best score: {best_score:.4f}")
# Out:
# Params: {'activation': 'elu', 'batch_size': 100.0, 'dropout_rate': 0.32587119987444696, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 186.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1371
# Params: {'activation': 'elu', 'batch_size': 76.0, 'dropout_rate': 0.029968094540700263, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 183.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 17}, Score: -1.2215
# Params: {'activation': 'relu', 'batch_size': 77.0, 'dropout_rate': 0.07858985028094856, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 24.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 4}, Score: -1.1384
# Params: {'activation': 'relu', 'batch_size': 17.0, 'dropout_rate': 0.35223000813752336, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 65.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 13}, Score: -1.1620
# Params: {'activation': 'tanh', 'batch_size': 49.0, 'dropout_rate': 0.17305929881725102, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 31.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 7}, Score: -1.1401
# Params: {'activation': 'tanh', 'batch_size': 117.0, 'dropout_rate': 0.36157396222211435, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 50.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 15}, Score: -1.1364
# Params: {'activation': 'sigmoid', 'batch_size': 69.0, 'dropout_rate': 0.434677958142653, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 298.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 15}, Score: -1.1396
# Params: {'activation': 'relu', 'batch_size': 25.0, 'dropout_rate': 0.16848986962255413, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 249.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 10}, Score: -1.1420
# Params: {'activation': 'sigmoid', 'batch_size': 127.0, 'dropout_rate': 0.28673048470873264, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 231.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 2}, Score: -1.1373
# Params: {'activation': 'tanh', 'batch_size': 86.0, 'dropout_rate': 0.35206702845306526, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 145.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 18}, Score: -1.1918
# Params: {'activation': 'tanh', 'batch_size': 122.0, 'dropout_rate': 0.4773902233445454, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 14.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 3}, Score: -1.1345
# Params: {'activation': 'sigmoid', 'batch_size': 39.0, 'dropout_rate': 0.15390229944946937, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 183.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 18}, Score: -1.1499
# Params: {'activation': 'relu', 'batch_size': 105.0, 'dropout_rate': 0.10843483792853714, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 219.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 8}, Score: -1.1348
# Params: {'activation': 'sigmoid', 'batch_size': 99.0, 'dropout_rate': 0.4410499053490562, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 141.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 14}, Score: -1.1382
# Params: {'activation': 'sigmoid', 'batch_size': 21.0, 'dropout_rate': 0.4869739733232261, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 271.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 11}, Score: -1.1372
# Params: {'activation': 'sigmoid', 'batch_size': 111.0, 'dropout_rate': 0.16743004719404048, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 295.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 5}, Score: -1.1747
# Params: {'activation': 'elu', 'batch_size': 45.0, 'dropout_rate': 0.2258128479235475, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 244.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 14}, Score: -1.1500
# Params: {'activation': 'tanh', 'batch_size': 26.0, 'dropout_rate': 0.4882626520810925, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 33.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 12}, Score: -1.1494
# Params: {'activation': 'sigmoid', 'batch_size': 50.0, 'dropout_rate': 0.2085813440926868, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 254.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 19}, Score: -1.1393
# Params: {'activation': 'elu', 'batch_size': 39.0, 'dropout_rate': 0.1149178980045017, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 214.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 5}, Score: -1.3322
# Params: {'activation': 'relu', 'batch_size': 122.0, 'dropout_rate': 0.05504573228518369, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 100.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 3}, Score: -1.1497
# Params: {'activation': 'relu', 'batch_size': 102.0, 'dropout_rate': 0.004460835850294401, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 113.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 8}, Score: -1.1798
# Params: {'activation': 'tanh', 'batch_size': 128.0, 'dropout_rate': 0.10002020331697753, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 206.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 3}, Score: -1.1502
# Params: {'activation': 'relu', 'batch_size': 88.0, 'dropout_rate': 0.2524464577706642, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 5.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 6}, Score: -1.1405
# Params: {'activation': 'tanh', 'batch_size': 108.0, 'dropout_rate': 0.42170612527864176, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 87.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 8}, Score: -1.1415
# Params: {'activation': 'tanh', 'batch_size': 89.0, 'dropout_rate': 0.2977585000837182, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 162.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 9}, Score: -1.1664
# Params: {'activation': 'relu', 'batch_size': 114.0, 'dropout_rate': 0.004699072165273863, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 126.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 16}, Score: -1.2643
# Params: {'activation': 'relu', 'batch_size': 57.0, 'dropout_rate': 0.3981937658560415, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 2.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 3}, Score: -1.1345
# Params: {'activation': 'tanh', 'batch_size': 62.0, 'dropout_rate': 0.3901149731131094, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 11.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 3}, Score: -1.1360
# Params: {'activation': 'elu', 'batch_size': 60.0, 'dropout_rate': 0.45574892639919845, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 70.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 3}, Score: -1.1541
# Params: {'activation': 'tanh', 'batch_size': 57.0, 'dropout_rate': 0.4115923185369692, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 4.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 17}, Score: -1.1382
# Params: {'activation': 'relu', 'batch_size': 73.0, 'dropout_rate': 0.47197084029993636, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 48.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 3}, Score: -1.1342
# Params: {'activation': 'elu', 'batch_size': 77.0, 'dropout_rate': 0.4780747299769906, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 46.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 4}, Score: -1.1440
# Params: {'activation': 'relu', 'batch_size': 8.0, 'dropout_rate': 0.301299909469887, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 78.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 13}, Score: nan
# Params: {'activation': 'relu', 'batch_size': 92.0, 'dropout_rate': 0.31887841865948313, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 78.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 13}, Score: -1.1413
# Params: {'activation': 'tanh', 'batch_size': 69.0, 'dropout_rate': 0.3743246938924678, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 52.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 7}, Score: -1.1421
# Params: {'activation': 'relu', 'batch_size': 11.0, 'dropout_rate': 0.33658648959578263, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 22.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 9}, Score: -1.1426
# Params: {'activation': 'tanh', 'batch_size': 77.0, 'dropout_rate': 0.4559914820413733, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 95.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 3}, Score: -1.1363
# Params: {'activation': 'elu', 'batch_size': 97.0, 'dropout_rate': 0.4997707786452193, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 59.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 10}, Score: -1.1420
# Params: {'activation': 'relu', 'batch_size': 120.0, 'dropout_rate': 0.2687571736267028, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 168.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 2}, Score: -1.1673
# Params: {'activation': 'tanh', 'batch_size': 83.0, 'dropout_rate': 0.36496149135904576, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 36.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 16}, Score: -1.1547
# Params: {'activation': 'relu', 'batch_size': 33.0, 'dropout_rate': 0.31128901734913256, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 123.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 15}, Score: -1.1761
# Params: {'activation': 'tanh', 'batch_size': 71.0, 'dropout_rate': 0.4602334575173924, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 72.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 11}, Score: -1.1443
# Params: {'activation': 'relu', 'batch_size': 82.0, 'dropout_rate': 0.3380128785359427, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 17.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 6}, Score: -1.1331
# Params: {'activation': 'relu', 'batch_size': 82.0, 'dropout_rate': 0.3328401876517595, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 44.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 6}, Score: -1.1413
# Params: {'activation': 'relu', 'batch_size': 72.0, 'dropout_rate': 0.20821954469622933, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 20.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 6}, Score: -1.1399
# Params: {'activation': 'relu', 'batch_size': 92.0, 'dropout_rate': 0.2740942273949411, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 105.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 6}, Score: -1.1418
# Params: {'activation': 'relu', 'batch_size': 47.0, 'dropout_rate': 0.38236784814780866, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 58.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 12}, Score: -1.1438
# Params: {'activation': 'relu', 'batch_size': 65.0, 'dropout_rate': 0.3444670877576313, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 130.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 19}, Score: -1.1433
# Params: {'activation': 'sigmoid', 'batch_size': 81.0, 'dropout_rate': 0.43008022945172464, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 84.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 17}, Score: -1.1447
# Params: {'activation': 'relu', 'batch_size': 51.0, 'dropout_rate': 0.22256395784509125, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 31.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 18}, Score: -1.1388
# Params: {'activation': 'relu', 'batch_size': 35.0, 'dropout_rate': 0.18938202802047868, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 151.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 4}, Score: -1.1401
# Params: {'activation': 'elu', 'batch_size': 53.0, 'dropout_rate': 0.40228698669974366, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 181.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 7}, Score: -1.1526
# Params: {'activation': 'sigmoid', 'batch_size': 95.0, 'dropout_rate': 0.13889340478071827, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 275.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 14}, Score: -1.1374
# Params: {'activation': 'relu', 'batch_size': 43.0, 'dropout_rate': 0.24029839906687067, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 112.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 13}, Score: -1.1350
# Params: {'activation': 'relu', 'batch_size': 105.0, 'dropout_rate': 0.29833687083083127, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 198.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 5}, Score: -1.1479
# Params: {'activation': 'sigmoid', 'batch_size': 74.0, 'dropout_rate': 0.49342626514664945, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 17.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 10}, Score: -1.1385
# Params: {'activation': 'elu', 'batch_size': 67.0, 'dropout_rate': 0.4328764417663449, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 41.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 6}, Score: -1.1413
# Params: {'activation': 'relu', 'batch_size': 16.0, 'dropout_rate': 0.34879930402397485, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 91.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 2}, Score: -1.1382
# Params: {'activation': 'relu', 'batch_size': 85.0, 'dropout_rate': 0.05852693099583095, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 234.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 12}, Score: -1.1619
# Params: {'activation': 'sigmoid', 'batch_size': 114.0, 'dropout_rate': 0.2583370974646181, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 65.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 15}, Score: -1.1356
# Params: {'activation': 'relu', 'batch_size': 100.0, 'dropout_rate': 0.4698676127432196, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 142.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 11}, Score: -1.1394
# Params: {'activation': 'elu', 'batch_size': 28.0, 'dropout_rate': 0.4445705953335929, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 9.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 18}, Score: -1.1532
# Params: {'activation': 'relu', 'batch_size': 63.0, 'dropout_rate': 0.4118204296765985, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 55.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 19}, Score: -1.1509
# Params: {'activation': 'relu', 'batch_size': 56.0, 'dropout_rate': 0.28474353572445654, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 29.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 8}, Score: -1.1338
# Params: {'activation': 'sigmoid', 'batch_size': 56.0, 'dropout_rate': 0.13358709498419033, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 27.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 8}, Score: -1.1388
# Params: {'activation': 'relu', 'batch_size': 79.0, 'dropout_rate': 0.28202612641798114, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 39.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 8}, Score: -1.1421
# Params: {'activation': 'relu', 'batch_size': 40.0, 'dropout_rate': 0.1849965386253943, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 76.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 8}, Score: -1.1392
# Params: {'activation': 'relu', 'batch_size': 60.0, 'dropout_rate': 0.3636090276377801, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 14.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 8}, Score: -1.1371
# Params: {'activation': 'relu', 'batch_size': 91.0, 'dropout_rate': 0.30374825838227426, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 28.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 3}, Score: -1.1385
# Params: {'activation': 'relu', 'batch_size': 73.0, 'dropout_rate': 0.325273995465156, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 48.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 9}, Score: -1.1400
# Params: {'activation': 'relu', 'batch_size': 54.0, 'dropout_rate': 0.24711994946339608, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 62.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 14}, Score: -1.1412
# Params: {'activation': 'relu', 'batch_size': 87.0, 'dropout_rate': 0.23056498880222392, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 9.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 16}, Score: -1.1369
# Params: {'activation': 'relu', 'batch_size': 48.0, 'dropout_rate': 0.1558460371297324, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 82.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 6}, Score: -1.1407
# Params: {'activation': 'elu', 'batch_size': 67.0, 'dropout_rate': 0.2902583776177878, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 98.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 4}, Score: -1.1382
# Params: {'activation': 'relu', 'batch_size': 44.0, 'dropout_rate': 0.21252395780096567, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 117.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 5}, Score: -1.1422
# Params: {'activation': 'relu', 'batch_size': 32.0, 'dropout_rate': 0.37787877485745597, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 154.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 17}, Score: -1.1597
# Params: {'activation': 'relu', 'batch_size': 103.0, 'dropout_rate': 0.3120771758537819, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 105.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 13}, Score: -1.1696
# Params: {'activation': 'relu', 'batch_size': 60.0, 'dropout_rate': 0.3576788798836875, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 3.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 3}, Score: -1.1343
# Params: {'activation': 'tanh', 'batch_size': 75.0, 'dropout_rate': 0.2705926994149838, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 70.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 2}, Score: -1.1375
# Params: {'activation': 'elu', 'batch_size': 110.0, 'dropout_rate': 0.18889374466828357, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 33.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 7}, Score: -1.1445
# Params: {'activation': 'sigmoid', 'batch_size': 96.0, 'dropout_rate': 0.08136488523532448, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 24.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 6}, Score: -1.1395
# Params: {'activation': 'relu', 'batch_size': 78.0, 'dropout_rate': 0.3888606133755392, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 135.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 10}, Score: -1.1396
# Params: {'activation': 'relu', 'batch_size': 22.0, 'dropout_rate': 0.3290495529706707, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 172.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 15}, Score: -1.1812
# Params: {'activation': 'relu', 'batch_size': 69.0, 'dropout_rate': 0.022101638708232924, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 50.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 11}, Score: -1.1416
# Params: {'activation': 'tanh', 'batch_size': 85.0, 'dropout_rate': 0.4220597512500659, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 18.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 8}, Score: -1.1394
# Params: {'activation': 'relu', 'batch_size': 63.0, 'dropout_rate': 0.3982164476807003, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 90.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 3}, Score: -1.1451
# Params: {'activation': 'sigmoid', 'batch_size': 9.0, 'dropout_rate': 0.441742617217198, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 287.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 9}, Score: -1.1601
# Params: {'activation': 'elu', 'batch_size': 81.0, 'dropout_rate': 0.2550668532911954, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 196.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 19}, Score: -1.1489
# Params: {'activation': 'relu', 'batch_size': 124.0, 'dropout_rate': 0.4793576066535742, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 64.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 12}, Score: -1.1425
# Params: {'activation': 'relu', 'batch_size': 37.0, 'dropout_rate': 0.23518496980221612, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 38.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 16}, Score: -1.1455
# Params: {'activation': 'tanh', 'batch_size': 90.0, 'dropout_rate': 0.499721833071409, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 76.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 18}, Score: -1.1425
# Params: {'activation': 'relu', 'batch_size': 58.0, 'dropout_rate': 0.20030327703467293, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 219.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 6}, Score: -1.2643
# Params: {'activation': 'sigmoid', 'batch_size': 71.0, 'dropout_rate': 0.37395033623164986, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 3.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 14}, Score: -1.1362
# Params: {'activation': 'relu', 'batch_size': 51.0, 'dropout_rate': 0.28129945944366935, 'initializer': 'glorot_uniform', 'num_layers_choice': {'neurons': 55.0, 'num_layers': 1}, 'optimizer': 'rmsprop', 'window_size': 17}, Score: -1.1641
# Params: {'activation': 'elu', 'batch_size': 65.0, 'dropout_rate': 0.34559335647708567, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 104.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 4}, Score: -1.1386
# Params: {'activation': 'relu', 'batch_size': 29.0, 'dropout_rate': 0.46877903750615135, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 115.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 3}, Score: -1.1390
# Params: {'activation': 'tanh', 'batch_size': 42.0, 'dropout_rate': 0.17342655784371958, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 254.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 13}, Score: -1.1464
# Params: {'activation': 'relu', 'batch_size': 15.0, 'dropout_rate': 0.11862366844812158, 'initializer': 'he_uniform', 'num_layers_choice': {'neurons': 69.0, 'num_layers': 1}, 'optimizer': 'sgd', 'window_size': 8}, Score: -1.1735
# Params: {'activation': 'relu', 'batch_size': 47.0, 'dropout_rate': 0.21835230466675568, 'initializer': 'uniform', 'num_layers_choice': {'neurons': 158.0, 'num_layers': 1}, 'optimizer': 'adam', 'window_size': 7}, Score: -1.1425
# 100%|██████████| 100/100 [03:12<00:00,  1.93s/trial, best loss: 1.133135152346092]
#
# ------------------------
# BEST OVERALL RESULTS:
# ------------------------
# Raw best parameters (indices/values):
# {'activation': 2, 'batch_size': 82.0, 'dropout_rate': 0.3380128785359427, 'initializer': 0, 'neurons_1': 17.0, 'num_layers_choice': 0, 'optimizer': 0, 'window_size': 4}
# Best score: 1.1331

# %%
window_sizes = list(range(2, 20))
activations_list = ["sigmoid", "tanh", "relu", "elu"]
initializers_list = ["uniform", "glorot_uniform", "he_uniform"]
optimizers_list = ["adam", "sgd", "rmsprop"]

best_window_size = window_sizes[ best["window_size"] ]
best_activation = activations_list[ best["activation"] ]
best_initializer = initializers_list[ best["initializer"] ]
best_optimizer = optimizers_list[ best["optimizer"] ]
best_dropout_rate = best["dropout_rate"]
best_batch_size = int(best["batch_size"])


if best["num_layers_choice"] == 0:
    best_num_layers = 1
    best_neurons = [int(best["neurons_1"])]
if best["num_layers_choice"] == 1:
    best_num_layers = 2
    best_neurons = [int(best["neurons_2_1"]), int(best["neurons_2_2"])]
if best["num_layers_choice"] == 2:
    best_num_layers = 3
    best_neurons = [int(best["neurons_3_1"]), int(best["neurons_3_2"]), int(best["neurons_3_3"])]


scaler = RobustScaler()
training_error_scaled = scaler.fit_transform(training_error)

train_X, train_Y = [], []
for i in range(0, len(training_error_scaled) - best_window_size):
    train_X.append(training_error_scaled[i:i+best_window_size])
    train_Y.append(training_error_scaled[i+best_window_size])
new_train_X = np.array([x.reshape(-1) for x in train_X])
new_train_Y = np.array(train_Y).ravel()


final_model = make_model(
    num_layers=best_num_layers,
    neurons=best_neurons,
    activation=best_activation,
    initializer=best_initializer,
    optimizer=best_optimizer,
    dropout_rate=best_dropout_rate,
    window_size=best_window_size
)

final_model.fit(new_train_X, new_train_Y,
                batch_size=best_batch_size,
                epochs=2000,
                validation_split=0.10,
                callbacks=[EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)],
                shuffle=False,
                verbose=1)
# Out:
# Epoch 1/2000
# 43/43 [==============================] - 0s 3ms/step - loss: 1.2712 - val_loss: 0.7126
# Epoch 2/2000
# 43/43 [==============================] - 0s 1ms/step - loss: 1.2692 - val_loss: 0.7125
# Epoch 3/2000
# 43/43 [==============================] - 0s 1ms/step - loss: 1.2614 - val_loss: 0.7124
# Epoch 4/2000
# 43/43 [==============================] - 0s 1ms/step - loss: 1.2624 - val_loss: 0.7130
# Epoch 5/2000
# 43/43 [==============================] - 0s 1ms/step - loss: 1.2622 - val_loss: 0.7145
# Epoch 6/2000
# 43/43 [==============================] - 0s 912us/step - loss: 1.2606 - val_loss: 0.7152
# Epoch 7/2000
# 43/43 [==============================] - 0s 1ms/step - loss: 1.2620 - val_loss: 0.7155
# Epoch 8/2000
# 43/43 [==============================] - 0s 1ms/step - loss: 1.2564 - val_loss: 0.7161
# Epoch 9/2000
# 43/43 [==============================] - 0s 1ms/step - loss: 1.2562 - val_loss: 0.7170
# Epoch 10/2000
# 43/43 [==============================] - 0s 1ms/step - loss: 1.2571 - val_loss: 0.7165
# Epoch 11/2000
# 43/43 [==============================] - 0s 894us/step - loss: 1.2561 - val_loss: 0.7170
# Epoch 12/2000
# 43/43 [==============================] - 0s 1ms/step - loss: 1.2523 - val_loss: 0.7167
# Epoch 13/2000
# 43/43 [==============================] - 0s 1ms/step - loss: 1.2596 - val_loss: 0.7162

# %%
print(best_window_size)
print(best_activation)
print(best_initializer)
print(best_optimizer)
print(best_dropout_rate)
print(best_batch_size) 
print(best_neurons)
# Out:
# 6
# relu
# uniform
# adam
# 0.3380128785359427
# 82
# [17]

# %%
window_size = best_window_size
model = final_model

# %%
predictions = model.predict(new_train_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))
Y = pd.DataFrame(training_error[window_size:])
pred = pd.DataFrame(predictions_rescaled)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()
error = mse(training_error[window_size:],predictions_rescaled)
print('Train MSE: %.6f' % error)
# Out:
# 122/122 [==============================] - 0s 488us/step
# Train MSE: 0.000471

# %%
rawResiduals_ARIMA_t_FNN = Y - pred
plt.plot(rawResiduals_ARIMA_t_FNN)
plt.show()

rawResiduals_ARIMA_t_FNN.to_csv('rawResiduals_ARIMA_t_FNN_BO-TPE_robustscaler.csv', index=False)

# %%
test_extended = training_error.tolist()[-1*window_size:] + error_list
test_data = []
for i in test_extended:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
        
test_data = np.array(test_data).reshape(-1,1)
test_scaled = scaler.transform(test_data)

test_X,test_Y = [],[]
for i in range(0 , len(test_scaled) - window_size):
    test_X.append(test_scaled[i:i+window_size])
    test_Y.append(test_scaled[i+window_size])

new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)


predictions = model.predict(new_test_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))


Y = pd.DataFrame(error_list)
pred = pd.DataFrame(predictions_rescaled)

plt.plot(predictions_rescaled , color = 'r')
plt.show()
error = mse(error_list,predictions_rescaled)
print('Test MSE: %.6f' % error)
# Out:
# 4/4 [==============================] - 0s 0s/step
# Test MSE: 0.000531

# %%
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()
error = mse(error_list,predictions_rescaled)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000531

# %%
predicted_array = np.array(predicted_list)
final_pred = predicted_array+predictions_rescaled.flatten()
hybrid_error = mse(np.array(test), final_pred)
print('Hybrid Test MSE: %.6f' % hybrid_error)

plt.plot(pd.DataFrame(test), label="Actual Log Close")
plt.plot(pd.DataFrame(final_pred), color='r', label="Hybrid Forecast Log Close")
plt.legend()
plt.show()
# Out:
# Hybrid Test MSE: 0.000531

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on logclose: ")
print(compute_error_metrics(test, final_pred))
print(compute_directional_metrics(test, final_pred))
# Out:
# Errors on logclose:
# {'NMSE': 0.09387159590850402, 'MAE': 0.01461656629338809, 'RMSE': 0.023054077105721885, 'MSE': 0.00053149047119657, 'MAPE': 0.4122034445731455, 'TheilsU': 0.9970862130521381}
# {'DS': 0.5252525252525253, 'CU': 0.5789473684210527, 'CD': 0.4523809523809524}

# %%
close_pred = np.exp(final_pred)
Y = pd.DataFrame(close_test)
pred = pd.DataFrame(close_pred)
plt.plot(Y, label="Actual Close")
plt.plot(pred , color = 'r', label="Hybrid Forecast Close")
plt.legend()
plt.show()

error = mse(close_test,close_pred)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.654533

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on close: ")
print(compute_error_metrics(close_test, close_pred))
print(compute_directional_metrics(close_test, close_pred))
# Out:
# Errors on close:
# {'NMSE': 0.10682026798247973, 'MAE': 0.5053022583618823, 'RMSE': 0.8090319688098903, 'MSE': 0.6545327265564072, 'MAPE': 1.452352064471221, 'TheilsU': 0.9970421351316512}
# {'DS': 0.5252525252525253, 'CU': 0.5789473684210527, 'CD': 0.4523809523809524}

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from trading_strategies import trading_strategy1

trading_strategy1(close_test, close_pred)
# Out:
# Stock: 28.09 Action: Buy Portfolio: 28090.0 Stocks: 1000 Balance_init: 0 total($) 28090.0
# Stock: 27.75 Action: Bought--Holding Portfolio: 27750.0 Stocks: 1000 Balance_init: 0 total($) 27750.0
# Stock: 27.94 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27940.0
# Stock: 28.18 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27940.0
# Stock: 28.42 Action: Buy Portfolio: 27936.86 Stocks: 983 Balance_init: 3 total($) 27939.86
# Stock: 28.41 Action: Bought--Holding Portfolio: 27927.03 Stocks: 983 Balance_init: 3 total($) 27930.03
# Stock: 29.44 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28942.52
# Stock: 29.65 Action: Buy Portfolio: 28938.4 Stocks: 976 Balance_init: 4 total($) 28942.4
# Stock: 29.72 Action: Bought--Holding Portfolio: 29006.72 Stocks: 976 Balance_init: 4 total($) 29010.72
# Stock: 29.94 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29225.44
# Stock: 30.76 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29225.44
# Stock: 31.36 Action: Buy Portfolio: 29196.16 Stocks: 931 Balance_init: 29 total($) 29225.16
# Stock: 31.07 Action: Bought--Holding Portfolio: 28926.17 Stocks: 931 Balance_init: 29 total($) 28955.17
# Stock: 31.19 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29066.89
# Stock: 31.82 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29066.89
# Stock: 32.69 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29066.89
# Stock: 33.01 Action: Buy Portfolio: 29048.8 Stocks: 880 Balance_init: 18 total($) 29066.8
# Stock: 32.65 Action: Bought--Holding Portfolio: 28732.0 Stocks: 880 Balance_init: 18 total($) 28750.0
# Stock: 32.75 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28838.0
# Stock: 33.14 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28838.0
# Stock: 32.8 Action: Buy Portfolio: 28831.2 Stocks: 879 Balance_init: 6 total($) 28837.2
# Stock: 38.36 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33724.44
# Stock: 36.5 Action: Buy Portfolio: 33689.5 Stocks: 923 Balance_init: 34 total($) 33723.5
# Stock: 35.32 Action: Bought--Holding Portfolio: 32600.36 Stocks: 923 Balance_init: 34 total($) 32634.36
# Stock: 35.35 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32662.05
# Stock: 35.63 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32662.05
# Stock: 36.18 Action: Buy Portfolio: 32634.36 Stocks: 902 Balance_init: 27 total($) 32661.36
# Stock: 36.45 Action: Bought--Holding Portfolio: 32877.9 Stocks: 902 Balance_init: 27 total($) 32904.9
# Stock: 36.18 Action: Bought--Holding Portfolio: 32634.36 Stocks: 902 Balance_init: 27 total($) 32661.36
# Stock: 36.32 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32787.64
# Stock: 36.3 Action: Buy Portfolio: 32778.9 Stocks: 903 Balance_init: 8 total($) 32786.9
# Stock: 36.45 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32922.35
# Stock: 35.51 Action: Buy Portfolio: 32917.77 Stocks: 927 Balance_init: 4 total($) 32921.77
# Stock: 35.93 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33311.11
# Stock: 36.75 Action: Buy Portfolio: 33295.5 Stocks: 906 Balance_init: 15 total($) 33310.5
# Stock: 36.24 Action: Bought--Holding Portfolio: 32833.44 Stocks: 906 Balance_init: 15 total($) 32848.44
# Stock: 36.37 Action: Bought--Holding Portfolio: 32951.22 Stocks: 906 Balance_init: 15 total($) 32966.22
# Stock: 36.3 Action: Bought--Holding Portfolio: 32887.8 Stocks: 906 Balance_init: 15 total($) 32902.8
# Stock: 36.27 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32875.62
# Stock: 35.09 Action: Buy Portfolio: 32844.24 Stocks: 936 Balance_init: 31 total($) 32875.24
# Stock: 34.71 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32519.56
# Stock: 35.02 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32519.56
# Stock: 34.97 Action: Buy Portfolio: 32487.13 Stocks: 929 Balance_init: 32 total($) 32519.13
# Stock: 34.8 Action: Bought--Holding Portfolio: 32329.2 Stocks: 929 Balance_init: 32 total($) 32361.2
# Stock: 34.85 Action: Bought--Holding Portfolio: 32375.65 Stocks: 929 Balance_init: 32 total($) 32407.65
# Stock: 34.63 Action: Bought--Holding Portfolio: 32171.27 Stocks: 929 Balance_init: 32 total($) 32203.27
# Stock: 35.32 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32844.28
# Stock: 35.42 Action: Buy Portfolio: 32834.34 Stocks: 927 Balance_init: 9 total($) 32843.34
# Stock: 36.07 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33445.89
# Stock: 36.1 Action: Buy Portfolio: 33428.6 Stocks: 926 Balance_init: 17 total($) 33445.6
# Stock: 36.73 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34028.98
# Stock: 37.34 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34028.98
# Stock: 38.0 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34028.98
# Stock: 38.11 Action: Buy Portfolio: 33994.12 Stocks: 892 Balance_init: 34 total($) 34028.12
# Stock: 37.38 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33376.96
# Stock: 37.15 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33376.96
# Stock: 38.02 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33376.96
# Stock: 37.71 Action: Buy Portfolio: 33373.35 Stocks: 885 Balance_init: 3 total($) 33376.35
# Stock: 37.82 Action: Bought--Holding Portfolio: 33470.7 Stocks: 885 Balance_init: 3 total($) 33473.7
# Stock: 36.25 Action: Bought--Holding Portfolio: 32081.25 Stocks: 885 Balance_init: 3 total($) 32084.25
# Stock: 36.34 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32163.9
# Stock: 36.13 Action: Buy Portfolio: 32155.7 Stocks: 890 Balance_init: 8 total($) 32163.7
# Stock: 35.52 Action: Bought--Holding Portfolio: 31612.8 Stocks: 890 Balance_init: 8 total($) 31620.8
# Stock: 36.09 Action: Bought--Holding Portfolio: 32120.1 Stocks: 890 Balance_init: 8 total($) 32128.1
# Stock: 35.17 Action: Bought--Holding Portfolio: 31301.3 Stocks: 890 Balance_init: 8 total($) 31309.3
# Stock: 33.72 Action: Bought--Holding Portfolio: 30010.8 Stocks: 890 Balance_init: 8 total($) 30018.8
# Stock: 32.75 Action: Bought--Holding Portfolio: 29147.5 Stocks: 890 Balance_init: 8 total($) 29155.5
# Stock: 32.72 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29128.8
# Stock: 32.02 Action: Buy Portfolio: 29106.18 Stocks: 909 Balance_init: 22 total($) 29128.18
# Stock: 33.02 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30037.18
# Stock: 33.54 Action: Buy Portfolio: 30018.3 Stocks: 895 Balance_init: 18 total($) 30036.3
# Stock: 33.78 Action: Bought--Holding Portfolio: 30233.1 Stocks: 895 Balance_init: 18 total($) 30251.1
# Stock: 34.76 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31128.2
# Stock: 34.75 Action: Buy Portfolio: 31101.25 Stocks: 895 Balance_init: 26 total($) 31127.25
# Stock: 35.49 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31789.55
# Stock: 35.91 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31789.55
# Stock: 34.6 Action: Buy Portfolio: 31762.8 Stocks: 918 Balance_init: 26 total($) 31788.8
# Stock: 34.81 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31981.58
# Stock: 35.27 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31981.58
# Stock: 35.08 Action: Buy Portfolio: 31957.88 Stocks: 911 Balance_init: 23 total($) 31980.88
# Stock: 35.66 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32509.26
# Stock: 35.57 Action: Buy Portfolio: 32475.41 Stocks: 913 Balance_init: 33 total($) 32508.41
# Stock: 35.6 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32535.8
# Stock: 34.76 Action: Buy Portfolio: 32535.36 Stocks: 936 Balance_init: 0 total($) 32535.36
# Stock: 35.46 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33190.56
# Stock: 36.18 Action: Buy Portfolio: 33177.06 Stocks: 917 Balance_init: 13 total($) 33190.06
# Stock: 35.38 Action: Bought--Holding Portfolio: 32443.46 Stocks: 917 Balance_init: 13 total($) 32456.46
# Stock: 35.33 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32410.61
# Stock: 34.4 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32410.61
# Stock: 33.82 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32410.61
# Stock: 34.18 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32410.61
# Stock: 33.47 Action: Buy Portfolio: 32398.96 Stocks: 968 Balance_init: 11 total($) 32409.96
# Stock: 33.37 Action: Bought--Holding Portfolio: 32302.16 Stocks: 968 Balance_init: 11 total($) 32313.16
# Stock: 33.1 Action: Bought--Holding Portfolio: 32040.8 Stocks: 968 Balance_init: 11 total($) 32051.8
# Stock: 33.32 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32264.76
# Stock: 33.76 Action: Buy Portfolio: 32240.8 Stocks: 955 Balance_init: 23 total($) 32263.8
# Stock: 34.43 Action: Bought--Holding Portfolio: 32880.65 Stocks: 955 Balance_init: 23 total($) 32903.65
# Stock: 34.53 Action: Bought--Holding Portfolio: 32976.15 Stocks: 955 Balance_init: 23 total($) 32999.15
# Stock: 34.82 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33276.1
# Final value of stock:
# 34.76
# Final value of portfolio:
# 33276.0
