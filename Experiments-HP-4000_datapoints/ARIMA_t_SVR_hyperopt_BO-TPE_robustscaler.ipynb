# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_squared_error as mse

# %%
import pandas as pd

csv_file_path = 'close.csv'

df = pd.read_csv(csv_file_path, header=None)

close = df[0].tolist()
logclose = np.log(close).tolist()

# %%
from math import floor

size = len(logclose)-100
close_train, close_test = close[0:size], close[size:len(close)]
logclose_train, logclose_test = logclose[0:size], logclose[size:len(logclose)]

series = logclose
train = logclose_train
test = logclose_test

plt.plot(series , color = 'r')
plt.show()

# %%
predicted_list, error_list = [], []
training_data = train

# %%
import pandas as pd

csv_file_path = 'forecasted_logclose_ARIMA_t.csv'

df = pd.read_csv(csv_file_path, header=None)

predicted_list = df[0].tolist()

print(predicted_list)
# Out:
# [3.3423, 3.3367, 3.3241, 3.3306, 3.3393, 3.3477, 3.3477, 3.3819, 3.391, 3.392, 3.4002, 3.426, 3.4465, 3.4372, 3.4407, 3.4605, 3.4874, 3.4977, 3.4869, 3.4894, 3.5014, 3.4916, 3.6427, 3.6035, 3.5622, 3.5684, 3.572, 3.5903, 3.5958, 3.5903, 3.5923, 3.5933, 3.5961, 3.5719, 3.581, 3.6052, 3.5912, 3.5943, 3.5929, 3.5916, 3.5599, 3.5473, 3.5568, 3.5552, 3.5506, 3.5517, 3.5459, 3.5644, 3.5686, 3.5853, 3.5878, 3.6033, 3.6212, 3.6376, 3.6418, 3.6222, 3.6158, 3.6382, 3.6315, 3.6329, 3.5931, 3.5923, 3.5892, 3.5705, 3.5867, 3.5619, 3.5195, 3.4901, 3.4885, 3.4681, 3.4963, 3.5143, 3.5199, 3.549, 3.5492, 3.5692, 3.5821, 3.5456, 3.5498, 3.5641, 3.5584, 3.5744, 3.5727, 3.5728, 3.5503, 3.5678, 3.5897, 3.5673, 3.5653, 3.5399, 3.5216, 3.5323, 3.5122, 3.508, 3.5009, 3.5063, 3.5202, 3.539, 3.543, 3.5504]

# %%
for t in range(len(test)):
    predicted_value = predicted_list[t]
    obs = test[t]
    error_list.append(obs - predicted_value)
    training_data.append(obs)
    print('predicted=%f, expected=%f error=%f' % (predicted_value, obs,abs(predicted_value-obs)))
# Out:
# predicted=3.342300, expected=3.335414 error=0.006886
# predicted=3.336700, expected=3.323236 error=0.013464
# predicted=3.324100, expected=3.330059 error=0.005959
# predicted=3.330600, expected=3.338613 error=0.008013
# predicted=3.339300, expected=3.347093 error=0.007793
# predicted=3.347700, expected=3.346741 error=0.000959
# predicted=3.347700, expected=3.382354 error=0.034654
# predicted=3.381900, expected=3.389462 error=0.007562
# predicted=3.391000, expected=3.391820 error=0.000820
# predicted=3.392000, expected=3.399195 error=0.007195
# predicted=3.400200, expected=3.426215 error=0.026015
# predicted=3.426000, expected=3.445533 error=0.019533
# predicted=3.446500, expected=3.436243 error=0.010257
# predicted=3.437200, expected=3.440098 error=0.002898
# predicted=3.440700, expected=3.460095 error=0.019395
# predicted=3.460500, expected=3.487069 error=0.026569
# predicted=3.487400, expected=3.496811 error=0.009411
# predicted=3.497700, expected=3.485845 error=0.011855
# predicted=3.486900, expected=3.488903 error=0.002003
# predicted=3.489400, expected=3.500741 error=0.011341
# predicted=3.501400, expected=3.490429 error=0.010971
# predicted=3.491600, expected=3.647015 error=0.155415
# predicted=3.642700, expected=3.597312 error=0.045388
# predicted=3.603500, expected=3.564449 error=0.039051
# predicted=3.562200, expected=3.565298 error=0.003098
# predicted=3.568400, expected=3.573188 error=0.004788
# predicted=3.572000, expected=3.588506 error=0.016506
# predicted=3.590300, expected=3.595941 error=0.005641
# predicted=3.595800, expected=3.588506 error=0.007294
# predicted=3.590300, expected=3.592369 error=0.002069
# predicted=3.592300, expected=3.591818 error=0.000482
# predicted=3.593300, expected=3.595941 error=0.002641
# predicted=3.596100, expected=3.569814 error=0.026286
# predicted=3.571900, expected=3.581573 error=0.009673
# predicted=3.581000, expected=3.604138 error=0.023138
# predicted=3.605200, expected=3.590163 error=0.015037
# predicted=3.591200, expected=3.593744 error=0.002544
# predicted=3.594300, expected=3.591818 error=0.002482
# predicted=3.592900, expected=3.590991 error=0.001909
# predicted=3.591600, expected=3.557916 error=0.033684
# predicted=3.559900, expected=3.547028 error=0.012872
# predicted=3.547300, expected=3.555919 error=0.008619
# predicted=3.556800, expected=3.554491 error=0.002309
# predicted=3.555200, expected=3.549617 error=0.005583
# predicted=3.550600, expected=3.551053 error=0.000453
# predicted=3.551700, expected=3.544720 error=0.006980
# predicted=3.545900, expected=3.564449 error=0.018549
# predicted=3.564400, expected=3.567277 error=0.002877
# predicted=3.568600, expected=3.585461 error=0.016861
# predicted=3.585300, expected=3.586293 error=0.000993
# predicted=3.587800, expected=3.603594 error=0.015794
# predicted=3.603300, expected=3.620065 error=0.016765
# predicted=3.621200, expected=3.637586 error=0.016386
# predicted=3.637600, expected=3.640477 error=0.002877
# predicted=3.641800, expected=3.621136 error=0.020664
# predicted=3.622200, expected=3.614964 error=0.007236
# predicted=3.615800, expected=3.638112 error=0.022312
# predicted=3.638200, expected=3.629925 error=0.008275
# predicted=3.631500, expected=3.632838 error=0.001338
# predicted=3.632900, expected=3.590439 error=0.042461
# predicted=3.593100, expected=3.592919 error=0.000181
# predicted=3.592300, expected=3.587124 error=0.005176
# predicted=3.589200, expected=3.570096 error=0.019104
# predicted=3.570500, expected=3.586016 error=0.015516
# predicted=3.586700, expected=3.560193 error=0.026507
# predicted=3.561900, expected=3.518091 error=0.043809
# predicted=3.519500, expected=3.488903 error=0.030597
# predicted=3.490100, expected=3.487987 error=0.002113
# predicted=3.488500, expected=3.466361 error=0.022139
# predicted=3.468100, expected=3.497113 error=0.029013
# predicted=3.496300, expected=3.512739 error=0.016439
# predicted=3.514300, expected=3.519869 error=0.005569
# predicted=3.519900, expected=3.548467 error=0.028567
# predicted=3.549000, expected=3.548180 error=0.000820
# predicted=3.549200, expected=3.569251 error=0.020051
# predicted=3.569200, expected=3.581016 error=0.011816
# predicted=3.582100, expected=3.543854 error=0.038246
# predicted=3.545600, expected=3.549905 error=0.004305
# predicted=3.549800, expected=3.563033 error=0.013233
# predicted=3.564100, expected=3.557631 error=0.006469
# predicted=3.558400, expected=3.574030 error=0.015630
# predicted=3.574400, expected=3.571503 error=0.002897
# predicted=3.572700, expected=3.572346 error=0.000354
# predicted=3.572800, expected=3.548467 error=0.024333
# predicted=3.550300, expected=3.568405 error=0.018105
# predicted=3.567800, expected=3.588506 error=0.020706
# predicted=3.589700, expected=3.566147 error=0.023553
# predicted=3.567300, expected=3.564732 error=0.002568
# predicted=3.565300, expected=3.538057 error=0.027243
# predicted=3.539900, expected=3.521052 error=0.018848
# predicted=3.521600, expected=3.531641 error=0.010041
# predicted=3.532300, expected=3.510650 error=0.021650
# predicted=3.512200, expected=3.507657 error=0.004543
# predicted=3.508000, expected=3.499533 error=0.008467
# predicted=3.500900, expected=3.506158 error=0.005258
# predicted=3.506300, expected=3.519277 error=0.012977
# predicted=3.520200, expected=3.538928 error=0.018728
# predicted=3.539000, expected=3.541829 error=0.002829
# predicted=3.543000, expected=3.550192 error=0.007192
# predicted=3.550400, expected=3.548467 error=0.001933

# %%
error = mse(test, predicted_list)
print('Test MSE: %.3f' % error)
# Out:
# Test MSE: 0.001

# %%
import pandas as pd

csv_file_path = 'rawResiduals_ARIMA_t.csv'

df = pd.read_csv(csv_file_path, header=None)

training_error = np.array(df[0].tolist())

print(training_error)
# Out:
# [-0.021932    0.038129    0.034581   ...  0.00047675 -0.0055517
#   0.0087502 ]

# %%
plt.plot(test)
plt.plot(predicted_list, color='red')
plt.show()

error = mse(test,predicted_list)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000533

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error as mse

# %%
import numpy as np
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.preprocessing import RobustScaler, RobustScaler
from sklearn.svm import SVR
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
import hyperopt
import warnings

training_error = np.array(training_error).reshape(-1,1)

space = {
    "window_size": hp.choice("window_size", range(2,20)),
    "kernel": hp.choice("kernel", ["linear", "poly", "rbf"]),
    "C": hp.loguniform("C", np.log(0.001), np.log(100)),
    "epsilon": hp.loguniform("epsilon", np.log(0.00001), np.log(1)),
    "gamma": hp.choice("gamma", ["scale", "auto"]),
    "degree": hp.quniform("degree", 2, 4, 1),  
    "coef0": hp.uniform("coef0", -5, 5)      
}

def objective(params):
    window_size = params["window_size"]
    kernel = params["kernel"]
    C = params["C"]
    epsilon = params["epsilon"]

    scaler = RobustScaler()

    training_error_scaled = scaler.fit_transform(training_error)
    train_X, train_Y = [], []
    for i in range(len(training_error_scaled) - window_size):
        train_X.append(training_error_scaled[i:i+window_size])
        train_Y.append(training_error_scaled[i+window_size])
    new_train_X = np.array([x.reshape(-1) for x in train_X])
    new_train_Y = np.array(train_Y).ravel()

    svr_params = {"C": C, "epsilon": epsilon}
    
    if kernel == "poly":
        svr_params["gamma"] = params["gamma"]
        svr_params["degree"] = int(params["degree"])  
        svr_params["coef0"] = (params["coef0"])    
    elif kernel == "rbf":
        svr_params["gamma"] = params["gamma"]

    model = SVR(kernel=kernel, **svr_params)

    tscv = TimeSeriesSplit(n_splits=2)
    score = np.mean(cross_val_score(model, new_train_X, new_train_Y, cv=tscv, scoring='neg_mean_squared_error', n_jobs=-1))
    
    return {"loss": -score, "status": STATUS_OK}

trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials,
            rstate=np.random.default_rng(42))

best_loss = trials.best_trial['result']['loss']
best_score = best_loss

print("\n------------------------")
print("BEST OVERALL RESULTS:")
print("------------------------")
print("Best parameters (raw indices and values):")
print(best)
print(f"Best score: {best_score:.4f}")
# Out:
# 100%|██████████| 100/100 [01:09<00:00,  1.43trial/s, best loss: 1.1327804655185498]
#
# ------------------------
# BEST OVERALL RESULTS:
# ------------------------
# Best parameters (raw indices and values):
# {'C': 0.007175016613747003, 'coef0': 3.8271125901889174, 'degree': 3.0, 'epsilon': 1.5615860811626446e-05, 'gamma': 0, 'kernel': 2, 'window_size': 3}
# Best score: 1.1328

# %%
from sklearn.preprocessing import RobustScaler, RobustScaler
from sklearn.svm import SVR
import numpy as np

window_sizes = range(2,20)
kernels_list = ["linear", "poly", "rbf"]
gamma_list = ["scale", "auto"]

window_size = window_sizes[best["window_size"]]
best_kernel = kernels_list[best["kernel"]]
best_gamma = gamma_list[best["gamma"]]
best_C = best["C"]
best_epsilon = best["epsilon"]
best_degree = int(best["degree"]) if best_kernel == "poly" else None
best_coef0 = (best["coef0"]) if best_kernel == "poly" else None

scaler = RobustScaler()

training_error_scaled = scaler.fit_transform(training_error)
train_X, train_Y = [], []
for i in range(0, len(training_error_scaled) - window_size):
    train_X.append(training_error_scaled[i:i+window_size])
    train_Y.append(training_error_scaled[i+window_size])

new_train_X = np.array([x.reshape(-1) for x in train_X])
new_train_Y = np.array(train_Y).ravel()

svr_params = {"C": best_C, "epsilon": best_epsilon}
if best_kernel == "poly":
    svr_params["gamma"] = best_gamma
    svr_params["degree"] = best_degree
    svr_params["coef0"] = best_coef0
elif best_kernel == "rbf":
    svr_params["gamma"] = best_gamma

model = SVR(kernel=best_kernel, **svr_params)

model.fit(new_train_X, new_train_Y)
# Out:
# SVR(C=0.007175016613747003, epsilon=1.5615860811626446e-05)

# %%
print(window_size)
print(best_kernel)
print(best_gamma)
print(best_C)
print(best_epsilon)
print(best_degree)
print(best_coef0)
# Out:
# 5
# rbf
# scale
# 0.007175016613747003
# 1.5615860811626446e-05
# None
# None

# %%
predictions = model.predict(new_train_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))
Y = pd.DataFrame(training_error[window_size:])
pred = pd.DataFrame(predictions_rescaled)
plt.plot(Y, label='ARIMA-t Residuals')
plt.plot(pred , color = 'r', label='In-sample Residual Predictions')
plt.xlabel('Date')  
plt.ylabel('Log Close')  
plt.legend()
plt.show()
error = mse(training_error[window_size:],predictions_rescaled)
print('Train MSE: %.6f' % error)
# Out:
# Train MSE: 0.000474

# %%
rawResiduals_ARIMA_t_SVR = Y - pred
plt.plot(rawResiduals_ARIMA_t_SVR)
plt.show()

rawResiduals_ARIMA_t_SVR.to_csv('rawResiduals_ARIMA_t_SVR_BO-TPE_robustscaler.csv', index=False)

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox

lags=np.ceil(np.log(len(rawResiduals_ARIMA_t_SVR)))

plt.figure(figsize=(10, 5))
plot_acf(rawResiduals_ARIMA_t_SVR, lags=lags, alpha=0.05)
plt.title('Autocorrelation Function (ACF)')
plt.show()

plt.figure(figsize=(10, 5))
plot_pacf(rawResiduals_ARIMA_t_SVR, lags=lags, alpha=0.05, method='ywm')
plt.title('Partial Autocorrelation Function (PACF)')
plt.show()

lbq_test = acorr_ljungbox(rawResiduals_ARIMA_t_SVR, lags=lags, return_df=True)
print(lbq_test)
# Out:
#      lb_stat  lb_pvalue
# 1   0.899401   0.342942
# 2   1.383960   0.500584
# 3   4.008258   0.260574
# 4   5.769565   0.217031
# 5   7.708825   0.173030
# 6  15.553444   0.016362
# 7  21.048313   0.003699
# 8  38.996988   0.000005
# 9  40.224949   0.000007

# %%
test_extended = training_error.tolist()[-1*window_size:] + error_list
test_data = []
for i in test_extended:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
        
test_data = np.array(test_data).reshape(-1,1)
test_scaled = scaler.transform(test_data)

test_X,test_Y = [],[]
for i in range(0 , len(test_scaled) - window_size):
    test_X.append(test_scaled[i:i+window_size])
    test_Y.append(test_scaled[i+window_size])

new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)

predictions = model.predict(new_test_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))


Y = pd.DataFrame(error_list)
pred = pd.DataFrame(predictions_rescaled)

plt.plot(predictions_rescaled , color = 'r')
plt.show()
error = mse(error_list,predictions_rescaled)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000531

# %%
plt.plot(Y, label='Out-of-Sample Prediction Error ARIMA-t')
plt.plot(pred , color = 'r', label='Out-of-Sample Residual Predictions ML')
plt.xlabel('Date')  
plt.ylabel('Log Close')  
plt.legend()
plt.show()
error = mse(error_list,predictions_rescaled)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000531

# %%
predicted_array = np.array(predicted_list)
final_pred = predicted_array+predictions_rescaled.flatten()
hybrid_error = mse(np.array(test), final_pred)
print('Hybrid Test MSE: %.6f' % hybrid_error)

plt.plot(pd.DataFrame(test), label="Actual")
plt.plot(pd.DataFrame(final_pred), color='r', label="Hybrid Forecast")
plt.xlabel('Date')  
plt.ylabel('Log Close')  
plt.legend()
plt.show()
# Out:
# Hybrid Test MSE: 0.000531

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on logclose: ")
print(compute_error_metrics(test, final_pred))
print(compute_directional_metrics(test, final_pred))
# Out:
# Errors on logclose:
# {'NMSE': 0.09378430969949492, 'MAE': 0.01453142448915512, 'RMSE': 0.023043356232308056, 'MSE': 0.0005309962664490505, 'MAPE': 0.40979473169644465, 'TheilsU': 0.9961674489075238}
# {'DS': 0.5252525252525253, 'CU': 0.5964912280701754, 'CD': 0.42857142857142855}

# %%
close_pred = np.exp(final_pred)
Y = pd.DataFrame(close_test)
pred = pd.DataFrame(close_pred)
plt.plot(Y, label="Actual Close")
plt.plot(pred , color = 'r', label="Hybrid Forecast Close")
plt.legend()
plt.show()

error = mse(close_test,close_pred)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.655115

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on close: ")
print(compute_error_metrics(close_test, close_pred))
print(compute_directional_metrics(close_test, close_pred))
# Out:
# Errors on close:
# {'NMSE': 0.10691534878596717, 'MAE': 0.5027249702880237, 'RMSE': 0.8093919487149738, 'MSE': 0.6551153266446228, 'MAPE': 1.444865486884525, 'TheilsU': 0.9962721139496888}
# {'DS': 0.5252525252525253, 'CU': 0.5964912280701754, 'CD': 0.42857142857142855}

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from trading_strategies import trading_strategy1

trading_strategy1(close_test, close_pred)
# Out:
# Stock: 28.09 Action: Buy Portfolio: 28090.0 Stocks: 1000 Balance_init: 0 total($) 28090.0
# Stock: 27.75 Action: Bought--Holding Portfolio: 27750.0 Stocks: 1000 Balance_init: 0 total($) 27750.0
# Stock: 27.94 Action: Bought--Holding Portfolio: 27940.0 Stocks: 1000 Balance_init: 0 total($) 27940.0
# Stock: 28.18 Action: Bought--Holding Portfolio: 28180.0 Stocks: 1000 Balance_init: 0 total($) 28180.0
# Stock: 28.42 Action: Bought--Holding Portfolio: 28420.0 Stocks: 1000 Balance_init: 0 total($) 28420.0
# Stock: 28.41 Action: Bought--Holding Portfolio: 28410.0 Stocks: 1000 Balance_init: 0 total($) 28410.0
# Stock: 29.44 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29440.0
# Stock: 29.65 Action: Buy Portfolio: 29412.8 Stocks: 992 Balance_init: 27 total($) 29439.8
# Stock: 29.72 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29509.24
# Stock: 29.94 Action: Buy Portfolio: 29490.9 Stocks: 985 Balance_init: 18 total($) 29508.9
# Stock: 30.76 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30316.6
# Stock: 31.36 Action: Buy Portfolio: 30293.76 Stocks: 966 Balance_init: 22 total($) 30315.76
# Stock: 31.07 Action: Bought--Holding Portfolio: 30013.62 Stocks: 966 Balance_init: 22 total($) 30035.62
# Stock: 31.19 Action: Bought--Holding Portfolio: 30129.54 Stocks: 966 Balance_init: 22 total($) 30151.54
# Stock: 31.82 Action: Bought--Holding Portfolio: 30738.12 Stocks: 966 Balance_init: 22 total($) 30760.12
# Stock: 32.69 Action: Bought--Holding Portfolio: 31578.54 Stocks: 966 Balance_init: 22 total($) 31600.54
# Stock: 33.01 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31909.66
# Stock: 32.65 Action: Buy Portfolio: 31899.05 Stocks: 977 Balance_init: 10 total($) 31909.05
# Stock: 32.75 Action: Bought--Holding Portfolio: 31996.75 Stocks: 977 Balance_init: 10 total($) 32006.75
# Stock: 33.14 Action: Bought--Holding Portfolio: 32377.78 Stocks: 977 Balance_init: 10 total($) 32387.78
# Stock: 32.8 Action: Bought--Holding Portfolio: 32045.6 Stocks: 977 Balance_init: 10 total($) 32055.6
# Stock: 38.36 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 37487.72
# Stock: 36.5 Action: Buy Portfolio: 37485.5 Stocks: 1027 Balance_init: 2 total($) 37487.5
# Stock: 35.32 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 36275.64
# Stock: 35.35 Action: Buy Portfolio: 36269.1 Stocks: 1026 Balance_init: 6 total($) 36275.1
# Stock: 35.63 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 36562.38
# Stock: 36.18 Action: Buy Portfolio: 36541.8 Stocks: 1010 Balance_init: 20 total($) 36561.8
# Stock: 36.45 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 36834.5
# Stock: 36.18 Action: Buy Portfolio: 36831.24 Stocks: 1018 Balance_init: 3 total($) 36834.24
# Stock: 36.32 Action: Bought--Holding Portfolio: 36973.76 Stocks: 1018 Balance_init: 3 total($) 36976.76
# Stock: 36.3 Action: Bought--Holding Portfolio: 36953.4 Stocks: 1018 Balance_init: 3 total($) 36956.4
# Stock: 36.45 Action: Bought--Holding Portfolio: 37106.1 Stocks: 1018 Balance_init: 3 total($) 37109.1
# Stock: 35.51 Action: Bought--Holding Portfolio: 36149.18 Stocks: 1018 Balance_init: 3 total($) 36152.18
# Stock: 35.93 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 36579.74
# Stock: 36.75 Action: Buy Portfolio: 36566.25 Stocks: 995 Balance_init: 13 total($) 36579.25
# Stock: 36.24 Action: Bought--Holding Portfolio: 36058.8 Stocks: 995 Balance_init: 13 total($) 36071.8
# Stock: 36.37 Action: Bought--Holding Portfolio: 36188.15 Stocks: 995 Balance_init: 13 total($) 36201.15
# Stock: 36.3 Action: Bought--Holding Portfolio: 36118.5 Stocks: 995 Balance_init: 13 total($) 36131.5
# Stock: 36.27 Action: Bought--Holding Portfolio: 36088.65 Stocks: 995 Balance_init: 13 total($) 36101.65
# Stock: 35.09 Action: Bought--Holding Portfolio: 34914.55 Stocks: 995 Balance_init: 13 total($) 34927.55
# Stock: 34.71 Action: Bought--Holding Portfolio: 34536.45 Stocks: 995 Balance_init: 13 total($) 34549.45
# Stock: 35.02 Action: Bought--Holding Portfolio: 34844.9 Stocks: 995 Balance_init: 13 total($) 34857.9
# Stock: 34.97 Action: Bought--Holding Portfolio: 34795.15 Stocks: 995 Balance_init: 13 total($) 34808.15
# Stock: 34.8 Action: Bought--Holding Portfolio: 34626.0 Stocks: 995 Balance_init: 13 total($) 34639.0
# Stock: 34.85 Action: Bought--Holding Portfolio: 34675.75 Stocks: 995 Balance_init: 13 total($) 34688.75
# Stock: 34.63 Action: Bought--Holding Portfolio: 34456.85 Stocks: 995 Balance_init: 13 total($) 34469.85
# Stock: 35.32 Action: Bought--Holding Portfolio: 35143.4 Stocks: 995 Balance_init: 13 total($) 35156.4
# Stock: 35.42 Action: Bought--Holding Portfolio: 35242.9 Stocks: 995 Balance_init: 13 total($) 35255.9
# Stock: 36.07 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 35902.65
# Stock: 36.1 Action: Buy Portfolio: 35883.4 Stocks: 994 Balance_init: 19 total($) 35902.4
# Stock: 36.73 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 36528.62
# Stock: 37.34 Action: Buy Portfolio: 36518.52 Stocks: 978 Balance_init: 10 total($) 36528.52
# Stock: 38.0 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 37174.0
# Stock: 38.11 Action: Buy Portfolio: 37157.25 Stocks: 975 Balance_init: 16 total($) 37173.25
# Stock: 37.38 Action: Bought--Holding Portfolio: 36445.5 Stocks: 975 Balance_init: 16 total($) 36461.5
# Stock: 37.15 Action: Bought--Holding Portfolio: 36221.25 Stocks: 975 Balance_init: 16 total($) 36237.25
# Stock: 38.02 Action: Bought--Holding Portfolio: 37069.5 Stocks: 975 Balance_init: 16 total($) 37085.5
# Stock: 37.71 Action: Bought--Holding Portfolio: 36767.25 Stocks: 975 Balance_init: 16 total($) 36783.25
# Stock: 37.82 Action: Bought--Holding Portfolio: 36874.5 Stocks: 975 Balance_init: 16 total($) 36890.5
# Stock: 36.25 Action: Bought--Holding Portfolio: 35343.75 Stocks: 975 Balance_init: 16 total($) 35359.75
# Stock: 36.34 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 35447.5
# Stock: 36.13 Action: Buy Portfolio: 35443.53 Stocks: 981 Balance_init: 3 total($) 35446.53
# Stock: 35.52 Action: Bought--Holding Portfolio: 34845.12 Stocks: 981 Balance_init: 3 total($) 34848.12
# Stock: 36.09 Action: Bought--Holding Portfolio: 35404.29 Stocks: 981 Balance_init: 3 total($) 35407.29
# Stock: 35.17 Action: Bought--Holding Portfolio: 34501.77 Stocks: 981 Balance_init: 3 total($) 34504.77
# Stock: 33.72 Action: Bought--Holding Portfolio: 33079.32 Stocks: 981 Balance_init: 3 total($) 33082.32
# Stock: 32.75 Action: Bought--Holding Portfolio: 32127.75 Stocks: 981 Balance_init: 3 total($) 32130.75
# Stock: 32.72 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32101.32
# Stock: 32.02 Action: Buy Portfolio: 32084.04 Stocks: 1002 Balance_init: 17 total($) 32101.04
# Stock: 33.02 Action: Bought--Holding Portfolio: 33086.04 Stocks: 1002 Balance_init: 17 total($) 33103.04
# Stock: 33.54 Action: Bought--Holding Portfolio: 33607.08 Stocks: 1002 Balance_init: 17 total($) 33624.08
# Stock: 33.78 Action: Bought--Holding Portfolio: 33847.56 Stocks: 1002 Balance_init: 17 total($) 33864.56
# Stock: 34.76 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34846.52
# Stock: 34.75 Action: Buy Portfolio: 34819.5 Stocks: 1002 Balance_init: 27 total($) 34846.5
# Stock: 35.49 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 35587.98
# Stock: 35.91 Action: Buy Portfolio: 35586.81 Stocks: 991 Balance_init: 1 total($) 35587.81
# Stock: 34.6 Action: Bought--Holding Portfolio: 34288.6 Stocks: 991 Balance_init: 1 total($) 34289.6
# Stock: 34.81 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34497.71
# Stock: 35.27 Action: Buy Portfolio: 34494.06 Stocks: 978 Balance_init: 3 total($) 34497.06
# Stock: 35.08 Action: Bought--Holding Portfolio: 34308.24 Stocks: 978 Balance_init: 3 total($) 34311.24
# Stock: 35.66 Action: Bought--Holding Portfolio: 34875.48 Stocks: 978 Balance_init: 3 total($) 34878.48
# Stock: 35.57 Action: Bought--Holding Portfolio: 34787.46 Stocks: 978 Balance_init: 3 total($) 34790.46
# Stock: 35.6 Action: Bought--Holding Portfolio: 34816.8 Stocks: 978 Balance_init: 3 total($) 34819.8
# Stock: 34.76 Action: Bought--Holding Portfolio: 33995.28 Stocks: 978 Balance_init: 3 total($) 33998.28
# Stock: 35.46 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34682.88
# Stock: 36.18 Action: Buy Portfolio: 34660.44 Stocks: 958 Balance_init: 22 total($) 34682.44
# Stock: 35.38 Action: Bought--Holding Portfolio: 33894.04 Stocks: 958 Balance_init: 22 total($) 33916.04
# Stock: 35.33 Action: Bought--Holding Portfolio: 33846.14 Stocks: 958 Balance_init: 22 total($) 33868.14
# Stock: 34.4 Action: Bought--Holding Portfolio: 32955.2 Stocks: 958 Balance_init: 22 total($) 32977.2
# Stock: 33.82 Action: Bought--Holding Portfolio: 32399.56 Stocks: 958 Balance_init: 22 total($) 32421.56
# Stock: 34.18 Action: Bought--Holding Portfolio: 32744.44 Stocks: 958 Balance_init: 22 total($) 32766.44
# Stock: 33.47 Action: Bought--Holding Portfolio: 32064.26 Stocks: 958 Balance_init: 22 total($) 32086.26
# Stock: 33.37 Action: Bought--Holding Portfolio: 31968.46 Stocks: 958 Balance_init: 22 total($) 31990.46
# Stock: 33.1 Action: Bought--Holding Portfolio: 31709.8 Stocks: 958 Balance_init: 22 total($) 31731.8
# Stock: 33.32 Action: Bought--Holding Portfolio: 31920.56 Stocks: 958 Balance_init: 22 total($) 31942.56
# Stock: 33.76 Action: Bought--Holding Portfolio: 32342.08 Stocks: 958 Balance_init: 22 total($) 32364.08
# Stock: 34.43 Action: Bought--Holding Portfolio: 32983.94 Stocks: 958 Balance_init: 22 total($) 33005.94
# Stock: 34.53 Action: Bought--Holding Portfolio: 33079.74 Stocks: 958 Balance_init: 22 total($) 33101.74
# Stock: 34.82 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33379.56
# Final value of stock:
# 34.76
# Final value of portfolio:
# 33380.0
