# %%
import sys
from pathlib import Path

script_dir = Path("../Functions/Performance Metrics").resolve()

if str(script_dir) not in sys.path:
    sys.path.append(str(script_dir))

from trading_strategies import trading_strategy1

# %%
import pandas as pd

csv_file_path = 'test_close.csv'
df = pd.read_csv(csv_file_path, header=None)

test_close = df[0].tolist()

# %%
import pandas as pd

csv_file_path = 'forecasted_close_ARIMA.csv'
df = pd.read_csv(csv_file_path, header=None)

forecasted_close_ARIMA = df[0].tolist()

# %%
trading_strategy1(test_close, forecasted_close_ARIMA)
# Out:
# Stock: 26.339 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26339.0
# Stock: 24.591 Action: Buy Portfolio: 26336.96 Stocks: 1071 Balance_init: 2 total($) 26338.96
# Stock: 24.786 Action: Bought--Holding Portfolio: 26545.81 Stocks: 1071 Balance_init: 2 total($) 26547.81
# Stock: 25.934 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27777.31
# Stock: 26.495 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27777.31
# Stock: 23.666 Action: Buy Portfolio: 27760.22 Stocks: 1173 Balance_init: 17 total($) 27777.22
# Stock: 25.243 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29627.04
# Stock: 25.166 Action: Buy Portfolio: 29620.38 Stocks: 1177 Balance_init: 6 total($) 29626.38
# Stock: 24.793 Action: Bought--Holding Portfolio: 29181.36 Stocks: 1177 Balance_init: 6 total($) 29187.36
# ...

# %%
import pandas as pd

csv_file_path = 'forecasted_close_ARIMA_t.csv'
df = pd.read_csv(csv_file_path, header=None)

forecasted_close_ARIMA_t = df[0].tolist()

# %%
trading_strategy1(test_close, forecasted_close_ARIMA_t)
# Out:
# Stock: 26.339 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26339.0
# Stock: 24.591 Action: Buy Portfolio: 26336.96 Stocks: 1071 Balance_init: 2 total($) 26338.96
# Stock: 24.786 Action: Bought--Holding Portfolio: 26545.81 Stocks: 1071 Balance_init: 2 total($) 26547.81
# Stock: 25.934 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27777.31
# Stock: 26.495 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27777.31
# Stock: 23.666 Action: Buy Portfolio: 27760.22 Stocks: 1173 Balance_init: 17 total($) 27777.22
# Stock: 25.243 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29627.04
# Stock: 25.166 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29627.04
# Stock: 24.793 Action: Buy Portfolio: 29602.84 Stocks: 1194 Balance_init: 24 total($) 29626.84
# ...

# %%
import pandas as pd

csv_file_path = 'forecasted_close_ARIMA_GARCH.csv'
df = pd.read_csv(csv_file_path, header=None)

forecasted_close_ARIMA_GARCH = df[0].tolist()

# %%
trading_strategy1(test_close, forecasted_close_ARIMA_GARCH)
# Out:
# Stock: 26.339 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26339.0
# Stock: 24.591 Action: Buy Portfolio: 26336.96 Stocks: 1071 Balance_init: 2 total($) 26338.96
# Stock: 24.786 Action: Bought--Holding Portfolio: 26545.81 Stocks: 1071 Balance_init: 2 total($) 26547.81
# Stock: 25.934 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27777.31
# Stock: 26.495 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27777.31
# Stock: 23.666 Action: Buy Portfolio: 27760.22 Stocks: 1173 Balance_init: 17 total($) 27777.22
# Stock: 25.243 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29627.04
# Stock: 25.166 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29627.04
# Stock: 24.793 Action: Buy Portfolio: 29602.84 Stocks: 1194 Balance_init: 24 total($) 29626.84
# ...

# %%
import pandas as pd

csv_file_path = 'forecasted_close_ARIMA_t_GARCH_t.csv'
df = pd.read_csv(csv_file_path, header=None)

forecasted_close_ARIMA_t_GARCH_t = df[0].tolist()

# %%
trading_strategy1(test_close, forecasted_close_ARIMA_t_GARCH_t)
# Out:
# Stock: 26.339 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26339.0
# Stock: 24.591 Action: Buy Portfolio: 26336.96 Stocks: 1071 Balance_init: 2 total($) 26338.96
# Stock: 24.786 Action: Bought--Holding Portfolio: 26545.81 Stocks: 1071 Balance_init: 2 total($) 26547.81
# Stock: 25.934 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27777.31
# Stock: 26.495 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27777.31
# Stock: 23.666 Action: Buy Portfolio: 27760.22 Stocks: 1173 Balance_init: 17 total($) 27777.22
# Stock: 25.243 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29627.04
# Stock: 25.166 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29627.04
# Stock: 24.793 Action: Buy Portfolio: 29602.84 Stocks: 1194 Balance_init: 24 total($) 29626.84
# ...
