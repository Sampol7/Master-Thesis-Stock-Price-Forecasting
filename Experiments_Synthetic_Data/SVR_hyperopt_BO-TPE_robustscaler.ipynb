# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_squared_error as mse

# %%
import pandas as pd

csv_file_path = 'close.csv'

df = pd.read_csv(csv_file_path, header=None)

close = df[0].tolist()
logclose = np.log(close).tolist()


plt.plot(close , color = 'r')
plt.show()

# %%
from math import floor

size = len(close) - 100
close_train, close_test = close[0:size], close[size:len(close)]
logclose_train, logclose_test = logclose[0:size], logclose[size:len(logclose)]

logreturns = np.diff(logclose).tolist()
logreturns_train, logreturns_test = logreturns[0:size-1], logreturns[size-1:len(logreturns)]

series = logreturns
train = logreturns_train
test = logreturns_test

plt.plot(series , color = 'r')
plt.show()

train = np.array(train).reshape(-1,1)

# %%
import numpy as np
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.svm import SVR
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
import hyperopt
import warnings


space = {
    "window_size": hp.choice("window_size", range(2,20)),
    "kernel": hp.choice("kernel", ["linear", "poly", "rbf"]),
    "C": hp.loguniform("C", np.log(0.001), np.log(100)),
    "epsilon": hp.loguniform("epsilon", np.log(0.00001), np.log(1)),
    "gamma": hp.choice("gamma", ["scale", "auto"]),
    "degree": hp.quniform("degree", 2, 4, 1),  
    "coef0": hp.uniform("coef0", -5, 5)      
}

def objective(params):
    window_size = params["window_size"]
    kernel = params["kernel"]
    C = params["C"]
    epsilon = params["epsilon"]

    scaler = RobustScaler()

    train_scaled = scaler.fit_transform(train)
    train_X, train_Y = [], []
    for i in range(len(train_scaled) - window_size):
        train_X.append(train_scaled[i:i+window_size])
        train_Y.append(train_scaled[i+window_size])
    new_train_X = np.array([x.reshape(-1) for x in train_X])
    new_train_Y = np.array(train_Y).ravel()

    svr_params = {"C": C, "epsilon": epsilon}
    
    if kernel == "poly":
        svr_params["gamma"] = params["gamma"]
        svr_params["degree"] = int(params["degree"]) 
        svr_params["coef0"] = (params["coef0"])     
    elif kernel == "rbf":
        svr_params["gamma"] = params["gamma"]

    model = SVR(kernel=kernel, **svr_params)

    tscv = TimeSeriesSplit(n_splits=2)
    score = np.mean(cross_val_score(model, new_train_X, new_train_Y, cv=tscv, scoring='neg_mean_squared_error', n_jobs=-1))
    
    return {"loss": -score, "status": STATUS_OK}

trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials,
            rstate=np.random.default_rng(42))

best_loss = trials.best_trial['result']['loss']
best_score = best_loss

print("\n------------------------")
print("BEST OVERALL RESULTS:")
print("------------------------")
print("Best parameters (raw indices and values):")
print(best)
print(f"Best score: {best_score:.4f}")
# Out:
# 100%|██████████| 100/100 [00:23<00:00,  4.22trial/s, best loss: 0.4790200015609306]
#
# ------------------------
# BEST OVERALL RESULTS:
# ------------------------
# Best parameters (raw indices and values):
# {'C': 41.90111620258188, 'coef0': 1.2025281854886665, 'degree': 2.0, 'epsilon': 0.024733145174492592, 'gamma': 1, 'kernel': 1, 'window_size': 1}
# Best score: 0.4790

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.svm import SVR
import numpy as np

window_sizes = range(2,20)
kernels_list = ["linear", "poly", "rbf"]
gamma_list = ["scale", "auto"]

window_size = window_sizes[best["window_size"]]
best_kernel = kernels_list[best["kernel"]]
best_gamma = gamma_list[best["gamma"]]
best_C = best["C"]
best_epsilon = best["epsilon"]
best_degree = int(best["degree"]) if best_kernel == "poly" else None
best_coef0 = (best["coef0"]) if best_kernel == "poly" else None

scaler = RobustScaler()

train_scaled = scaler.fit_transform(train)
train_X, train_Y = [], []
for i in range(0, len(train_scaled) - window_size):
    train_X.append(train_scaled[i:i+window_size])
    train_Y.append(train_scaled[i+window_size])

new_train_X = np.array([x.reshape(-1) for x in train_X])
new_train_Y = np.array(train_Y).ravel()

svr_params = {"C": best_C, "epsilon": best_epsilon}
if best_kernel == "poly":
    svr_params["gamma"] = best_gamma
    svr_params["degree"] = best_degree
    svr_params["coef0"] = best_coef0
elif best_kernel == "rbf":
    svr_params["gamma"] = best_gamma

model = SVR(kernel=best_kernel, **svr_params)

model.fit(new_train_X, new_train_Y)
# Out:
# SVR(C=41.90111620258188, coef0=1.2025281854886665, degree=2,
#     epsilon=0.024733145174492592, gamma='auto', kernel='poly')

# %%
print(window_size)
print(best_kernel)
print(best_gamma)
print(best_C)
print(best_epsilon)
print(best_degree)
print(best_coef0)
# Out:
# 3
# poly
# auto
# 41.90111620258188
# 0.024733145174492592
# 2
# 1.2025281854886665

# %%
predictions = model.predict(new_train_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))
Y = pd.DataFrame(train[window_size:])
pred = pd.DataFrame(predictions_rescaled)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()
error = mse(train[window_size:],predictions_rescaled)
print('Train MSE: %.6f' % error)
# Out:
# Train MSE: 0.001668

# %%
rawResiduals_SVR = Y - pred
plt.plot(rawResiduals_SVR)
plt.show()

rawResiduals_SVR.to_csv('rawResiduals_SVR_BO-TPE_robustscaler.csv', index=False)

# %%
test_extended = train.tolist()[-1*window_size:] + test
test_data = []
for i in test_extended:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
test_data = np.array(test_data).reshape(-1,1)
test_scaled = scaler.transform(test_data)
test_X,test_Y = [],[]
for i in range(0 , len(test_scaled) - window_size):
    test_X.append(test_scaled[i:i+window_size])
    test_Y.append(test_scaled[i+window_size])
new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)
predictions = model.predict(new_test_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))
predictions_rescaled = predictions_rescaled.flatten().tolist()

Y = pd.DataFrame(test)
pred = pd.DataFrame(predictions_rescaled)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()
error = mse(test,predictions_rescaled)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.001873

# %%
predicted_log_prices = np.zeros(len(logclose_test)) 
predicted_log_prices[0] = logclose_train[-1] + predictions_rescaled[0]

for t in range(1, len(logclose_test)):
    predicted_log_prices[t] = logclose_test[t-1] + predictions_rescaled[t] 


Y = pd.DataFrame(logclose_test)
pred = pd.DataFrame(predicted_log_prices)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()

error = mse(logclose_test,predicted_log_prices)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.001873

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on logclose: ")
print(compute_error_metrics(logclose_test, predicted_log_prices))
print(compute_directional_metrics(logclose_test, predicted_log_prices))
# Out:
# Errors on logclose:
# {'NMSE': 0.6101342170894194, 'MAE': 0.03391776903645482, 'RMSE': 0.04327463468568, 'MSE': 0.0018726940071790584, 'MAPE': 1.0678329658139651, 'TheilsU': 0.8557640334853636}
# {'DA': 0.6666666666666666, 'DS': 0.46464646464646464, 'CU': 0.4909090909090909, 'CD': 0.4318181818181818}

# %%
predicted_prices = np.exp(predicted_log_prices)
Y = pd.DataFrame(close_test)
pred = pd.DataFrame(predicted_prices)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()

error = mse(close_test,predicted_prices)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 1.081917

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on close: ")
print(compute_error_metrics(close_test, predicted_prices))
print(compute_directional_metrics(close_test, predicted_prices))
# Out:
# Errors on close:
# {'NMSE': 0.6112909297310081, 'MAE': 0.8172042827885325, 'RMSE': 1.0401525870436388, 'MSE': 1.0819174043335744, 'MAPE': 3.404105090342487, 'TheilsU': 0.851045209818665}
# {'DA': 0.6666666666666666, 'DS': 0.46464646464646464, 'CU': 0.4909090909090909, 'CD': 0.4318181818181818}

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from trading_strategies import trading_strategy1

trading_strategy1(close_test, predicted_prices)
# Out:
# Stock: 26.339 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 26339.0
# Stock: 24.591 Action: Buy Portfolio: 26336.96 Stocks: 1071 Balance_init: 2 total($) 26338.96
# Stock: 24.786 Action: Bought--Holding Portfolio: 26545.81 Stocks: 1071 Balance_init: 2 total($) 26547.81
# Stock: 25.934 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27777.31
# Stock: 26.495 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27777.31
# Stock: 23.666 Action: Buy Portfolio: 27760.22 Stocks: 1173 Balance_init: 17 total($) 27777.22
# Stock: 25.243 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29627.04
# Stock: 25.166 Action: Buy Portfolio: 29620.38 Stocks: 1177 Balance_init: 6 total($) 29626.38
# Stock: 24.793 Action: Bought--Holding Portfolio: 29181.36 Stocks: 1177 Balance_init: 6 total($) 29187.36
# Stock: 23.938 Action: Bought--Holding Portfolio: 28175.03 Stocks: 1177 Balance_init: 6 total($) 28181.03
# Stock: 24.631 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28996.69
# Stock: 24.159 Action: Buy Portfolio: 28990.8 Stocks: 1200 Balance_init: 5 total($) 28995.8
# Stock: 25.168 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30206.6
# Stock: 24.932 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30206.6
# Stock: 25.36 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30206.6
# Stock: 24.67 Action: Buy Portfolio: 30196.08 Stocks: 1224 Balance_init: 10 total($) 30206.08
# Stock: 24.249 Action: Bought--Holding Portfolio: 29680.78 Stocks: 1224 Balance_init: 10 total($) 29690.78
# Stock: 24.685 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30224.44
# Stock: 25.415 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30224.44
# Stock: 25.663 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30224.44
# Stock: 24.592 Action: Buy Portfolio: 30223.57 Stocks: 1229 Balance_init: 0 total($) 30223.57
# Stock: 25.95 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31892.55
# Stock: 21.6 Action: Buy Portfolio: 31881.6 Stocks: 1476 Balance_init: 10 total($) 31891.6
# Stock: 24.77 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 36570.52
# Stock: 26.506 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 36570.52
# Stock: 25.793 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 36570.52
# Stock: 23.931 Action: Buy Portfolio: 36566.57 Stocks: 1528 Balance_init: 3 total($) 36569.57
# Stock: 25.156 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 38441.37
# Stock: 24.679 Action: Buy Portfolio: 38425.2 Stocks: 1557 Balance_init: 16 total($) 38441.2
# Stock: 25.514 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 39741.3
# Stock: 24.493 Action: Buy Portfolio: 39727.65 Stocks: 1622 Balance_init: 13 total($) 39740.65
# Stock: 24.233 Action: Bought--Holding Portfolio: 39305.93 Stocks: 1622 Balance_init: 13 total($) 39318.93
# Stock: 25.032 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 40614.9
# Stock: 24.373 Action: Buy Portfolio: 40605.42 Stocks: 1666 Balance_init: 9 total($) 40614.42
# Stock: 24.05 Action: Bought--Holding Portfolio: 40067.3 Stocks: 1666 Balance_init: 9 total($) 40076.3
# Stock: 24.316 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 40519.46
# Stock: 24.101 Action: Buy Portfolio: 40513.78 Stocks: 1681 Balance_init: 5 total($) 40518.78
# Stock: 22.529 Action: Bought--Holding Portfolio: 37871.25 Stocks: 1681 Balance_init: 5 total($) 37876.25
# Stock: 24.468 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 41135.71
# Stock: 23.043 Action: Buy Portfolio: 41131.75 Stocks: 1785 Balance_init: 3 total($) 41134.75
# Stock: 23.437 Action: Bought--Holding Portfolio: 41835.05 Stocks: 1785 Balance_init: 3 total($) 41838.05
# Stock: 23.671 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 42255.74
# Stock: 22.916 Action: Buy Portfolio: 42234.19 Stocks: 1843 Balance_init: 21 total($) 42255.19
# Stock: 24.303 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 44811.43
# Stock: 23.573 Action: Buy Portfolio: 44788.7 Stocks: 1900 Balance_init: 22 total($) 44810.7
# Stock: 23.909 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 45449.1
# Stock: 24.397 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 45449.1
# Stock: 23.738 Action: Buy Portfolio: 45434.53 Stocks: 1914 Balance_init: 14 total($) 45448.53
# Stock: 23.837 Action: Bought--Holding Portfolio: 45624.02 Stocks: 1914 Balance_init: 14 total($) 45638.02
# Stock: 23.94 Action: Bought--Holding Portfolio: 45821.16 Stocks: 1914 Balance_init: 14 total($) 45835.16
# Stock: 22.362 Action: Bought--Holding Portfolio: 42800.87 Stocks: 1914 Balance_init: 14 total($) 42814.87
# Stock: 22.758 Action: Bought--Holding Portfolio: 43558.81 Stocks: 1914 Balance_init: 14 total($) 43572.81
# Stock: 22.035 Action: Bought--Holding Portfolio: 42174.99 Stocks: 1914 Balance_init: 14 total($) 42188.99
# Stock: 21.8 Action: Bought--Holding Portfolio: 41725.2 Stocks: 1914 Balance_init: 14 total($) 41739.2
# Stock: 23.359 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 44723.13
# Stock: 23.785 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 44723.13
# Stock: 24.091 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 44723.13
# Stock: 23.314 Action: Buy Portfolio: 44716.25 Stocks: 1918 Balance_init: 6 total($) 44722.25
# Stock: 21.596 Action: Bought--Holding Portfolio: 41421.13 Stocks: 1918 Balance_init: 6 total($) 41427.13
# Stock: 23.953 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 45947.85
# Stock: 24.457 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 45947.85
# Stock: 24.753 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 45947.85
# Stock: 22.633 Action: Buy Portfolio: 45944.99 Stocks: 2030 Balance_init: 2 total($) 45946.99
# Stock: 23.979 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 48679.37
# Stock:
# 22.821 Action: Buy Portfolio: 48677.19 Stocks: 2133 Balance_init: 2 total($) 48679.19
# Stock: 24.459 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 52173.05
# Stock: 25.466 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 52173.05
# Stock: 26.374 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 52173.05
# Stock: 26.473 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 52173.05
# Stock: 24.702 Action: Buy Portfolio: 52170.62 Stocks: 2112 Balance_init: 2 total($) 52172.62
# Stock: 25.515 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 53889.68
# Stock: 24.997 Action: Buy Portfolio: 53868.53 Stocks: 2155 Balance_init: 21 total($) 53889.53
# Stock: 25.238 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 54408.89
# Stock: 23.93 Action: Buy Portfolio: 54392.89 Stocks: 2273 Balance_init: 16 total($) 54408.89
# Stock: 25.122 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 57118.31
# Stock: 23.431 Action: Buy Portfolio: 57101.35 Stocks: 2437 Balance_init: 16 total($) 57117.35
# Stock: 24.343 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 59339.89
# Stock: 23.245 Action: Buy Portfolio: 59321.24 Stocks: 2552 Balance_init: 18 total($) 59339.24
# Stock: 23.396 Action: Bought--Holding Portfolio: 59706.59 Stocks: 2552 Balance_init: 18 total($) 59724.59
# Stock: 23.498 Action: Bought--Holding Portfolio: 59966.9 Stocks: 2552 Balance_init: 18 total($) 59984.9
# Stock: 22.328 Action: Bought--Holding Portfolio: 56981.06 Stocks: 2552 Balance_init: 18 total($) 56999.06
# Stock: 21.8 Action: Bought--Holding Portfolio: 55633.6 Stocks: 2552 Balance_init: 18 total($) 55651.6
# Stock: 22.647 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 57813.14
# Stock: 24.258 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 57813.14
# Stock: 21.807 Action: Buy Portfolio: 57810.36 Stocks: 2651 Balance_init: 2 total($) 57812.36
# Stock: 21.374 Action: Bought--Holding Portfolio: 56662.47 Stocks: 2651 Balance_init: 2 total($) 56664.47
# Stock: 21.691 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 57504.84
# Stock: 21.558 Action: Buy Portfolio: 57495.19 Stocks: 2667 Balance_init: 9 total($) 57504.19
# Stock: 22.146 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 59072.38
# Stock: 22.16 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 59072.38
# Stock: 22.069 Action: Buy Portfolio: 59056.64 Stocks: 2676 Balance_init: 15 total($) 59071.64
# Stock: 23.584 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 63125.78
# Stock: 23.1 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 63125.78
# Stock: 24.253 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 63125.78
# Stock: 24.368 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 63125.78
# Stock: 25.048 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 63125.78
# Stock: 23.371 Action: Buy Portfolio: 63125.07 Stocks: 2701 Balance_init: 0 total($) 63125.07
# Stock: 25.455 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 68753.96
# Stock: 27.2 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 68753.96
# Final value of stock:
# 27601.0
# Final value of portfolio:
# 68754.0
# TS=
# 2.4909967030180065

# %%
68754/(1000*27.601)
# Out:
# 2.4909967030180065
