# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_squared_error as mse

# %%
import pandas as pd

csv_file_path = 'close.csv'

df = pd.read_csv(csv_file_path, header=None)

close = df[0].tolist()
logclose = np.log(close).tolist()


plt.plot(close , color = 'r')
plt.show()

# %%
from math import floor

size = len(close) - 100
close_train, close_test = close[0:size], close[size:len(close)]
logclose_train, logclose_test = logclose[0:size], logclose[size:len(logclose)]

logreturns = np.diff(logclose).tolist()
logreturns_train, logreturns_test = logreturns[0:size-1], logreturns[size-1:len(logreturns)]

series = logreturns
train = logreturns_train
test = logreturns_test

plt.plot(series , color = 'r')
plt.show()

train = np.array(train).reshape(-1,1)

# %%
import numpy as np
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.svm import SVR
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
import hyperopt
import warnings


space = {
    "window_size": hp.choice("window_size", range(2,20)),
    "kernel": hp.choice("kernel", ["linear", "poly", "rbf"]),
    "C": hp.loguniform("C", np.log(0.001), np.log(100)),
    "epsilon": hp.loguniform("epsilon", np.log(0.00001), np.log(1)),
    "gamma": hp.choice("gamma", ["scale", "auto"]),
    "degree": hp.quniform("degree", 2, 4, 1),  
    "coef0": hp.uniform("coef0", -5, 5)      
}

def objective(params):
    window_size = params["window_size"]
    kernel = params["kernel"]
    C = params["C"]
    epsilon = params["epsilon"]

    scaler = StandardScaler()

    train_scaled = scaler.fit_transform(train)
    train_X, train_Y = [], []
    for i in range(len(train_scaled) - window_size):
        train_X.append(train_scaled[i:i+window_size])
        train_Y.append(train_scaled[i+window_size])
    new_train_X = np.array([x.reshape(-1) for x in train_X])
    new_train_Y = np.array(train_Y).ravel()

    svr_params = {"C": C, "epsilon": epsilon}
    
    if kernel == "poly":
        svr_params["gamma"] = params["gamma"]
        svr_params["degree"] = int(params["degree"]) 
        svr_params["coef0"] = (params["coef0"])   
    elif kernel == "rbf":
        svr_params["gamma"] = params["gamma"]

    model = SVR(kernel=kernel, **svr_params)

    tscv = TimeSeriesSplit(n_splits=2)
    score = np.mean(cross_val_score(model, new_train_X, new_train_Y, cv=tscv, scoring='neg_mean_squared_error', n_jobs=-1))
    
    return {"loss": -score, "status": STATUS_OK}

trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials,
            rstate=np.random.default_rng(42))

best_loss = trials.best_trial['result']['loss']
best_score = best_loss

print("\n------------------------")
print("BEST OVERALL RESULTS:")
print("------------------------")
print("Best parameters (raw indices and values):")
print(best)
print(f"Best score: {best_score:.4f}")
# Out:
# 100%|██████████| 100/100 [00:35<00:00,  2.80trial/s, best loss: 1.1816788399767255]
#
# ------------------------
# BEST OVERALL RESULTS:
# ------------------------
# Best parameters (raw indices and values):
# {'C': 0.02121440727791672, 'coef0': 1.5108106085656365, 'degree': 2.0, 'epsilon': 0.715523748715019, 'gamma': 1, 'kernel': 0, 'window_size': 0}
# Best score: 1.1817

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.svm import SVR
import numpy as np

window_sizes = range(2,20)
kernels_list = ["linear", "poly", "rbf"]
gamma_list = ["scale", "auto"]

window_size = window_sizes[best["window_size"]]
best_kernel = kernels_list[best["kernel"]]
best_gamma = gamma_list[best["gamma"]]
best_C = best["C"]
best_epsilon = best["epsilon"]
best_degree = int(best["degree"]) if best_kernel == "poly" else None
best_coef0 = (best["coef0"]) if best_kernel == "poly" else None

scaler = StandardScaler()

train_scaled = scaler.fit_transform(train)
train_X, train_Y = [], []
for i in range(0, len(train_scaled) - window_size):
    train_X.append(train_scaled[i:i+window_size])
    train_Y.append(train_scaled[i+window_size])

new_train_X = np.array([x.reshape(-1) for x in train_X])
new_train_Y = np.array(train_Y).ravel()

svr_params = {"C": best_C, "epsilon": best_epsilon}
if best_kernel == "poly":
    svr_params["gamma"] = best_gamma
    svr_params["degree"] = best_degree
    svr_params["coef0"] = best_coef0
elif best_kernel == "rbf":
    svr_params["gamma"] = best_gamma

model = SVR(kernel=best_kernel, **svr_params)

model.fit(new_train_X, new_train_Y)
# Out:
# SVR(C=0.02121440727791672, epsilon=0.715523748715019, kernel='linear')

# %%
print(window_size)
print(best_kernel)
print(best_gamma)
print(best_C)
print(best_epsilon)
print(best_degree)
print(best_coef0)
# Out:
# 2
# linear
# auto
# 0.02121440727791672
# 0.715523748715019
# None
# None

# %%
predictions = model.predict(new_train_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))
Y = pd.DataFrame(train[window_size:])
pred = pd.DataFrame(predictions_rescaled)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()
error = mse(train[window_size:],predictions_rescaled)
print('Train MSE: %.10f' % error)
# Out:
# Train MSE: 0.0004703337

# %%
rawResiduals_SVR = Y - pred
plt.plot(rawResiduals_SVR)
plt.show()

rawResiduals_SVR.to_csv('rawResiduals_SVR_BO-TPE_standardscaler.csv', index=False)

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox

lags=np.ceil(np.log(len(rawResiduals_SVR)))

plt.figure(figsize=(10, 5))
plot_acf(rawResiduals_SVR, lags=lags, alpha=0.05)
plt.title('Autocorrelation Function (ACF)')
plt.show()

plt.figure(figsize=(10, 5))
plot_pacf(rawResiduals_SVR, lags=lags, alpha=0.05, method='ywm')
plt.title('Partial Autocorrelation Function (PACF)')
plt.show()

pd.options.display.float_format = '{:.4e}'.format

lbq_test = acorr_ljungbox(rawResiduals_SVR, lags=lags, return_df=True)
print(lbq_test)
# Out:
#      lb_stat  lb_pvalue
# 1 3.1458e-01 5.7488e-01
# 2 3.0668e+00 2.1580e-01
# 3 3.1366e+00 3.7104e-01
# 4 8.1085e+00 8.7685e-02
# 5 8.1135e+00 1.5009e-01
# 6 2.6911e+01 1.5046e-04
# 7 2.8392e+01 1.8669e-04
# 8 4.1987e+01 1.3619e-06

# %%
test_extended = train.tolist()[-1*window_size:] + test
test_data = []
for i in test_extended:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
test_data = np.array(test_data).reshape(-1,1)
test_scaled = scaler.transform(test_data)
test_X,test_Y = [],[]
for i in range(0 , len(test_scaled) - window_size):
    test_X.append(test_scaled[i:i+window_size])
    test_Y.append(test_scaled[i+window_size])
new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)
predictions = model.predict(new_test_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))
predictions_rescaled = predictions_rescaled.flatten().tolist()

Y = pd.DataFrame(test)
pred = pd.DataFrame(predictions_rescaled)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()
error = mse(test,predictions_rescaled)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000530

# %%
predicted_log_prices = np.zeros(len(logclose_test)) 
predicted_log_prices[0] = logclose_train[-1] + predictions_rescaled[0]

for t in range(1, len(logclose_test)):
    predicted_log_prices[t] = logclose_test[t-1] + predictions_rescaled[t] 


Y = pd.DataFrame(logclose_test)
pred = pd.DataFrame(predicted_log_prices)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()

error = mse(logclose_test,predicted_log_prices)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000530

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on logclose: ")
print(compute_error_metrics(logclose_test, predicted_log_prices))
print(compute_directional_metrics(logclose_test, predicted_log_prices))
# Out:
# Errors on logclose:
# {'NMSE': 0.09365061036909669, 'MAE': 0.014582651625566191, 'RMSE': 0.023026925018381276, 'MSE': 0.0005302392758021535, 'MAPE': 0.4112837378271342, 'TheilsU': 0.9959689971288366}
# {'DA': 0.5151515151515151, 'DS': 0.5252525252525253, 'CU': 0.5964912280701754, 'CD': 0.42857142857142855}

# %%
predicted_prices = np.exp(predicted_log_prices)
Y = pd.DataFrame(close_test)
pred = pd.DataFrame(predicted_prices)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()

error = mse(close_test,predicted_prices)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.652664

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on close: ")
print(compute_error_metrics(close_test, predicted_prices))
print(compute_directional_metrics(close_test, predicted_prices))
# Out:
# Errors on close:
# {'NMSE': 0.10651531238883007, 'MAE': 0.5041485486197729, 'RMSE': 0.8078763118968458, 'MSE': 0.6526641353240497, 'MAPE': 1.4495028878800036, 'TheilsU': 0.9958156865738355}
# {'DA': 0.5151515151515151, 'DS': 0.5252525252525253, 'CU': 0.5964912280701754, 'CD': 0.42857142857142855}

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from trading_strategies import trading_strategy1

trading_strategy1(close_test, predicted_prices)
# Out:
# Stock: 28.09 Action: Buy Portfolio: 28090.0 Stocks: 1000 Balance_init: 0 total($) 28090.0
# Stock: 27.75 Action: Bought--Holding Portfolio: 27750.0 Stocks: 1000 Balance_init: 0 total($) 27750.0
# Stock: 27.94 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27940.0
# Stock: 28.18 Action: Buy Portfolio: 27926.38 Stocks: 991 Balance_init: 13 total($) 27939.38
# Stock: 28.42 Action: Bought--Holding Portfolio: 28164.22 Stocks: 991 Balance_init: 13 total($) 28177.22
# Stock: 28.41 Action: Bought--Holding Portfolio: 28154.31 Stocks: 991 Balance_init: 13 total($) 28167.31
# Stock: 29.44 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29188.04
# Stock: 29.65 Action: Buy Portfolio: 29175.6 Stocks: 984 Balance_init: 12 total($) 29187.6
# Stock: 29.72 Action: Bought--Holding Portfolio: 29244.48 Stocks: 984 Balance_init: 12 total($) 29256.48
# Stock: 29.94 Action: Bought--Holding Portfolio: 29460.96 Stocks: 984 Balance_init: 12 total($) 29472.96
# Stock: 30.76 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30279.84
# Stock: 31.36 Action: Buy Portfolio: 30262.4 Stocks: 965 Balance_init: 17 total($) 30279.4
# Stock: 31.07 Action: Bought--Holding Portfolio: 29982.55 Stocks: 965 Balance_init: 17 total($) 29999.55
# Stock: 31.19 Action: Bought--Holding Portfolio: 30098.35 Stocks: 965 Balance_init: 17 total($) 30115.35
# Stock: 31.82 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30723.3
# Stock: 32.69 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30723.3
# Stock: 33.01 Action: Buy Portfolio: 30699.3 Stocks: 930 Balance_init: 24 total($) 30723.3
# Stock: 32.65 Action: Bought--Holding Portfolio: 30364.5 Stocks: 930 Balance_init: 24 total($) 30388.5
# Stock: 32.75 Action: Bought--Holding Portfolio: 30457.5 Stocks: 930 Balance_init: 24 total($) 30481.5
# Stock: 33.14 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 30844.2
# Stock: 32.8 Action: Buy Portfolio: 30832.0 Stocks: 940 Balance_init: 12 total($) 30844.0
# Stock: 38.36 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 36070.4
# Stock: 36.5 Action: Buy Portfolio: 36062.0 Stocks: 988 Balance_init: 8 total($) 36070.0
# Stock: 35.32 Action: Bought--Holding Portfolio: 34896.16 Stocks: 988 Balance_init: 8 total($) 34904.16
# Stock: 35.35 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34933.8
# Stock: 35.63 Action: Buy Portfolio: 34917.4 Stocks: 980 Balance_init: 16 total($) 34933.4
# Stock: 36.18 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 35472.4
# Stock: 36.45 Action: Buy Portfolio: 35465.85 Stocks: 973 Balance_init: 6 total($) 35471.85
# Stock: 36.18 Action: Bought--Holding Portfolio: 35203.14 Stocks: 973 Balance_init: 6 total($) 35209.14
# Stock: 36.32 Action: Bought--Holding Portfolio: 35339.36 Stocks: 973 Balance_init: 6 total($) 35345.36
# Stock: 36.3 Action: Bought--Holding Portfolio: 35319.9 Stocks: 973 Balance_init: 6 total($) 35325.9
# Stock: 36.45 Action: Bought--Holding Portfolio: 35465.85 Stocks: 973 Balance_init: 6 total($) 35471.85
# Stock: 35.51 Action: Bought--Holding Portfolio: 34551.23 Stocks: 973 Balance_init: 6 total($) 34557.23
# Stock: 35.93 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34965.89
# Stock: 36.75 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34965.89
# Stock: 36.24 Action: Buy Portfolio: 34935.36 Stocks: 964 Balance_init: 30 total($) 34965.36
# Stock: 36.37 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 35090.68
# Stock: 36.3 Action: Buy Portfolio: 35065.8 Stocks: 966 Balance_init: 24 total($) 35089.8
# Stock: 36.27 Action: Bought--Holding Portfolio: 35036.82 Stocks: 966 Balance_init: 24 total($) 35060.82
# Stock: 35.09 Action: Bought--Holding Portfolio: 33896.94 Stocks: 966 Balance_init: 24 total($) 33920.94
# Stock: 34.71 Action: Bought--Holding Portfolio: 33529.86 Stocks: 966 Balance_init: 24 total($) 33553.86
# Stock: 35.02 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33853.32
# Stock: 34.97 Action: Buy Portfolio: 33850.96 Stocks: 968 Balance_init: 2 total($) 33852.96
# Stock: 34.8 Action: Bought--Holding Portfolio: 33686.4 Stocks: 968 Balance_init: 2 total($) 33688.4
# Stock: 34.85 Action: Bought--Holding Portfolio: 33734.8 Stocks: 968 Balance_init: 2 total($) 33736.8
# Stock: 34.63 Action: Bought--Holding Portfolio: 33521.84 Stocks: 968 Balance_init: 2 total($) 33523.84
# Stock: 35.32 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34191.76
# Stock: 35.42 Action: Buy Portfolio: 34180.3 Stocks: 965 Balance_init: 11 total($) 34191.3
# Stock: 36.07 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34818.55
# Stock: 36.1 Action: Buy Portfolio: 34800.4 Stocks: 964 Balance_init: 18 total($) 34818.4
# Stock: 36.73 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 35425.72
# Stock: 37.34 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 35425.72
# Stock: 38.0 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 35425.72
# Stock: 38.11 Action: Buy Portfolio: 35404.19 Stocks: 929 Balance_init: 21 total($) 35425.19
# Stock: 37.38 Action: Bought--Holding Portfolio: 34726.02 Stocks: 929 Balance_init: 21 total($) 34747.02
# Stock: 37.15 Action: Bought--Holding Portfolio: 34512.35 Stocks: 929 Balance_init: 21 total($) 34533.35
# Stock: 38.02 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 35341.58
# Stock: 37.71 Action: Buy Portfolio: 35334.27 Stocks: 937 Balance_init: 7 total($) 35341.27
# Stock: 37.82 Action: Bought--Holding Portfolio: 35437.34 Stocks: 937 Balance_init: 7 total($) 35444.34
# Stock: 36.25 Action: Bought--Holding Portfolio: 33966.25 Stocks: 937 Balance_init: 7 total($) 33973.25
# Stock: 36.34 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34057.58
# Stock: 36.13 Action: Buy Portfolio: 34034.46 Stocks: 942 Balance_init: 23 total($) 34057.46
# Stock: 35.52 Action: Bought--Holding Portfolio: 33459.84 Stocks: 942 Balance_init: 23 total($) 33482.84
# Stock: 36.09 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34019.78
# Stock: 35.17 Action: Buy Portfolio: 34009.39 Stocks: 967 Balance_init: 10 total($) 34019.39
# Stock: 33.72 Action: Bought--Holding Portfolio: 32607.24 Stocks: 967 Balance_init: 10 total($) 32617.24
# Stock: 32.75 Action: Bought--Holding Portfolio: 31669.25 Stocks: 967 Balance_init: 10 total($) 31679.25
# Stock: 32.72 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31650.24
# Stock: 32.02 Action: Buy Portfolio: 31635.76 Stocks: 988 Balance_init: 14 total($) 31649.76
# Stock: 33.02 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32637.76
# Stock: 33.54 Action: Buy Portfolio: 32634.42 Stocks: 973 Balance_init: 3 total($) 32637.42
# Stock: 33.78 Action: Bought--Holding Portfolio: 32867.94 Stocks: 973 Balance_init: 3 total($) 32870.94
# Stock: 34.76 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33824.48
# Stock: 34.75 Action: Buy Portfolio: 33811.75 Stocks: 973 Balance_init: 12 total($) 33823.75
# Stock: 35.49 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34543.77
# Stock: 35.91 Action: Buy Portfolio: 34509.51 Stocks: 961 Balance_init: 34 total($) 34543.51
# Stock: 34.6 Action: Bought--Holding Portfolio: 33250.6 Stocks: 961 Balance_init: 34 total($) 33284.6
# Stock: 34.81 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33486.41
# Stock: 35.27 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33486.41
# Stock: 35.08 Action: Buy Portfolio: 33466.32 Stocks: 954 Balance_init: 20 total($) 33486.32
# Stock: 35.66 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34039.64
# Stock: 35.57 Action: Buy Portfolio: 34004.92 Stocks: 956 Balance_init: 34 total($) 34038.92
# Stock: 35.6 Action: Bought--Holding Portfolio: 34033.6 Stocks: 956 Balance_init: 34 total($) 34067.6
# Stock: 34.76 Action: Bought--Holding Portfolio: 33230.56 Stocks: 956 Balance_init: 34 total($) 33264.56
# Stock: 35.46 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33933.76
# Stock: 36.18 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33933.76
# Stock: 35.38 Action: Buy Portfolio: 33929.42 Stocks: 959 Balance_init: 4 total($) 33933.42
# Stock: 35.33 Action: Bought--Holding Portfolio: 33881.47 Stocks: 959 Balance_init: 4 total($) 33885.47
# Stock: 34.4 Action: Bought--Holding Portfolio: 32989.6 Stocks: 959 Balance_init: 4 total($) 32993.6
# Stock: 33.82 Action: Bought--Holding Portfolio: 32433.38 Stocks: 959 Balance_init: 4 total($) 32437.38
# Stock: 34.18 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32782.62
# Stock: 33.47 Action: Buy Portfolio: 32767.13 Stocks: 979 Balance_init: 15 total($) 32782.13
# Stock: 33.37 Action: Bought--Holding Portfolio: 32669.23 Stocks: 979 Balance_init: 15 total($) 32684.23
# Stock: 33.1 Action: Bought--Holding Portfolio: 32404.9 Stocks: 979 Balance_init: 15 total($) 32419.9
# Stock: 33.32 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32635.28
# Stock: 33.76 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32635.28
# Stock: 34.43 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32635.28
# Stock: 34.53 Action: Buy Portfolio: 32630.85 Stocks: 945 Balance_init: 4 total($) 32634.85
# Stock: 34.82 Action: Bought--Holding Portfolio: 32904.9 Stocks: 945 Balance_init: 4 total($) 32908.9
# Final value of stock:
# 34760.0
# Final value of portfolio:
# 32909.0
# TS=
# 0.9467491369390103
