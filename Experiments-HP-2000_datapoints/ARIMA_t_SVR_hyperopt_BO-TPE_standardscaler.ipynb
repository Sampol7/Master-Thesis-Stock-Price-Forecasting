# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_squared_error as mse

# %%
import pandas as pd

csv_file_path = 'close.csv'

df = pd.read_csv(csv_file_path, header=None)

close = df[0].tolist()
logclose = np.log(close).tolist()
logclose_series = pd.Series(logclose)
logreturns = np.array(logclose_series.diff().dropna()).tolist()

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, axes = plt.subplots(2, 1,figsize=(6, 6)) 

lags=np.ceil(np.log(len(logreturns)))

plot_acf(logreturns, ax=axes[0], lags=lags)  
axes[0].set_title('')
axes[0].set_xlabel('Lags', fontsize=20)
axes[0].set_ylabel('ACF', fontsize=20)
axes[0].tick_params(axis='both', which='major', labelsize=16) 

plot_pacf(logreturns, ax=axes[1], lags=lags, method='ywm') 
axes[1].set_title('')
axes[1].set_xlabel('Lags', fontsize=20)
axes[1].set_ylabel('PACF', fontsize=20)
axes[1].tick_params(axis='both', which='major', labelsize=16) 

fig.suptitle('Correlation in Training Log Returns', fontsize=24)


plt.tight_layout()
plt.show()

# %%
from math import floor

size = len(logclose)-100
close_train, close_test = close[0:size], close[size:len(close)]
logclose_train, logclose_test = logclose[0:size], logclose[size:len(logclose)]

series = logclose
train = logclose_train
test = logclose_test

plt.plot(series , color = 'r')
plt.show()

# %%
predicted_list, error_list = [], []
training_data = train

# %%
import pandas as pd

csv_file_path = 'forecasted_logclose_ARIMA_t.csv'

df = pd.read_csv(csv_file_path, header=None)

predicted_list = df[0].tolist()

print(predicted_list)
# Out:
# [3.3426, 3.3371, 3.3246, 3.3308, 3.3397, 3.348, 3.3481, 3.3819, 3.3914, 3.3924, 3.4004, 3.4262, 3.4466, 3.4379, 3.4408, 3.4607, 3.4875, 3.4981, 3.4875, 3.4897, 3.5017, 3.4922, 3.641, 3.6052, 3.5629, 3.5682, 3.5729, 3.5899, 3.5967, 3.5903, 3.593, 3.5934, 3.5967, 3.5724, 3.5814, 3.6052, 3.592, 3.5944, 3.5935, 3.5919, 3.5607, 3.5477, 3.5571, 3.5558, 3.551, 3.5521, 3.5463, 3.5645, 3.569, 3.5855, 3.5882, 3.6036, 3.6213, 3.638, 3.642, 3.6229, 3.616, 3.6384, 3.6321, 3.6333, 3.5939, 3.5926, 3.5895, 3.5712, 3.5865, 3.5629, 3.5201, 3.4908, 3.4888, 3.4687, 3.4962, 3.5146, 3.5203, 3.5489, 3.5499, 3.5692, 3.5825, 3.5465, 3.5499, 3.5644, 3.5589, 3.5744, 3.5733, 3.5731, 3.551, 3.5679, 3.5899, 3.5682, 3.5654, 3.5407, 3.5221, 3.5325, 3.513, 3.5083, 3.5014, 3.5066, 3.5204, 3.5393, 3.5434, 3.5508]

# %%
for t in range(len(test)):
    predicted_value = predicted_list[t]
    obs = test[t]
    error_list.append(obs - predicted_value)
    training_data.append(obs)
    print('predicted=%f, expected=%f error=%f' % (predicted_value, obs,abs(predicted_value-obs)))
# Out:
# predicted=3.342600, expected=3.335414 error=0.007186
# predicted=3.337100, expected=3.323236 error=0.013864
# predicted=3.324600, expected=3.330059 error=0.005459
# predicted=3.330800, expected=3.338613 error=0.007813
# predicted=3.339700, expected=3.347093 error=0.007393
# predicted=3.348000, expected=3.346741 error=0.001259
# predicted=3.348100, expected=3.382354 error=0.034254
# predicted=3.381900, expected=3.389462 error=0.007562
# predicted=3.391400, expected=3.391820 error=0.000420
# predicted=3.392400, expected=3.399195 error=0.006795
# predicted=3.400400, expected=3.426215 error=0.025815
# predicted=3.426200, expected=3.445533 error=0.019333
# predicted=3.446600, expected=3.436243 error=0.010357
# predicted=3.437900, expected=3.440098 error=0.002198
# predicted=3.440800, expected=3.460095 error=0.019295
# predicted=3.460700, expected=3.487069 error=0.026369
# predicted=3.487500, expected=3.496811 error=0.009311
# predicted=3.498100, expected=3.485845 error=0.012255
# predicted=3.487500, expected=3.488903 error=0.001403
# predicted=3.489700, expected=3.500741 error=0.011041
# predicted=3.501700, expected=3.490429 error=0.011271
# predicted=3.492200, expected=3.647015 error=0.154815
# predicted=3.641000, expected=3.597312 error=0.043688
# predicted=3.605200, expected=3.564449 error=0.040751
# predicted=3.562900, expected=3.565298 error=0.002398
# predicted=3.568200, expected=3.573188 error=0.004988
# predicted=3.572900, expected=3.588506 error=0.015606
# predicted=3.589900, expected=3.595941 error=0.006041
# predicted=3.596700, expected=3.588506 error=0.008194
# predicted=3.590300, expected=3.592369 error=0.002069
# predicted=3.593000, expected=3.591818 error=0.001182
# predicted=3.593400, expected=3.595941 error=0.002541
# predicted=3.596700, expected=3.569814 error=0.026886
# predicted=3.572400, expected=3.581573 error=0.009173
# predicted=3.581400, expected=3.604138 error=0.022738
# predicted=3.605200, expected=3.590163 error=0.015037
# predicted=3.592000, expected=3.593744 error=0.001744
# predicted=3.594400, expected=3.591818 error=0.002582
# predicted=3.593500, expected=3.590991 error=0.002509
# predicted=3.591900, expected=3.557916 error=0.033984
# predicted=3.560700, expected=3.547028 error=0.013672
# predicted=3.547700, expected=3.555919 error=0.008219
# predicted=3.557100, expected=3.554491 error=0.002609
# predicted=3.555800, expected=3.549617 error=0.006183
# predicted=3.551000, expected=3.551053 error=0.000053
# predicted=3.552100, expected=3.544720 error=0.007380
# predicted=3.546300, expected=3.564449 error=0.018149
# predicted=3.564500, expected=3.567277 error=0.002777
# predicted=3.569000, expected=3.585461 error=0.016461
# predicted=3.585500, expected=3.586293 error=0.000793
# predicted=3.588200, expected=3.603594 error=0.015394
# predicted=3.603600, expected=3.620065 error=0.016465
# predicted=3.621300, expected=3.637586 error=0.016286
# predicted=3.638000, expected=3.640477 error=0.002477
# predicted=3.642000, expected=3.621136 error=0.020864
# predicted=3.622900, expected=3.614964 error=0.007936
# predicted=3.616000, expected=3.638112 error=0.022112
# predicted=3.638400, expected=3.629925 error=0.008475
# predicted=3.632100, expected=3.632838 error=0.000738
# predicted=3.633300, expected=3.590439 error=0.042861
# predicted=3.593900, expected=3.592919 error=0.000981
# predicted=3.592600, expected=3.587124 error=0.005476
# predicted=3.589500, expected=3.570096 error=0.019404
# predicted=3.571200, expected=3.586016 error=0.014816
# predicted=3.586500, expected=3.560193 error=0.026307
# predicted=3.562900, expected=3.518091 error=0.044809
# predicted=3.520100, expected=3.488903 error=0.031197
# predicted=3.490800, expected=3.487987 error=0.002813
# predicted=3.488800, expected=3.466361 error=0.022439
# predicted=3.468700, expected=3.497113 error=0.028413
# predicted=3.496200, expected=3.512739 error=0.016539
# predicted=3.514600, expected=3.519869 error=0.005269
# predicted=3.520300, expected=3.548467 error=0.028167
# predicted=3.548900, expected=3.548180 error=0.000720
# predicted=3.549900, expected=3.569251 error=0.019351
# predicted=3.569200, expected=3.581016 error=0.011816
# predicted=3.582500, expected=3.543854 error=0.038646
# predicted=3.546500, expected=3.549905 error=0.003405
# predicted=3.549900, expected=3.563033 error=0.013133
# predicted=3.564400, expected=3.557631 error=0.006769
# predicted=3.558900, expected=3.574030 error=0.015130
# predicted=3.574400, expected=3.571503 error=0.002897
# predicted=3.573300, expected=3.572346 error=0.000954
# predicted=3.573100, expected=3.548467 error=0.024633
# predicted=3.551000, expected=3.568405 error=0.017405
# predicted=3.567900, expected=3.588506 error=0.020606
# predicted=3.589900, expected=3.566147 error=0.023753
# predicted=3.568200, expected=3.564732 error=0.003468
# predicted=3.565400, expected=3.538057 error=0.027343
# predicted=3.540700, expected=3.521052 error=0.019648
# predicted=3.522100, expected=3.531641 error=0.009541
# predicted=3.532500, expected=3.510650 error=0.021850
# predicted=3.513000, expected=3.507657 error=0.005343
# predicted=3.508300, expected=3.499533 error=0.008767
# predicted=3.501400, expected=3.506158 error=0.004758
# predicted=3.506600, expected=3.519277 error=0.012677
# predicted=3.520400, expected=3.538928 error=0.018528
# predicted=3.539300, expected=3.541829 error=0.002529
# predicted=3.543400, expected=3.550192 error=0.006792
# predicted=3.550800, expected=3.548467 error=0.002333

# %%
error = mse(test, predicted_list)
print('Test MSE: %.3f' % error)
# Out:
# Test MSE: 0.001

# %%
import pandas as pd

csv_file_path = 'rawResiduals_ARIMA_t.csv'

df = pd.read_csv(csv_file_path, header=None)

training_error = np.array(df[0].tolist())

print(training_error)
# Out:
# [-0.00073077 -0.0080551  -0.0092136  ...  0.00040223 -0.0060988
#   0.0083882 ]

# %%
plt.plot(test)
plt.plot(predicted_list, color='red')
plt.show()

error = mse(test,predicted_list)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000532

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error as mse

# %%
import numpy as np
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.svm import SVR
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
import hyperopt
import warnings

training_error = np.array(training_error).reshape(-1,1)

space = {
    "window_size": hp.choice("window_size", range(2,20)),
    "kernel": hp.choice("kernel", ["linear", "poly", "rbf"]),
    "C": hp.loguniform("C", np.log(0.001), np.log(100)),
    "epsilon": hp.loguniform("epsilon", np.log(0.00001), np.log(1)),
    "gamma": hp.choice("gamma", ["scale", "auto"]),
    "degree": hp.quniform("degree", 2, 4, 1),  
    "coef0": hp.uniform("coef0", -5, 5)      
}

def objective(params):
    window_size = params["window_size"]
    kernel = params["kernel"]
    C = params["C"]
    epsilon = params["epsilon"]

    scaler = StandardScaler()

    training_error_scaled = scaler.fit_transform(training_error)
    train_X, train_Y = [], []
    for i in range(len(training_error_scaled) - window_size):
        train_X.append(training_error_scaled[i:i+window_size])
        train_Y.append(training_error_scaled[i+window_size])
    new_train_X = np.array([x.reshape(-1) for x in train_X])
    new_train_Y = np.array(train_Y).ravel()

    svr_params = {"C": C, "epsilon": epsilon}
    
    if kernel == "poly":
        svr_params["gamma"] = params["gamma"]
        svr_params["degree"] = int(params["degree"]) 
        svr_params["coef0"] = (params["coef0"])    
    elif kernel == "rbf":
        svr_params["gamma"] = params["gamma"]

    model = SVR(kernel=kernel, **svr_params)

    tscv = TimeSeriesSplit(n_splits=2)
    score = np.mean(cross_val_score(model, new_train_X, new_train_Y, cv=tscv, scoring='neg_mean_squared_error', n_jobs=-1))
    
    return {"loss": -score, "status": STATUS_OK}

trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials,
            rstate=np.random.default_rng(42))

best_loss = trials.best_trial['result']['loss']
best_score = best_loss

print("\n------------------------")
print("BEST OVERALL RESULTS:")
print("------------------------")
print("Best parameters (raw indices and values):")
print(best)
print(f"Best score: {best_score:.4f}")
# Out:
# 100%|██████████| 100/100 [00:47<00:00,  2.11trial/s, best loss: 1.183925866515653]
#
# ------------------------
# BEST OVERALL RESULTS:
# ------------------------
# Best parameters (raw indices and values):
# {'C': 2.3429297648029874, 'coef0': -1.6470337914496567, 'degree': 2.0, 'epsilon': 0.8114240059376079, 'gamma': 1, 'kernel': 0, 'window_size': 2}
# Best score: 1.1839

# %%
from sklearn.preprocessing import RobustScaler, RobustScaler
from sklearn.svm import SVR
import numpy as np

window_sizes = range(2,20)
kernels_list = ["linear", "poly", "rbf"]
gamma_list = ["scale", "auto"]

window_size = window_sizes[best["window_size"]]
best_kernel = kernels_list[best["kernel"]]
best_gamma = gamma_list[best["gamma"]]
best_C = best["C"]
best_epsilon = best["epsilon"]
best_degree = int(best["degree"]) if best_kernel == "poly" else None
best_coef0 = (best["coef0"]) if best_kernel == "poly" else None

scaler = StandardScaler()

training_error_scaled = scaler.fit_transform(training_error)
train_X, train_Y = [], []
for i in range(0, len(training_error_scaled) - window_size):
    train_X.append(training_error_scaled[i:i+window_size])
    train_Y.append(training_error_scaled[i+window_size])

new_train_X = np.array([x.reshape(-1) for x in train_X])
new_train_Y = np.array(train_Y).ravel()

svr_params = {"C": best_C, "epsilon": best_epsilon}
if best_kernel == "poly":
    svr_params["gamma"] = best_gamma
    svr_params["degree"] = best_degree
    svr_params["coef0"] = best_coef0
elif best_kernel == "rbf":
    svr_params["gamma"] = best_gamma

model = SVR(kernel=best_kernel, **svr_params)

model.fit(new_train_X, new_train_Y)
# Out:
# SVR(C=2.3429297648029874, epsilon=0.8114240059376079, kernel='linear')

# %%
print(window_size)
print(best_kernel)
print(best_gamma)
print(best_C)
print(best_epsilon)
print(best_degree)
print(best_coef0)
# Out:
# 4
# linear
# auto
# 2.3429297648029874
# 0.8114240059376079
# None
# None

# %%
predictions = model.predict(new_train_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))

error = mse(training_error[window_size:],predictions_rescaled)
print('Train MSE: %.10f' % error)

Y = pd.DataFrame(training_error[window_size:])
pred = pd.DataFrame(predictions_rescaled)
plt.plot(Y, label='Real Residuals')
plt.plot(pred , color = 'r', label='Residual Predictions')
plt.xlabel('Time', fontsize=16)  
plt.ylabel('Value', fontsize=16) 
plt.ylim([-0.18,0.18]) 
plt.title('ML Predictions On ARIMA-t Residuals', fontsize=24)
legend = plt.legend(loc='best', fontsize=14, frameon=True)
legend.get_frame().set_facecolor('white')  
legend.get_frame().set_edgecolor('black')  
plt.text(10, -0.15, f'MSE: {error:.6f}', fontsize=14, color='k',
         bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()
# Out:
# Train MSE: 0.000471

# %%
rawResiduals_ARIMA_t_SVR = Y - pred
plt.plot(rawResiduals_ARIMA_t_SVR)
plt.show()

rawResiduals_ARIMA_t_SVR.to_csv('rawResiduals_ARIMA_t_SVR_BO-TPE_standardscaler.csv', index=False)

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox

lags=np.ceil(np.log(len(rawResiduals_ARIMA_t_SVR)))

plt.figure(figsize=(10, 5))
plot_acf(rawResiduals_ARIMA_t_SVR, lags=lags, alpha=0.05)
plt.title('Autocorrelation Function (ACF)')
plt.show()

plt.figure(figsize=(10, 5))
plot_pacf(rawResiduals_ARIMA_t_SVR, lags=lags, alpha=0.05, method='ywm')
plt.title('Partial Autocorrelation Function (PACF)')
plt.show()

lbq_test = acorr_ljungbox(rawResiduals_ARIMA_t_SVR, lags=lags, return_df=True)
print(lbq_test)
# Out:
#      lb_stat     lb_pvalue
# 1   0.044592  8.327554e-01
# 2   2.490549  2.878618e-01
# 3   4.444026  2.173377e-01
# 4   7.687506  1.037197e-01
# 5   7.815417  1.667060e-01
# 6  28.083320  9.062779e-05
# 7  29.971087  9.612630e-05
# 8  44.781308  4.048375e-07

# %%
test_extended = training_error.tolist()[-1*window_size:] + error_list
test_data = []
for i in test_extended:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
        
test_data = np.array(test_data).reshape(-1,1)
test_scaled = scaler.transform(test_data)

test_X,test_Y = [],[]
for i in range(0 , len(test_scaled) - window_size):
    test_X.append(test_scaled[i:i+window_size])
    test_Y.append(test_scaled[i+window_size])

new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)

predictions = model.predict(new_test_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))


Y = pd.DataFrame(error_list)
pred = pd.DataFrame(predictions_rescaled)

plt.plot(predictions_rescaled , color = 'r')
plt.show()
error = mse(error_list,predictions_rescaled)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000536

# %%
error = mse(error_list,predictions_rescaled)
print('Test MSE: %.6f' % error)

plt.plot(Y, label='Forecasting Error ARIMA-t')
plt.plot(pred , color = 'r', label='Residual Forecasts')
plt.xlabel('Time', fontsize=20)  
plt.ylabel('Value', fontsize=20) 
plt.ylim([-0.18,0.18])  
legend = plt.legend(loc='best', fontsize=14, frameon=True)
legend.get_frame().set_facecolor('white') 
legend.get_frame().set_edgecolor('black') 
plt.title('ML Forecasts On ARIMA-t Forecasting Errors', fontsize=24)
plt.text(50, 0.13, f'MSE: {error:.6f}', fontsize=14, color='k',
         bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()
# Out:
# Test MSE: 0.000536

# %%
predicted_array = np.array(predicted_list)
final_pred = predicted_array+predictions_rescaled.flatten()
hybrid_error = mse(np.array(test), final_pred)
print('Hybrid Test MSE: %.6f' % hybrid_error)

plt.plot(pd.DataFrame(test), label="Real Log Close")
plt.plot(pd.DataFrame(final_pred), color='r', label="Hybrid Forecasts")
plt.xlabel('Time', fontsize=20)  
plt.ylabel('Value', fontsize=20)  
legend = plt.legend(loc='best', fontsize=14, frameon=True)
legend.get_frame().set_facecolor('white') 
legend.get_frame().set_edgecolor('black') 
plt.title('Hybrid Forecasts On Test Data', fontsize=24)
plt.text(60, 3.3, f'MSE: {error:.6f}', fontsize=14, color='k',
         bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()
# Out:
# Hybrid Test MSE: 0.000536

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on logclose: ")
print(compute_error_metrics(test, final_pred))
print(compute_directional_metrics(test, final_pred))
# Out:
# Errors on logclose:
# {'NMSE': 0.09463161041897197, 'MAE': 0.014829452200622865, 'RMSE': 0.02314721556266133, 'MSE': 0.0005357935883043109, 'MAPE': 0.418296439926252, 'TheilsU': 1.0014358534233536}
# {'DA': 0.5050505050505051, 'DS': 0.5454545454545454, 'CU': 0.5964912280701754, 'CD': 0.47619047619047616}

# %%
close_pred = np.exp(final_pred)
Y = pd.DataFrame(close_test)
pred = pd.DataFrame(close_pred)
plt.plot(Y, label="Actual Close")
plt.plot(pred , color = 'r', label="Hybrid Forecast Close")
plt.legend()
plt.show()

error = mse(close_test,close_pred)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.658509

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on close: ")
print(compute_error_metrics(close_test, close_pred))
print(compute_directional_metrics(close_test, close_pred))
# Out:
# Errors on close:
# {'NMSE': 0.10746912460468584, 'MAE': 0.5123204543509189, 'RMSE': 0.811485393637549, 'MSE': 0.6585085440870878, 'MAPE': 1.4736193643599973, 'TheilsU': 1.000903978424456}
# {'DA': 0.5050505050505051, 'DS': 0.5454545454545454, 'CU': 0.5964912280701754, 'CD': 0.47619047619047616}

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from trading_strategies import trading_strategy1

trading_strategy1(close_test, close_pred)
# Out:
# Stock: 28.09 Action: Buy Portfolio: 28090.0 Stocks: 1000 Balance_init: 0 total($) 28090.0
# Stock: 27.75 Action: Bought--Holding Portfolio: 27750.0 Stocks: 1000 Balance_init: 0 total($) 27750.0
# Stock: 27.94 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 27940.0
# Stock: 28.18 Action: Buy Portfolio: 27926.38 Stocks: 991 Balance_init: 13 total($) 27939.38
# Stock: 28.42 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28177.22
# Stock: 28.41 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28177.22
# Stock: 29.44 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28177.22
# Stock: 29.65 Action: Buy Portfolio: 28167.5 Stocks: 950 Balance_init: 9 total($) 28176.5
# Stock: 29.72 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28243.0
# Stock: 29.94 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28243.0
# Stock: 30.76 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28243.0
# Stock: 31.36 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28243.0
# Stock: 31.07 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28243.0
# Stock: 31.19 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28243.0
# Stock: 31.82 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28243.0
# Stock: 32.69 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28243.0
# Stock: 33.01 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28243.0
# Stock: 32.65 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28243.0
# Stock: 32.75 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28243.0
# Stock: 33.14 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 28243.0
# Stock: 32.8 Action: Buy Portfolio: 28240.8 Stocks: 861 Balance_init: 2 total($) 28242.8
# Stock: 38.36 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33029.96
# Stock: 36.5 Action: Buy Portfolio: 32996.0 Stocks: 904 Balance_init: 33 total($) 33029.0
# Stock: 35.32 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31962.28
# Stock: 35.35 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31962.28
# Stock: 35.63 Action: Buy Portfolio: 31960.11 Stocks: 897 Balance_init: 2 total($) 31962.11
# Stock: 36.18 Action: Bought--Holding Portfolio: 32453.46 Stocks: 897 Balance_init: 2 total($) 32455.46
# Stock: 36.45 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32697.65
# Stock: 36.18 Action: Buy Portfolio: 32670.54 Stocks: 903 Balance_init: 27 total($) 32697.54
# Stock: 36.32 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32823.96
# Stock: 36.3 Action: Buy Portfolio: 32815.2 Stocks: 904 Balance_init: 8 total($) 32823.2
# Stock: 36.45 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32958.8
# Stock: 35.51 Action: Buy Portfolio: 32953.28 Stocks: 928 Balance_init: 5 total($) 32958.28
# Stock: 35.93 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33348.04
# Stock: 36.75 Action: Buy Portfolio: 33332.25 Stocks: 907 Balance_init: 15 total($) 33347.25
# Stock: 36.24 Action: Bought--Holding Portfolio: 32869.68 Stocks: 907 Balance_init: 15 total($) 32884.68
# Stock: 36.37 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33002.59
# Stock: 36.3 Action: Buy Portfolio: 32996.7 Stocks: 909 Balance_init: 5 total($) 33001.7
# Stock: 36.27 Action: Bought--Holding Portfolio: 32969.43 Stocks: 909 Balance_init: 5 total($) 32974.43
# Stock: 35.09 Action: Bought--Holding Portfolio: 31896.81 Stocks: 909 Balance_init: 5 total($) 31901.81
# Stock: 34.71 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31556.39
# Stock: 35.02 Action: Buy Portfolio: 31553.02 Stocks: 901 Balance_init: 3 total($) 31556.02
# Stock: 34.97 Action: Bought--Holding Portfolio: 31507.97 Stocks: 901 Balance_init: 3 total($) 31510.97
# Stock: 34.8 Action: Bought--Holding Portfolio: 31354.8 Stocks: 901 Balance_init: 3 total($) 31357.8
# Stock: 34.85 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31402.85
# Stock: 34.63 Action: Buy Portfolio: 31374.78 Stocks: 906 Balance_init: 28 total($) 31402.78
# Stock: 35.32 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32027.92
# Stock: 35.42 Action: Buy Portfolio: 32019.68 Stocks: 904 Balance_init: 8 total($) 32027.68
# Stock: 36.07 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32615.28
# Stock: 36.1 Action: Buy Portfolio: 32598.3 Stocks: 903 Balance_init: 16 total($) 32614.3
# Stock: 36.73 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33183.19
# Stock: 37.34 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33183.19
# Stock: 38.0 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33183.19
# Stock: 38.11 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33183.19
# Stock: 37.38 Action: Buy Portfolio: 33156.06 Stocks: 887 Balance_init: 27 total($) 33183.06
# Stock: 37.15 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32979.05
# Stock: 38.02 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32979.05
# Stock: 37.71 Action: Buy Portfolio: 32958.54 Stocks: 874 Balance_init: 20 total($) 32978.54
# Stock: 37.82 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33074.68
# Stock: 36.25 Action: Buy Portfolio: 33060.0 Stocks: 912 Balance_init: 14 total($) 33074.0
# Stock: 36.34 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33156.08
# Stock: 36.13 Action: Buy Portfolio: 33131.21 Stocks: 917 Balance_init: 24 total($) 33155.21
# Stock: 35.52 Action: Bought--Holding Portfolio: 32571.84 Stocks: 917 Balance_init: 24 total($) 32595.84
# Stock: 36.09 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33118.53
# Stock: 35.17 Action: Buy Portfolio: 33094.97 Stocks: 941 Balance_init: 23 total($) 33117.97
# Stock: 33.72 Action: Bought--Holding Portfolio: 31730.52 Stocks: 941 Balance_init: 23 total($) 31753.52
# Stock: 32.75 Action: Bought--Holding Portfolio: 30817.75 Stocks: 941 Balance_init: 23 total($) 30840.75
# Stock: 32.72 Action: Bought--Holding Portfolio: 30789.52 Stocks: 941 Balance_init: 23 total($) 30812.52
# Stock: 32.02 Action: Bought--Holding Portfolio: 30130.82 Stocks: 941 Balance_init: 23 total($) 30153.82
# Stock: 33.02 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31094.82
# Stock: 33.54 Action: Buy Portfolio: 31091.58 Stocks: 927 Balance_init: 3 total($) 31094.58
# Stock: 33.78 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31317.06
# Stock: 34.76 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31317.06
# Stock: 34.75 Action: Buy Portfolio: 31309.75 Stocks: 901 Balance_init: 7 total($) 31316.75
# Stock: 35.49 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31983.49
# Stock: 35.91 Action: Price-Prediction-Already-Lower Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31983.49
# Stock: 34.6 Action: Buy Portfolio: 31970.4 Stocks: 924 Balance_init: 13 total($) 31983.4
# Stock: 34.81 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32177.44
# Stock: 35.27 Action: Buy Portfolio: 32166.24 Stocks: 912 Balance_init: 11 total($) 32177.24
# Stock: 35.08 Action: Bought--Holding Portfolio: 31992.96 Stocks: 912 Balance_init: 11 total($) 32003.96
# Stock: 35.66 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32532.92
# Stock: 35.57 Action: Buy Portfolio: 32510.98 Stocks: 914 Balance_init: 21 total($) 32531.98
# Stock: 35.6 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32559.4
# Stock: 34.76 Action: Buy Portfolio: 32535.36 Stocks: 936 Balance_init: 24 total($) 32559.36
# Stock: 35.46 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 33214.56
# Stock: 36.18 Action: Buy Portfolio: 33213.24 Stocks: 918 Balance_init: 1 total($) 33214.24
# Stock: 35.38 Action: Bought--Holding Portfolio: 32478.84 Stocks: 918 Balance_init: 1 total($) 32479.84
# Stock: 35.33 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32433.94
# Stock: 34.4 Action: Buy Portfolio: 32404.8 Stocks: 942 Balance_init: 29 total($) 32433.8
# Stock: 33.82 Action: Bought--Holding Portfolio: 31858.44 Stocks: 942 Balance_init: 29 total($) 31887.44
# Stock: 34.18 Action: Bought--Holding Portfolio: 32197.56 Stocks: 942 Balance_init: 29 total($) 32226.56
# Stock: 33.47 Action: Bought--Holding Portfolio: 31528.74 Stocks: 942 Balance_init: 29 total($) 31557.74
# Stock: 33.37 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31463.54
# Stock: 33.1 Action: Buy Portfolio: 31445.0 Stocks: 950 Balance_init: 18 total($) 31463.0
# Stock: 33.32 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 31672.0
# Stock: 33.76 Action: Buy Portfolio: 31666.88 Stocks: 938 Balance_init: 5 total($) 31671.88
# Stock: 34.43 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32300.34
# Stock: 34.53 Action: Buy Portfolio: 32285.55 Stocks: 935 Balance_init: 14 total($) 32299.55
# Stock: 34.82 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 32570.7
# Final value of stock:
# 34.76
# Final value of portfolio:
# 32571.0

# %%
32571.0/(1000*34.76)
# Out:
# 0.9370253164556962

# %% [markdown]
# From here on all figures that were originally in MATLAB are generated for poster presentation

# %%
plt.plot(close)
plt.xlabel('Time', fontsize=20)  
plt.ylabel('Value', fontsize=20)  
plt.title('Close', fontsize=24)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()

# %%
plt.plot(logclose)
plt.xlabel('Time', fontsize=20)  
plt.ylabel('Value', fontsize=20)  
plt.title('Log Close', fontsize=24)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()

# %%
plt.plot(logreturns)
plt.xlabel('Time', fontsize=20)  
plt.ylabel('Value', fontsize=20)  
plt.title('Log Returns', fontsize=24)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, axes = plt.subplots(2, 1,figsize=(6, 6)) 

lags=np.ceil(np.log(len(logreturns)))

plot_acf(logreturns, ax=axes[0], lags=lags)  
axes[0].set_title('')
axes[0].set_xlabel('Lags', fontsize=20)
axes[0].set_ylabel('ACF', fontsize=20)
axes[0].tick_params(axis='both', which='major', labelsize=16) 
axes[0].grid(True)

plot_pacf(logreturns, ax=axes[1], lags=lags, method='ywm') 
axes[1].set_title('')
axes[1].set_xlabel('Lags', fontsize=20)
axes[1].set_ylabel('PACF', fontsize=20)
axes[1].tick_params(axis='both', which='major', labelsize=16) 
axes[1].grid(True)

fig.suptitle('Correlation in Training Log Returns', fontsize=24)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, axes = plt.subplots(2, 1,figsize=(6, 6)) 

lags=np.ceil(np.log(len(training_error)))

plot_acf(training_error, ax=axes[0], lags=lags)  
axes[0].set_title('')
axes[0].set_xlabel('Lags', fontsize=20)
axes[0].set_ylabel('ACF', fontsize=20)
axes[0].tick_params(axis='both', which='major', labelsize=16) 
axes[0].grid(True)

plot_pacf(training_error, ax=axes[1], lags=lags, method='ywm') 
axes[1].set_title('')
axes[1].set_xlabel('Lags', fontsize=20)
axes[1].set_ylabel('PACF', fontsize=20)
axes[1].tick_params(axis='both', which='major', labelsize=16) 
axes[1].grid(True)

fig.suptitle('Correlation in Residuals of ARIMA-t', fontsize=24)


plt.tight_layout()
plt.show()

# %%
import pandas as pd

csv_file_path = 'stanResiduals_ARIMA_t.csv'

df = pd.read_csv(csv_file_path, header=None)

stan = np.array(df[0].tolist())

import pandas as pd
import matplotlib.pyplot as plt

stan_series = pd.Series(stan)  


window_size = 100
moving_variance = stan_series.rolling(window=window_size, min_periods=1).var()

plt.figure()
plt.plot(moving_variance)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Variance', fontsize=20)
plt.ylim([-0.1,2.2])
plt.title('Moving Variance in Residuals of ARIMA-t', fontsize=24)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()

# %%
import pandas as pd

csv_file_path = 'stanResiduals_ARIMA_t_GARCH_t.csv'

df = pd.read_csv(csv_file_path, header=None)

stan = np.array(df[0].tolist())


import pandas as pd
import matplotlib.pyplot as plt

stan_series = pd.Series(stan)  


window_size = 100
moving_variance = stan_series.rolling(window=window_size, min_periods=1).var()

plt.figure()
plt.plot(moving_variance)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Variance', fontsize=20)
plt.ylim([-0.1,2.2])
plt.title('Moving Variance Residuals ARIMA_t-GARCH_t', fontsize=24)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()

# %%
import pandas as pd

csv_file_path = 'train_logclose.csv'

df = pd.read_csv(csv_file_path, header=None)

train_logclose = df[0].tolist()


plt.plot(train_logclose)
plt.xlabel('Time', fontsize=20)  
plt.ylabel('Value', fontsize=20)  
plt.title('Log Close Training Data', fontsize=24)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()

# %%
import pandas as pd

csv_file_path = 'rawResiduals_ARIMA_t.csv'

df = pd.read_csv(csv_file_path, header=None)

training_error = np.array(df[0].tolist())


import numpy as np
import matplotlib.pyplot as plt

train_logclose_pred = train_logclose - training_error

mse = np.mean((train_logclose - train_logclose_pred) ** 2)

plt.figure()
plt.plot(train_logclose, label='Real Log Close') 
plt.plot(train_logclose_pred, 'r', label='Log Close Predictions')  
plt.title('ARIMA-t Predictions On Training Data', fontsize=24)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Value', fontsize=20)
legend = plt.legend(loc='best', fontsize=14)
legend.get_frame().set_facecolor('white')
legend.get_frame().set_edgecolor('black')
plt.text(400, 2.65, f'MSE: {mse:.6f}', fontsize=14, color='k',
         bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()

# %%
import pandas as pd

csv_file_path = 'forecasted_logclose_ARIMA_t.csv'

df = pd.read_csv(csv_file_path, header=None)

predicted_list = np.array(df[0].tolist())


import numpy as np
import matplotlib.pyplot as plt


mse = np.mean((logclose_test - predicted_list) ** 2)

plt.figure()
plt.plot(logclose_test, label='Real Log Close') 
plt.plot(predicted_list, 'r', label='Log Close Forecasts')  
plt.title('ARIMA-t Forecasts on Test Data', fontsize=24)
plt.xlabel('Time', fontsize=20)
plt.ylabel('Value', fontsize=20)
legend = plt.legend(loc='best', fontsize=14)
legend.get_frame().set_facecolor('white')
legend.get_frame().set_edgecolor('black')
plt.text(0, 3.07, f'MSE: {mse:.6f}', fontsize=14, color='k',
         bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3'))
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)
plt.show()
