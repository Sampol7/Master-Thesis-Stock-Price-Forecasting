# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_squared_error as mse

# %%
import pandas as pd

csv_file_path = 'close.csv'

df = pd.read_csv(csv_file_path, header=None)

close = df[0].tolist()
logclose = np.log(close).tolist()


plt.plot(close , color = 'r')
plt.show()

# %%
from math import floor

size = len(close) - 100
close_train, close_test = close[0:size], close[size:len(close)]
logclose_train, logclose_test = logclose[0:size], logclose[size:len(logclose)]

logreturns = np.diff(logclose).tolist()
logreturns_train, logreturns_test = logreturns[0:size-1], logreturns[size-1:len(logreturns)]

series = logreturns
train = logreturns_train
test = logreturns_test

plt.plot(series , color = 'r')
plt.show()

train = np.array(train).reshape(-1,1)

# %%
import numpy as np
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.svm import SVR
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
import hyperopt
import warnings


space = {
    "window_size": hp.choice("window_size", range(2,20)),
    "kernel": hp.choice("kernel", ["linear", "poly", "rbf"]),
    "C": hp.loguniform("C", np.log(0.001), np.log(100)),
    "epsilon": hp.loguniform("epsilon", np.log(0.00001), np.log(1)),
    "gamma": hp.choice("gamma", ["scale", "auto"]),
    "degree": hp.quniform("degree", 2, 4, 1),  
    "coef0": hp.uniform("coef0", -5, 5)      
}

def objective(params):
    window_size = params["window_size"]
    kernel = params["kernel"]
    C = params["C"]
    epsilon = params["epsilon"]

    scaler = RobustScaler()

    train_scaled = scaler.fit_transform(train)
    train_X, train_Y = [], []
    for i in range(len(train_scaled) - window_size):
        train_X.append(train_scaled[i:i+window_size])
        train_Y.append(train_scaled[i+window_size])
    new_train_X = np.array([x.reshape(-1) for x in train_X])
    new_train_Y = np.array(train_Y).ravel()

    svr_params = {"C": C, "epsilon": epsilon}
    
    if kernel == "poly":
        svr_params["gamma"] = params["gamma"]
        svr_params["degree"] = int(params["degree"]) 
        svr_params["coef0"] = (params["coef0"])     
    elif kernel == "rbf":
        svr_params["gamma"] = params["gamma"]

    model = SVR(kernel=kernel, **svr_params)

    tscv = TimeSeriesSplit(n_splits=2)
    score = np.mean(cross_val_score(model, new_train_X, new_train_Y, cv=tscv, scoring='neg_mean_squared_error', n_jobs=-1))
    
    return {"loss": -score, "status": STATUS_OK}

trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials,
            rstate=np.random.default_rng(42))

best_loss = trials.best_trial['result']['loss']
best_score = best_loss

print("\n------------------------")
print("BEST OVERALL RESULTS:")
print("------------------------")
print("Best parameters (raw indices and values):")
print(best)
print(f"Best score: {best_score:.4f}")
# Out:
# 100%|██████████| 100/100 [01:41<00:00,  1.02s/trial, best loss: 1.5591761472636503]
#
# ------------------------
# BEST OVERALL RESULTS:
# ------------------------
# Best parameters (raw indices and values):
# {'C': 0.04775046373841452, 'coef0': 0.7637796058473376, 'degree': 3.0, 'epsilon': 0.40929922744511105, 'gamma': 1, 'kernel': 0, 'window_size': 0}
# Best score: 1.5592

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.svm import SVR
import numpy as np

window_sizes = range(2,20)
kernels_list = ["linear", "poly", "rbf"]
gamma_list = ["scale", "auto"]

window_size = window_sizes[best["window_size"]]
best_kernel = kernels_list[best["kernel"]]
best_gamma = gamma_list[best["gamma"]]
best_C = best["C"]
best_epsilon = best["epsilon"]
best_degree = int(best["degree"]) if best_kernel == "poly" else None
best_coef0 = (best["coef0"]) if best_kernel == "poly" else None

scaler = RobustScaler()

train_scaled = scaler.fit_transform(train)
train_X, train_Y = [], []
for i in range(0, len(train_scaled) - window_size):
    train_X.append(train_scaled[i:i+window_size])
    train_Y.append(train_scaled[i+window_size])

new_train_X = np.array([x.reshape(-1) for x in train_X])
new_train_Y = np.array(train_Y).ravel()

svr_params = {"C": best_C, "epsilon": best_epsilon}
if best_kernel == "poly":
    svr_params["gamma"] = best_gamma
    svr_params["degree"] = best_degree
    svr_params["coef0"] = best_coef0
elif best_kernel == "rbf":
    svr_params["gamma"] = best_gamma

model = SVR(kernel=best_kernel, **svr_params)

model.fit(new_train_X, new_train_Y)
# Out:
# SVR(C=0.04775046373841452, epsilon=0.40929922744511105, kernel='linear')

# %%
print(window_size)
print(best_kernel)
print(best_gamma)
print(best_C)
print(best_epsilon)
print(best_degree)
print(best_coef0)
# Out:
# 2
# linear
# auto
# 0.04775046373841452
# 0.40929922744511105
# None
# None

# %%
predictions = model.predict(new_train_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))
Y = pd.DataFrame(train[window_size:])
pred = pd.DataFrame(predictions_rescaled)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()
error = mse(train[window_size:],predictions_rescaled)
print('Train MSE: %.10f' % error)
# Out:
# Train MSE: 0.0004708460

# %%
rawResiduals_SVR = Y - pred
plt.plot(rawResiduals_SVR)
plt.show()

rawResiduals_SVR.to_csv('rawResiduals_SVR_BO-TPE_robustscaler.csv', index=False)

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox

lags=np.ceil(np.log(len(rawResiduals_SVR)))

plt.figure(figsize=(10, 5))
plot_acf(rawResiduals_SVR, lags=lags, alpha=0.05)
plt.title('Autocorrelation Function (ACF)')
plt.show()

plt.figure(figsize=(10, 5))
plot_pacf(rawResiduals_SVR, lags=lags, alpha=0.05, method='ywm')
plt.title('Partial Autocorrelation Function (PACF)')
plt.show()

lbq_test = acorr_ljungbox(rawResiduals_SVR, lags=lags, return_df=True)
print(lbq_test)
# Out:
#      lb_stat     lb_pvalue
# 1   0.091889  7.617892e-01
# 2   3.120093  2.101263e-01
# 3   3.197168  3.622132e-01
# 4   8.168060  8.561234e-02
# 5   8.207549  1.451621e-01
# 6  27.340084  1.250323e-04
# 7  29.223922  1.316952e-04
# 8  43.133065  8.291693e-07

# %%
test_extended = train.tolist()[-1*window_size:] + test
test_data = []
for i in test_extended:
    try:
        test_data.append(i[0])
    except:
        test_data.append(i)
test_data = np.array(test_data).reshape(-1,1)
test_scaled = scaler.transform(test_data)
test_X,test_Y = [],[]
for i in range(0 , len(test_scaled) - window_size):
    test_X.append(test_scaled[i:i+window_size])
    test_Y.append(test_scaled[i+window_size])
new_test_X,new_test_Y = [],[]
for i in test_X:
    new_test_X.append(i.reshape(-1))
for i in test_Y:
    new_test_Y.append(i.reshape(-1))
new_test_X = np.array(new_test_X)
new_test_Y = np.array(new_test_Y)
predictions = model.predict(new_test_X)
predictions_rescaled=scaler.inverse_transform(predictions.reshape(-1, 1))
predictions_rescaled = predictions_rescaled.flatten().tolist()

Y = pd.DataFrame(test)
pred = pd.DataFrame(predictions_rescaled)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()
error = mse(test,predictions_rescaled)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000529

# %%
predicted_log_prices = np.zeros(len(logclose_test)) 
predicted_log_prices[0] = logclose_train[-1] + predictions_rescaled[0]

for t in range(1, len(logclose_test)):
    predicted_log_prices[t] = logclose_test[t-1] + predictions_rescaled[t] 


Y = pd.DataFrame(logclose_test)
pred = pd.DataFrame(predicted_log_prices)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()

error = mse(logclose_test,predicted_log_prices)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.000529

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on logclose: ")
print(compute_error_metrics(logclose_test, predicted_log_prices))
print(compute_directional_metrics(logclose_test, predicted_log_prices))
# Out:
# Errors on logclose:
# {'NMSE': 0.09351899337270482, 'MAE': 0.014502906762261012, 'RMSE': 0.02301073825624406, 'MSE': 0.000529494075097374, 'MAPE': 0.40898960297731646, 'TheilsU': 0.9947772950362466}
# {'DA': 0.5656565656565656, 'DS': 0.5151515151515151, 'CU': 0.5789473684210527, 'CD': 0.42857142857142855}

# %%
predicted_prices = np.exp(predicted_log_prices)
Y = pd.DataFrame(close_test)
pred = pd.DataFrame(predicted_prices)
plt.plot(Y)
plt.plot(pred , color = 'r')
plt.show()

error = mse(close_test,predicted_prices)
print('Test MSE: %.6f' % error)
# Out:
# Test MSE: 0.653181

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from forecast_metrics import compute_error_metrics, compute_directional_metrics
print("Errors on close: ")
print(compute_error_metrics(close_test, predicted_prices))
print(compute_directional_metrics(close_test, predicted_prices))
# Out:
# Errors on close:
# {'NMSE': 0.10659972320241971, 'MAE': 0.5018557337504708, 'RMSE': 0.8081963597386239, 'MSE': 0.6531813558947632, 'MAPE': 1.4423919149713125, 'TheilsU': 0.9947935810295321}
# {'DA': 0.5656565656565656, 'DS': 0.5151515151515151, 'CU': 0.5789473684210527, 'CD': 0.42857142857142855}

# %%
import sys
sys.path.append('../Functions/Performance Metrics/')
from trading_strategies import trading_strategy1

trading_strategy1(close_test, predicted_prices)
# Out:
# Stock: 28.09 Action: Buy Portfolio: 28090.0 Stocks: 1000 Balance_init: 0 total($) 28090.0
# Stock: 27.75 Action: Bought--Holding Portfolio: 27750.0 Stocks: 1000 Balance_init: 0 total($) 27750.0
# Stock: 27.94 Action: Bought--Holding Portfolio: 27940.0 Stocks: 1000 Balance_init: 0 total($) 27940.0
# Stock: 28.18 Action: Bought--Holding Portfolio: 28180.0 Stocks: 1000 Balance_init: 0 total($) 28180.0
# Stock: 28.42 Action: Bought--Holding Portfolio: 28420.0 Stocks: 1000 Balance_init: 0 total($) 28420.0
# Stock: 28.41 Action: Bought--Holding Portfolio: 28410.0 Stocks: 1000 Balance_init: 0 total($) 28410.0
# Stock: 29.44 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 29440.0
# Stock: 29.65 Action: Buy Portfolio: 29412.8 Stocks: 992 Balance_init: 27 total($) 29439.8
# Stock: 29.72 Action: Bought--Holding Portfolio: 29482.24 Stocks: 992 Balance_init: 27 total($) 29509.24
# Stock: 29.94 Action: Bought--Holding Portfolio: 29700.48 Stocks: 992 Balance_init: 27 total($) 29727.48
# Stock: 30.76 Action: Bought--Holding Portfolio: 30513.92 Stocks: 992 Balance_init: 27 total($) 30540.92
# Stock: 31.36 Action: Bought--Holding Portfolio: 31109.12 Stocks: 992 Balance_init: 27 total($) 31136.12
# Stock: 31.07 Action: Bought--Holding Portfolio: 30821.44 Stocks: 992 Balance_init: 27 total($) 30848.44
# Stock: 31.19 Action: Bought--Holding Portfolio: 30940.48 Stocks: 992 Balance_init: 27 total($) 30967.48
# Stock: 31.82 Action: Bought--Holding Portfolio: 31565.44 Stocks: 992 Balance_init: 27 total($) 31592.44
# Stock: 32.69 Action: Bought--Holding Portfolio: 32428.48 Stocks: 992 Balance_init: 27 total($) 32455.48
# Stock: 33.01 Action: Bought--Holding Portfolio: 32745.92 Stocks: 992 Balance_init: 27 total($) 32772.92
# Stock: 32.65 Action: Bought--Holding Portfolio: 32388.8 Stocks: 992 Balance_init: 27 total($) 32415.8
# Stock: 32.75 Action: Bought--Holding Portfolio: 32488.0 Stocks: 992 Balance_init: 27 total($) 32515.0
# Stock: 33.14 Action: Bought--Holding Portfolio: 32874.88 Stocks: 992 Balance_init: 27 total($) 32901.88
# Stock: 32.8 Action: Bought--Holding Portfolio: 32537.6 Stocks: 992 Balance_init: 27 total($) 32564.6
# Stock: 38.36 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 38080.12
# Stock: 36.5 Action: Buy Portfolio: 38069.5 Stocks: 1043 Balance_init: 10 total($) 38079.5
# Stock: 35.32 Action: Bought--Holding Portfolio: 36838.76 Stocks: 1043 Balance_init: 10 total($) 36848.76
# Stock: 35.35 Action: Bought--Holding Portfolio: 36870.05 Stocks: 1043 Balance_init: 10 total($) 36880.05
# Stock: 35.63 Action: Bought--Holding Portfolio: 37162.09 Stocks: 1043 Balance_init: 10 total($) 37172.09
# Stock: 36.18 Action: Bought--Holding Portfolio: 37735.74 Stocks: 1043 Balance_init: 10 total($) 37745.74
# Stock: 36.45 Action: Bought--Holding Portfolio: 38017.35 Stocks: 1043 Balance_init: 10 total($) 38027.35
# Stock: 36.18 Action: Bought--Holding Portfolio: 37735.74 Stocks: 1043 Balance_init: 10 total($) 37745.74
# Stock: 36.32 Action: Bought--Holding Portfolio: 37881.76 Stocks: 1043 Balance_init: 10 total($) 37891.76
# Stock: 36.3 Action: Bought--Holding Portfolio: 37860.9 Stocks: 1043 Balance_init: 10 total($) 37870.9
# Stock: 36.45 Action: Bought--Holding Portfolio: 38017.35 Stocks: 1043 Balance_init: 10 total($) 38027.35
# Stock: 35.51 Action: Bought--Holding Portfolio: 37036.93 Stocks: 1043 Balance_init: 10 total($) 37046.93
# Stock: 35.93 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 37484.99
# Stock: 36.75 Action: Buy Portfolio: 37448.25 Stocks: 1019 Balance_init: 36 total($) 37484.25
# Stock: 36.24 Action: Bought--Holding Portfolio: 36928.56 Stocks: 1019 Balance_init: 36 total($) 36964.56
# Stock: 36.37 Action: Bought--Holding Portfolio: 37061.03 Stocks: 1019 Balance_init: 36 total($) 37097.03
# Stock: 36.3 Action: Bought--Holding Portfolio: 36989.7 Stocks: 1019 Balance_init: 36 total($) 37025.7
# Stock: 36.27 Action: Bought--Holding Portfolio: 36959.13 Stocks: 1019 Balance_init: 36 total($) 36995.13
# Stock: 35.09 Action: Bought--Holding Portfolio: 35756.71 Stocks: 1019 Balance_init: 36 total($) 35792.71
# Stock: 34.71 Action: Bought--Holding Portfolio: 35369.49 Stocks: 1019 Balance_init: 36 total($) 35405.49
# Stock: 35.02 Action: Bought--Holding Portfolio: 35685.38 Stocks: 1019 Balance_init: 36 total($) 35721.38
# Stock: 34.97 Action: Bought--Holding Portfolio: 35634.43 Stocks: 1019 Balance_init: 36 total($) 35670.43
# Stock: 34.8 Action: Bought--Holding Portfolio: 35461.2 Stocks: 1019 Balance_init: 36 total($) 35497.2
# Stock: 34.85 Action: Bought--Holding Portfolio: 35512.15 Stocks: 1019 Balance_init: 36 total($) 35548.15
# Stock: 34.63 Action: Bought--Holding Portfolio: 35287.97 Stocks: 1019 Balance_init: 36 total($) 35323.97
# Stock: 35.32 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 36027.08
# Stock: 35.42 Action: Buy Portfolio: 36022.14 Stocks: 1017 Balance_init: 4 total($) 36026.14
# Stock: 36.07 Action: Bought--Holding Portfolio: 36683.19 Stocks: 1017 Balance_init: 4 total($) 36687.19
# Stock: 36.1 Action: Bought--Holding Portfolio: 36713.7 Stocks: 1017 Balance_init: 4 total($) 36717.7
# Stock: 36.73 Action: Bought--Holding Portfolio: 37354.41 Stocks: 1017 Balance_init: 4 total($) 37358.41
# Stock: 37.34 Action: Bought--Holding Portfolio: 37974.78 Stocks: 1017 Balance_init: 4 total($) 37978.78
# Stock: 38.0 Action: Bought--Holding Portfolio: 38646.0 Stocks: 1017 Balance_init: 4 total($) 38650.0
# Stock: 38.11 Action: Bought--Holding Portfolio: 38757.87 Stocks: 1017 Balance_init: 4 total($) 38761.87
# Stock: 37.38 Action: Bought--Holding Portfolio: 38015.46 Stocks: 1017 Balance_init: 4 total($) 38019.46
# Stock: 37.15 Action: Bought--Holding Portfolio: 37781.55 Stocks: 1017 Balance_init: 4 total($) 37785.55
# Stock: 38.02 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 38670.34
# Stock: 37.71 Action: Buy Portfolio: 38652.75 Stocks: 1025 Balance_init: 17 total($) 38669.75
# Stock: 37.82 Action: Bought--Holding Portfolio: 38765.5 Stocks: 1025 Balance_init: 17 total($) 38782.5
# Stock: 36.25 Action: Bought--Holding Portfolio: 37156.25 Stocks: 1025 Balance_init: 17 total($) 37173.25
# Stock: 36.34 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 37265.5
# Stock: 36.13 Action: Buy Portfolio: 37250.03 Stocks: 1031 Balance_init: 15 total($) 37265.03
# Stock: 35.52 Action: Bought--Holding Portfolio: 36621.12 Stocks: 1031 Balance_init: 15 total($) 36636.12
# Stock: 36.09 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 37223.79
# Stock: 35.17 Action: Buy Portfolio: 37209.86 Stocks: 1058 Balance_init: 13 total($) 37222.86
# Stock: 33.72 Action: Bought--Holding Portfolio: 35675.76 Stocks: 1058 Balance_init: 13 total($) 35688.76
# Stock: 32.75 Action: Bought--Holding Portfolio: 34649.5 Stocks: 1058 Balance_init: 13 total($) 34662.5
# Stock: 32.72 Action: Bought--Holding Portfolio: 34617.76 Stocks: 1058 Balance_init: 13 total($) 34630.76
# Stock: 32.02 Action: Bought--Holding Portfolio: 33877.16 Stocks: 1058 Balance_init: 13 total($) 33890.16
# Stock: 33.02 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 34948.16
# Stock: 33.54 Action: Buy Portfolio: 34915.14 Stocks: 1041 Balance_init: 33 total($) 34948.14
# Stock: 33.78 Action: Bought--Holding Portfolio: 35164.98 Stocks: 1041 Balance_init: 33 total($) 35197.98
# Stock: 34.76 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 36218.16
# Stock: 34.75 Action: Buy Portfolio: 36209.5 Stocks: 1042 Balance_init: 8 total($) 36217.5
# Stock: 35.49 Action: Bought--Holding Portfolio: 36980.58 Stocks: 1042 Balance_init: 8 total($) 36988.58
# Stock: 35.91 Action: Bought--Holding Portfolio: 37418.22 Stocks: 1042 Balance_init: 8 total($) 37426.22
# Stock: 34.6 Action: Bought--Holding Portfolio: 36053.2 Stocks: 1042 Balance_init: 8 total($) 36061.2
# Stock: 34.81 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 36280.02
# Stock: 35.27 Action: Buy Portfolio: 36257.56 Stocks: 1028 Balance_init: 22 total($) 36279.56
# Stock: 35.08 Action: Bought--Holding Portfolio: 36062.24 Stocks: 1028 Balance_init: 22 total($) 36084.24
# Stock: 35.66 Action: Bought--Holding Portfolio: 36658.48 Stocks: 1028 Balance_init: 22 total($) 36680.48
# Stock: 35.57 Action: Bought--Holding Portfolio: 36565.96 Stocks: 1028 Balance_init: 22 total($) 36587.96
# Stock: 35.6 Action: Bought--Holding Portfolio: 36596.8 Stocks: 1028 Balance_init: 22 total($) 36618.8
# Stock: 34.76 Action: Bought--Holding Portfolio: 35733.28 Stocks: 1028 Balance_init: 22 total($) 35755.28
# Stock: 35.46 Action: Sell Portfolio: 0 Stocks: 0 Balance_init: 0 total($) 36474.88
# Stock: 36.18 Action: Buy Portfolio: 36469.44 Stocks: 1008 Balance_init: 5 total($) 36474.44
# Stock: 35.38 Action: Bought--Holding Portfolio: 35663.04 Stocks: 1008 Balance_init: 5 total($) 35668.04
# Stock: 35.33 Action: Bought--Holding Portfolio: 35612.64 Stocks: 1008 Balance_init: 5 total($) 35617.64
# Stock: 34.4 Action: Bought--Holding Portfolio: 34675.2 Stocks: 1008 Balance_init: 5 total($) 34680.2
# Stock: 33.82 Action: Bought--Holding Portfolio: 34090.56 Stocks: 1008 Balance_init: 5 total($) 34095.56
# Stock: 34.18 Action: Bought--Holding Portfolio: 34453.44 Stocks: 1008 Balance_init: 5 total($) 34458.44
# Stock: 33.47 Action: Bought--Holding Portfolio: 33737.76 Stocks: 1008 Balance_init: 5 total($) 33742.76
# Stock: 33.37 Action: Bought--Holding Portfolio: 33636.96 Stocks: 1008 Balance_init: 5 total($) 33641.96
# Stock: 33.1 Action: Bought--Holding Portfolio: 33364.8 Stocks: 1008 Balance_init: 5 total($) 33369.8
# Stock: 33.32 Action: Bought--Holding Portfolio: 33586.56 Stocks: 1008 Balance_init: 5 total($) 33591.56
# Stock: 33.76 Action: Bought--Holding Portfolio: 34030.08 Stocks: 1008 Balance_init: 5 total($) 34035.08
# Stock: 34.43 Action: Bought--Holding Portfolio: 34705.44 Stocks: 1008 Balance_init: 5 total($) 34710.44
# Stock: 34.53 Action: Bought--Holding Portfolio: 34806.24 Stocks: 1008 Balance_init: 5 total($) 34811.24
# Stock: 34.82 Action: Bought--Holding Portfolio: 35098.56 Stocks: 1008 Balance_init: 5 total($) 35103.56
# Final value of stock:
# 34760.0
# Final value of portfolio:
# 35104.0
# TS=
# 1.0098964326812427
